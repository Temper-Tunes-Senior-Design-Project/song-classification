# %%
import json
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import scipy.stats as stats
import pickle
import numpy as np
import matplotlib.pyplot as plt
from numpy.linalg import norm
import pandas as pd
from sklearn.discriminant_analysis import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import warnings
import time
from spotipy.oauth2 import SpotifyOAuth

# %%
from os import chdir

# %%
chdir('C:/Users/mlar5/OneDrive/Desktop/Code Folder/Python Projects/IRL projects/Aspire - Affective Computing Project/Playlists Data/Audio Features/Personal Track Testing')
songs_df = pd.read_csv('liked_songs_and_playlists.csv')
chdir('C:/Users/mlar5/OneDrive/Desktop/Code Folder/198 Senior Design/Models/Spotipy v1.2')

# %%
sp = spotipy.Spotify(auth_manager=SpotifyOAuth('86677c795a49463d9281fac012a87155','fe6f941da771447c920e02bbb2a82859', redirect_uri='http://localhost:5000', scope='playlist-modify-public,playlist-modify-private') )

# %%
"""songs_df = pd.read_csv('results_from_800.csv').drop(['Unnamed: 0'],axis=1)
songs_df.head()"""
# Out:
# "songs_df = pd.read_csv('results_from_800.csv').drop(['Unnamed: 0'],axis=1)\nsongs_df.head()"

# %%
#Setup Spotify and Firebase Credentials
sp = None
def spotify_client():
    global sp
    #sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials('bf1ba68423404778a60bcf3dee58d199','7365dc611a2d4ddba4ad61343f0b64d7'))
    sp = spotipy.Spotify(auth_manager=SpotifyOAuth('86677c795a49463d9281fac012a87155','fe6f941da771447c920e02bbb2a82859', redirect_uri='http://localhost:5000',scope='user-library-read') )

    """sp_cred = None
    with open('spotify_credentials.json') as credentials:
        sp_cred = json.load(credentials)
    sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(sp_cred["client_id"],sp_cred['client_secret']))
    """
LR_model = None
def load_LR_model():
    global LR_model
    with open('logreg_model1.pkl','rb') as f:
        LR_model = pickle.load(f)
    warnings.filterwarnings("ignore", message="X does not have valid feature names, but LogisticRegression was fitted with feature names")
    
RF_model = None
def load_RF_model():
    global RF_model
    with open('rf2.pkl','rb') as f:
        RF_model = pickle.load(f)
        
MLP_model = None
def load_mlp_model():
    global MLP_model
    with open('MLP3.pkl','rb') as f:
        MLP_model = pickle.load(f)

# %%
#First, we need to obtain the centroids for each model:

#Create dict of dict of labels for each model
predicted_labels = {"MLP":{},"LR":{},"RF":{}, "CS":{}}


moods = ['sad','angry','energetic','excited','happy','content','calm','depressed'] #Represents DB indexing of moods
#Centroid features for the MLP, RF, and LR Models
centroid_features_MLP_RF = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 
                            'acousticness','instrumentalness', 'liveness', 'valence', 'tempo', 
                            'duration_ms', 'time_signature']
centroid_features_LR_CS = ['valence', 'energy']

#--------------------
# Classify Songs 
#--------------------

#Predicting labels of songs for each model
def assignLabels(names, song_ids):
    global sp
    if sp == None:
        spotify_client()
    
    predictions = {}
    predictions_prob = {}
    track_data = {}
    for name in names:
        predictions[name] = {}
        predictions_prob[name] = {}
        track_data[name] = {}
        # Use Spotipy to retrieve track information
        features_df = retrieveTrackFeatures(name, song_ids)
        processed_features_df = clipAndNormalize(name, features_df)
        if processed_features_df.shape[0] == 0:
            return {"error": "Issue with model and/or spotify server"}
        else:
            pred, pred_probability = getMoodLabel(name, processed_features_df)
            for i, (key, row) in enumerate(features_df.iterrows()):
                predictions[name][key]=pred[i]
                predictions_prob[name][key] = list(pred_probability[0])
                data = row.values.reshape(1,-1)
                track_data[name][key] = list(data[0])

    return (predictions, predictions_prob, track_data)

#--------------------
# Calculate Centroids
#--------------------

#Assign centroids for each model
def assignCentroids(names, predicted_labels, track_data):    
    model_centroids = {}
    for name in names:
        centroids = {mood:{} for mood in moods}
        predictions_current_model = predicted_labels[name]
        data = track_data[name]
        for mood_index in range(len(moods)):
            mood_song_scores = {song_id:data[song_id] for song_id, value in predictions_current_model.items() 
                                if value == mood_index}
            mood = moods[mood_index]
            fields = centroid_features_LR_CS if name in ['LR','CS'] else centroid_features_MLP_RF
            centroid = calculateCentroid(mood_song_scores, fields)
            if centroid is not None:
                centroids[mood] = centroid 
            #else default value for centroid??? (currently just 0.0)
        model_centroids[name] = centroids
    return model_centroids

#Calculate a single centroid
def calculateCentroid(songs, fields): #assuming songs is stored as {id: scores}
    num_songs = len(songs)
    if num_songs == 0: return None
    #get scores for the mood
    num_fields = len(fields)
    weight = 1/num_songs
    cumulative_score = [0 for element in range(num_fields)]
    for scores in songs.values():
        cumulative_score = np.add(scores, cumulative_score)
    final_scores = np.multiply(weight, cumulative_score)
    centroid = {feature:value for feature,value in zip(fields, final_scores)}
    return centroid


#--------------------
# Retrieve Closest Songs to Centroid
#--------------------
#Return closest songs for all moods for each model
def closestSongs(names, track_data, predictions, model_centroids):
    model_closest_songs = {}
    for name in names:
        model_closest_songs[name] = {}
        for mood_index in range(len(moods)):
            mood = moods[mood_index]
            centroid = model_centroids[name][mood]
            centroid_list = list(centroid.values())
            mood_songs = [track for track in predictions[name] if predictions[name][track] == mood_index] 
            songs = {track:track_data[name][track] for track in mood_songs}
            distances = []
            for (song_name, score) in songs.items():
                calculated_distance = cosineSimilarity(centroid_list, score)
                distances.append((song_name,calculated_distance))
            #sort the distances by value
            distances = sorted(distances, key=lambda x: x[1], reverse=True)
            #return the song names in order of closest to the centroid
            closest_songs = [pair[0] for pair in distances]
            model_closest_songs[name][mood] = closest_songs
    return model_closest_songs


#--------------------
# Generate Playlist 
#--------------------

def generateNewSongsList(names, num_songs, model_closest_songs): 
    global sp
    if sp == None:
        spotify_client()
    
    
    predicted_labels = {}
    final_stats = {}
    for name in names:
        predicted_labels[name] = {}
        final_stats[name] = {}
        for mood in moods:
            num_songs_in_arr = num_songs
            start_time = time.time()
            stats = {}
            predicted_labels[name][mood] = {}
            mood_index = moods.index(mood) #Numbered label of mood
            #specify target and close moods
#             acceptable_moods = [mood_index, (mood_index + len(moods) - 1) % len(moods), (mood_index + 1)%len(moods)]
            acceptable_moods = [mood_index]
            song_count = 0
            count_mood_index = 0 #TESTING TO DETERMINE RATE OF SONG ADDITION
            count_other_moods = 0
            count_similar_moods = 0
            counts = {}
            
            closest_song_ids = [song for song in model_closest_songs[name][mood] if song is not None][:5]
            # Use Spotipy to retrieve track information
            track_info = sp.tracks(closest_song_ids)['tracks']
            # Remove any elements that are None
            track_info = [track for track in track_info if track is not None]
            if len(track_info) == 0:
                return {"error": "could not identify any tracks in the closest songs list"}
            # Extract the URIs from the track information
            try:
                track_uris = [track['uri'] for track in track_info]
            except Exception as e:
                print(e)
                return e
                
            final_song_ids = []
            number_songs_to_pass = 5
            while len(final_song_ids) < num_songs_in_arr:        
                # Get recommended tracks and add them to final_song_ids if mood is classified as specified mood
                tracks = sp.recommendations(seed_tracks=track_uris[:number_songs_to_pass], limit=100)['tracks'] ##############################LIMIT
                track_ids = [track["id"] for track in tracks if track["id"] not in final_song_ids]
                # Get song features of the new ids
                features_df = retrieveTrackFeatures(name, track_ids)
                # Preprocess features
                processed_features_df = clipAndNormalize(name, features_df)

                # If there are no features or lyrics, and no songs are already labelled return an error
                if processed_features_df.shape[0] == 0:
                    return {"error": "Issue with model and/or spotify server"}
                else:
                    stop_loops = False
                    
                    pred, pred_probability = getMoodLabel(name, processed_features_df)
                    for i, (key, row) in enumerate(features_df.iterrows()):
                        if not(stop_loops):
                            predicted_labels[name][mood][key]=pred[i]
                            if pred[i] in acceptable_moods: song_count += 1
                            stop_loops = (song_count == num_songs_in_arr)
                            

                    # Combine predictions and known labels
                    # Currently, this will prioritize adding new songs to playlist over hits in our DB
                    
                # Add the remaining (newly predicted) song IDs where mood = mood_index
                ids_to_add = [key for key in predicted_labels[name][mood].keys() if predicted_labels[name][mood][key] in acceptable_moods
                             and key not in final_song_ids]
                if len(ids_to_add) == 0: # no songs were added
                    if number_songs_to_pass > 1:
                         number_songs_to_pass -= 1
                    else:
                        num_songs_in_arr = round(num_songs_in_arr/1.5)
                final_song_ids.extend(ids_to_add)
                num_songs_remaining = num_songs_in_arr - song_count    
                print(f"num_songs_remaining: {num_songs_remaining}")
                
            ### TESTING TO DETERMINE RATE OF SONG ADDITION
            ###STAT DICT FOR TESTING
            end_time = time.time()
            elapsed_time = end_time - start_time
            stat_dict = predicted_labels[name][mood]
            count_mood_index += len([key for key in stat_dict.keys() if stat_dict[key] == mood_index])
            count_other_moods += len(stat_dict) - len(final_song_ids)
            count_similar_moods += len([key for key in stat_dict.keys() if stat_dict[key] in 
                                        [(mood_index + len(moods) - 1) % len(moods), 
                                         (mood_index + 1)%len(moods)]])
            print(f"{name}:{mood}")
            print(f"\tcount of specified moods: {count_mood_index}")
            print(f"\tcount of other moods: {count_other_moods}")
            print(f"\tcount of similar moods: {count_similar_moods}")

            unique_elements = range(8)
            for elem in unique_elements:
                count = list(stat_dict.values()).count(elem)
                counts[moods[elem]] = counts.get(elem,0) + count
            print(f"\tcount of labels: {counts}")
            print(f"\tcounts: {counts.values()}")
            count_prob = {k: v/sum(counts.values()) for k,v in counts.items()}
            print(f"\tprobability of labels: {count_prob}")
            print(f"\telapsed time: {elapsed_time}")
            stats["count_mood_index"] = count_mood_index
            stats["count_other_moods"] = count_other_moods
            stats["count_similar_moods"] = count_similar_moods
            stats["label_counts"] = counts
            stats["label_prob"] = count_prob
            stats["elapsed_time"] = elapsed_time
            final_stats[name][mood] = stats
        
    return (predicted_labels, final_stats)

# %%
#--------------------
# Dispatcher Methods
#--------------------
def getMoodLabel(name, features):
    if name == "MLP":
        return getMoodLabelMLP(features)
    elif name == "RF":
        return getMoodLabelRF(features)
    elif name == "CS":
        return getMoodLabelCS(features)
    else: 
        return getMoodLabelLR(features)
    
def clipAndNormalize(name, features):
    if name == "MLP" or name == "RF":
        return clipAndNormalizeMLP_RF(features)
    elif name == "CS":
        return clipAndNormalizeCS(features)
    else: 
        return features #Nothing needed for LR model

def retrieveTrackFeatures(name, track_ids):
    dfs = []
    for i in range(0, len(track_ids), 50):
        # Retrieve track features with current offset
        features = sp.audio_features(track_ids[i:i+50])
        checked_features = [l for l in features if l is not None]
        # Convert to DataFrame
        if len(checked_features) > 0:
            df = pd.DataFrame(checked_features)

            # Remove columns that we don't need
            if name in ['LR','CS']:
                df = df[['id', 'valence', 'energy']]
            else:
                df = df.drop(['type', 'uri', 'analysis_url', 'track_href'], axis=1)

            # Append to list of dataframes
            dfs.append(df)
    
    # Concatenate all dataframes into a single one
    features_df = pd.concat(dfs, ignore_index=True)
    features_df.set_index("id", inplace=True)
    #convert to dictionary, with track id as key
#     features_dict = features_df.set_index('id').T.to_dict('list')
    return features_df
    
#--------------------
# MLP Functions
#--------------------
def getMoodLabelMLP(songFeatures):
    if MLP_model is None:
        load_mlp_model()
    prediction = MLP_model.predict(songFeatures.values)
    pred_probability= MLP_model.predict_proba(songFeatures.values)
    return prediction, pred_probability


#--------------------
# RF Functions
#--------------------
def getMoodLabelRF(songFeatures):
    if RF_model is None:
        load_RF_model()
    prediction = RF_model.predict(songFeatures.values)
    pred_probability= RF_model.predict_proba(songFeatures.values)
    return prediction, pred_probability

#Shared between MLP and RF models
def clipAndNormalizeMLP_RF(features):
    #clip the features to the range of the training data
    features['danceability'] = features['danceability'].clip(lower=0.25336000000000003, upper=0.9188199999999997)
    features['energy'] = features['energy'].clip(lower=0.047536, upper=0.982)
    features['loudness'] = features['loudness'].clip(lower=-24.65708, upper=-0.8038200000000288)
    features['speechiness'] = features['speechiness'].clip(lower=0.0263, upper=0.5018199999999997)
    features['acousticness'] = features['acousticness'].clip(lower=1.4072e-04, upper=0.986)
    features['instrumentalness'] = features['instrumentalness'].clip(lower=0.0, upper=0.951)
    features['liveness'] = features['liveness'].clip(lower=0.044836, upper=0.7224599999999991)
    features['valence'] = features['valence'].clip(lower=0.038318, upper=0.9348199999999998)
    features['tempo'] = features['tempo'].clip(lower=66.34576, upper=189.87784)
    features['duration_ms'] = features['duration_ms'].clip(lower=86120.0, upper=341848.79999999976)
    features['time_signature'] = features['time_signature'].clip(lower=3.0, upper=5.0)
    
    columns_to_log=['liveness', 'instrumentalness', 'acousticness', 'speechiness','loudness','energy']

    for i in columns_to_log:
        if i == 'loudness':
            features[i] = features[i] + 60
        features[i] = np.log(features[i]+1)

    #normalize the data
    scaler = pickle.load(open('scaler3.pkl', 'rb'))
    #fit on all columns except the track id
    preprocessedFeatures = scaler.transform(features)

    #convert to dictionary, with track id as key
    preprocessedFeatures = pd.DataFrame(preprocessedFeatures, columns=features.columns)

    
    #apply z-score normalization
    for i in columns_to_log:
        preprocessedFeatures[i] = stats.zscore(preprocessedFeatures[i])
        preprocessedFeatures.clip(lower=-2.7, upper=2.7, inplace=True)

    preprocessedFeatures['id'] = features.index.to_list()
    preprocessedFeatures.set_index('id', inplace=True)

#     preprocessedFeatures = preprocessedFeatures.set_index('id').T.to_dict('list')
    return preprocessedFeatures


#--------------------
# LR Functions
#--------------------

def getMoodLabelLR(songFeatures):
    if LR_model is None:
        load_LR_model()
    prediction = LR_model.predict(songFeatures.values)
    pred_probability= LR_model.predict_proba(songFeatures.values)
    return prediction, pred_probability

#--------------------
# Centroid Similarity Functions
#--------------------
valenceArousalToLabel = [
  # Low, Medium, High Arousal
  ["depressed", "sad", "angry"],    # Low Valence
  ["calm", "neutral", "energetic"], # Medium Valence
  ["content", "happy", "excited"],  # High Valence
]
# Get size label of valence and arousal
def getMoodLabelCS(songFeatures):
    pred = []
    for row in songFeatures.iterrows():
        valence = row[1][0]
        arousal = row[1][1]
        (valence_label, arousal_label) = getValenceArousalLabels(valence, arousal)
        mood = valenceArousalToLabel[valence_label][arousal_label];
        pred.append(moods.index(mood)) # other functions return as array
    return pred, [[]]

# Helper for getMoodLabelCS
def getValenceArousalLabels(valence, arousal):
    LOW = 0
    MEDIUM = 1
    HIGH = 2
    to_labeled_size = lambda val: HIGH if val >= 0.5 else LOW if val <= -0.5 else MEDIUM
    valence_label = to_labeled_size(valence)
    arousal_label = to_labeled_size(arousal)
    if valence_label == MEDIUM and arousal_label == MEDIUM:
        # Case where both are medium
        valence_label = HIGH if valence > 0.25 else LOW if valence < -0.25 else MEDIUM
        arousal_label = HIGH if arousal > 0.25 else LOW if arousal < -0.25 else MEDIUM
        # Check if they are both still medium
        if valence_label == MEDIUM and arousal_label == MEDIUM:
            valence_is_bigger_extreme = abs(valence) <= abs(arousal)
            valence_label = LOW if valence < 0 and valence_is_bigger_extreme else HIGH if valence_is_bigger_extreme else valence_label
            arousal_label = LOW if arousal < 0 and not valence_is_bigger_extreme else HIGH if not valence_is_bigger_extreme else arousal_label
    return valence_label, arousal_label

def clipAndNormalizeCS(features):
    # define the midpoint and range of the new scale
    midpoint = 0.5
    scale_range = 1
    # adjust for bias
    valence_bias = 0.5 - sum(features['valence'])/len(features)
    energy_bias = 0.5 - sum(features['energy'])/len(features)
    # rescale the "valence" column to the new scale
    features['valence'] = (features['valence'] + valence_bias - midpoint) * (2 * scale_range)
    # rescale the "energy" column to the new scale
    features['energy'] = ((features['energy'] + energy_bias - midpoint) * (2 * scale_range))
    # clip the values in the to the range of -1 to 1
    features['valence'] = features['valence'].clip(lower=-1.0, upper=1.0)
    # clip the values in the "energy" column to the range of -1 to 1
    features['energy'] = features['energy'].clip(lower=-1.0, upper=1.0)
    
    return features

#--------------------
# Retrieve Closest Songs Functions
#--------------------

def cosineSimilarity(arr1, arr2):
    return np.dot(arr1, arr2)/(norm(arr1)*norm(arr2))

# %%
id_list = songs_df["uri"].to_list()
#names = ['CS', 'MLP', 'LR', 'RF']
names = ['MLP']

# %%
(predictions, predictions_prob, track_data) = assignLabels(names, id_list)

# %%
#If the kernel crashes, recover here
print(predictions)
print("\n")
print(predictions_prob)
print("\n")
print(track_data)
# Out:
# {'MLP': {'6zTbtySCRStJOv5xA4XvRE': 6, '6cr9XbO2yAJgTNa6XNRINF': 6, '4br0nM6NdvDKMJgLj44foR': 6, '7qa14fkhxgOwWgJ2cbDTyc': 6, '11nkLTEsCUzxXLWpyuz65G': 6, '40yQjVqMx52xTlY4KFZXnh': 6, '5AciiCKJKTLKRrAPSrKQy5': 6, '7hYgGeMBarMRK5iGPqKGsb': 6, '76aMjXNa94NuHTNC0BFoH8': 6, '4ojVtI82vjDG9gBEE29YBb': 6, '7kfCTnxt6irtsSWWbFib62': 6, '7aUZ3tEkoDN8qE6Rl6TfCc': 6, '1hWZ0uScuJ6PSeoe2p4sKC': 6, '47ibywRXe3EGtaL4ZVhvzL': 6, '4oNCXU6RZG6qpVDAfZUoEh': 6, '5483XAumUCO44oXXH5lxfg': 6, '1rkxyQH6y3qxysbYKo8yyI': 6, '1a2BXMnQbjArGITwt3bMD9': 7, '4gAlANEHRk0T04OKXNc9vy': 6, '65g63lVQqRCZsqROayNak9': 6, '41ial1TTDNlhaEuzpI5SAk': 6, '0fOzbcpxqSgX5KhLwfdGyi': 6, '5iFHdi7BB0koNu8t2Ug82n': 6, '0RsUZkIIsJAXDzsDa5xz12': 6, '2p36nzolzAlLbaFAQiqfPd': 6, '5LdVyywNiR4gqPPM3yqVSR': 6, '7cEcI3DZiwBrFcF3bAeBuL': 6, '0fdn9DETYyIN4sEuSqkm1x': 6, '6f6qUsqIfRIEqHJuL6EFAn': 6, '4HXS5JIpFZmXj4yFMOv4gU': 6, '7wjaxqy8HJOMfX1qoZNdTZ': 6, '2B8K5m8XwCz2MJvahACTjD': 6, '7Cr1H2QTtm9KXobncJOkJF': 6, '1xn4V99fkCg868FBTlQSyC': 6, '3nBn6Ox2yVzTuAmi2rbo9H': 6, '7AkmShdIslE2jkJ4jHbYmd': 6, '09o3Sp5xVj63YQIoMmPHad': 6, '1AL54jGmiH5sEn7OUIbVVP': 6, '0oXl1pTqskTdXuu46tPCJm': 6, '7hwwc6qNtXxwurI2AcDg3E': 6, '34Dgd9lC0X0AQwq4L3RbvY': 6, '5vAUwAzCryz0XuR6QdGwbk': 6, '1E5wZo0royZB8p9rt7TRB8': 6, '07niZTYNkvPcw61OX0YSR6': 6, '1ScBivNTBV7KVIjumkFvFE': 6, '3S5bNdw13XmF0Zw98KtVrV': 6, '2dcOprxauIydtyWGbRY7aF': 6, '3XW2ewe1iNoBlHTYPUi39V': 6, '1vlaBhPNXdqdhdjkwV8VCv': 6, '0yVsNXZjSNO0uLhPs8pynS': 6, '3TR4OoqzX947WgOxG1d5F3': 6, '5r9fTbn6YZVxHKaU4Rze3t': 6, '2O6ok8mA213SiKlHD3yOPt': 6, '0WUmEgNPYXDCe8zwecTlYk': 6, '2MQhJVwdsmdfG5qK96tEHH': 6, '1UdPbtn1tr1fm1d0FcrgAg': 6, '41GmT2g8MpZ5F9IKbzVAc8': 7, '2g7oWQYXIurU5x2YtMAC7H': 6, '5Uj3rUYghH7vcKl5IiitWC': 6, '1t2lWnGFqsejjpEUIoziKU': 6, '7rsRqxM1uneTiTKVjcxfPv': 6, '1bUiyTithUxLGEMZ2RD8US': 6, '7AhQiikvGQzcr2Kpb74fLG': 6, '4Bl2bWpteL5TFmqQ22IQXp': 7, '6lCPEra6l4YkPkXVZeFqeT': 6, '7zVTz5fDa8AfRfGdnXou3m': 6, '7IbbjapJhOwteSxyMjWOLB': 6, '0MeFxDLrLaw3n0sSjIXYvn': 6, '6opcJWSYfidSOyn8bQlTlK': 6, '5UZdpqf1F4fvDqvGYC2sRt': 6, '0sm2PC8NP8L0J2sxPJwKvA': 6, '433T7mnFe3pkrTZfnYtq7A': 6, '0jgfH1TWoXIC0Qk5x0Uerw': 6, '4mQEVCbtbQuiOYouVR0fcs': 7, '2o41jDa4T0QKF9804tqyka': 6, '3YTZyDywwVOWOXw2d970Dx': 6, '0acEauszFAvCGw9cNF0kZM': 6, '0Mjbx4mfOH02A9xmUE3F40': 6, '02Nyn3a2nHssi9rNg3jkdL': 6, '7GuN1Fddm0hCfppgIDUArP': 6, '2ZSCtZBMhLuINrMNF23v2e': 6, '5NFybpngup7caMPSMiJ5ZO': 6, '3xXQCt1vfzNEOndrrNWAZR': 7, '2dwLTY84vCeubyM0jM0nXH': 6, '3kKwXt8TAU7wMCPIPCrzkI': 6, '23sRVWvfwWdagkqC95eS6n': 6, '1chT7Yo3zSvjFPRQ20fWFH': 6, '5iR4ziuzYZO1VondRmrvsc': 6, '4YhxXaf6Qrn5DrmgEfhwLH': 6, '09LGPIStoVjhEWYV5PG9M6': 6, '580SKYBPZ2vQQRcQogBF9N': 6, '3hPRkKFO5mIflYwDjicJ4U': 6, '794SxkpLERVaBoag5946LG': 6, '6xcD8EbsvMep9ULtidHI2j': 6, '4RQFT3aZPjhuafwXNUnL6x': 6, '7Dxb8siYBoC5rZRPTmhob4': 6, '0Y12GuKnIa7ObO8s6E0D9X': 6, '6GgnlnCWIw7QsIBFewAnuE': 6, '4tfaUHGYBCMliBaOHM5vHX': 6, '0gDMSJ8JtTjnAnROaM4L9w': 6, '1c3QWfGAadGw4ywwmLx5ju': 6, '5kukWcGnSNpw8YGy1JV8zu': 6, '5bUMUrnrWr29gSRy7UgUOO': 6, '5FGMMbjDUWrfwyP1w2ac0K': 6, '43qHoXJIYjMwJsRNTj9V98': 6, '745ZrIG7sLyZniaQBAgIdg': 6, '5PEzT7NREhifSvdJLkw2Ej': 6, '6sV8mjqZTDnZA5qMz5RtwF': 6, '2bMSh7BYTXtL5h3dGJlfl7': 6, '6obsAYZi05zj2412g9UsGJ': 6, '05FuhMHmo0gi65Sotwj01c': 6, '60xGrKFHgLNpqhuS00HINp': 6, '28fBoIuzvYI6uQExWj9DbN': 6, '5ubuyElg33ARspfgM0z2yt': 6, '1m1G0nm9tWDY8Jr3T1Dzi4': 6, '5SSvRUwuAGPz7vDEIcq4LA': 6, '0BYqfF118BfjcxvQRCwaWk': 6, '6DjuB3ja8UvTVIrbLP7pSr': 6, '6fE5kgw2HR8AxQGqA3e2Gu': 6, '1eEHpyWT5AOAFbgqAGSMns': 6, '41niA9BIBT3GBJODEWicuP': 6, '1Tqt1u2aFYDBCMxxJRiM0f': 6, '3vROTGlX31Rem9VaTqdBzS': 6, '0yS587osB0zPG0JB01roTg': 6, '0AOz0XTa8sCskJQlBtHfHG': 6, '1IKTSaVFGdnkbWkzSJPveE': 6, '6ZB05VtNtULcsYIwAzAYjS': 6, '0SdF87pVzhydKwygD13H6B': 6, '4lcT08ARvK8cVjRLJbnKLh': 6, '6zUDEI1myhSL5mAHRlKrIo': 7, '1ubCPXu6jZQJfttzO9APUB': 6, '7wH5Ck2MRPWwwunLeMjg9f': 6, '0lWWho4vGcKfIX8kA8YmAy': 6, '3aQlVIegX4nPS2igYBFllB': 6, '2yR2KTxdGPqpk8krap1Bbl': 6, '4BLroGG5pTJwGui3vurqql': 6, '1rpHkU5rHv0aPQwD65Ld1y': 6, '2kRzlPRExNaBBsIAN ...
#
#
# {'MLP': {'6zTbtySCRStJOv5xA4XvRE': [0.0021865380937227097, 0.00024074876633267518, 6.616574489084878e-05, 5.228213200766648e-05, 0.03728097031735454, 0.04846628534723256, 0.7425768391854524, 0.1691301704130065], '6cr9XbO2yAJgTNa6XNRINF': [0.0021865380937227097, 0.00024074876633267518, 6.616574489084878e-05, 5.228213200766648e-05, 0.03728097031735454, 0.04846628534723256, 0.7425768391854524, 0.1691301704130065], '4br0nM6NdvDKMJgLj44foR': [0.0021865380937227097, 0.00024074876633267518, 6.616574489084878e-05, 5.228213200766648e-05, 0.03728097031735454, 0.04846628534723256, 0.7425768391854524, 0.1691301704130065], '7qa14fkhxgOwWgJ2cbDTyc': [0.0021865380937227097, 0.00024074876633267518, 6.616574489084878e-05, 5.228213200766648e-05, 0.03728097031735454, 0.04846628534723256, 0.7425768391854524, 0.1691301704130065], '11nkLTEsCUzxXLWpyuz65G': [0.0021865380937227097, 0.00024074876633267518, 6.616574489084878e-05, 5.228213200766648e-05, 0.03728097031735454, 0.04846628534723256, 0.7425768391854524, 0.1691301704130065], '40yQjVqMx52xTlY4KFZXnh': [0.0021865380937227097, 0.00024074876633267518, 6.616574489084878e-05, 5.228213200766648e-05, 0.03728097031735454, 0.04846628534723256, 0.7425768391854524, 0.1691301704130065], '5AciiCKJKTLKRrAPSrKQy5': [0.0021865380937227097, 0.00024074876633267518, 6.616574489084878e-05, 5.228213200766648e-05, 0.03728097031735454, 0.04846628534723256, 0.7425768391854524, 0.1691301704130065], '7hYgGeMBarMRK5iGPqKGsb': [0.0021865380937227097, 0.00024074876633267518, 6.616574489084878e-05, 5.228213200766648e-05, 0.03728097031735454, 0.04846628534723256, 0.7425768391854524, 0.1691301704130065], '76aMjXNa94NuHTNC0BFoH8': [0.0021865380937227097, 0.00024074876633267518, 6.616574489084878e-05, 5.228213200766648e-05, 0.03728097031735454, 0.04846628534723256, 0.7425768391854524, 0.1691301704130065], '4ojVtI82vjDG9gBEE29YBb': [0.0021865380937227097, 0.00024074876633267518, 6.616574489084878e-05, 5.228213200766648e-05, 0.03728097031735454, 0.04846628534723256, 0.7425768391854524, 0.1691301704130065], '7kfCTnxt6irtsSWWbFib62': [0.0021865380937227097, 0.00024074876633267518, 6.616574489084878e-05, 5.228213200766648e-05, 0.03728097031735454, 0.04846628534723256, 0.7425768391854524, 0.1691301704130065], '7aUZ3tEkoDN8qE6Rl6TfCc': [0.0021865380937227097, 0.00024074876633267518, 6.616574489084878e-05, 5.228213200766648e-05, 0.03728097031735454, 0.04846628534723256, 0.7425768391854524, 0.1691301704130065], '1hWZ0uScuJ6PSeoe2p4sKC': [0.0021865380937227097, 0.00024074876633267518, 6.616574489084878e-05, 5.228213200766648e-05, 0.03728097031735454, 0.04846628534723256, 0.7425768391854524, 0.1691301704130065], '47ibywRXe3EGtaL4ZVhvzL': [0.0021865380937227097, 0.00024074876633267518, 6.616574489084878e-05, 5.228213200766648e-05, 0.03728097031735454, 0.04846628534723256, 0.7425768391854524, 0.1691301704130065], '4oNCXU6RZG6qpVDAfZUoEh': [0.0021865380937227097, 0.00024074876633267518, 6.616574489084878e-05, 5.228213200766648e-05, 0.03728097031735454, 0.04846628534723256, 0.7425768391854524, 0.1691301704130065], '5483XAumUCO44oXXH5lxfg': [0.0021865380937227097, 0.00024074876633267518, 6.616574489084878e-05, 5.228213200766648e-05, 0.03728097031735454, 0.04846628534723256, 0.7425768391854524, 0.1691301704130065], '1rkxyQH6y3qxysbYKo8yyI': [0.0021865380937227097, 0.00024074876633267518, 6.616574489084878e-05, 5.228213200766648e-05, 0.03728097031735454, 0.04846628534723256, 0.7425768391854524, 0.1691301704130065], '1a2BXMnQbjArGITwt3bMD9': [0.0021865380937227097, 0.00024074876633267518, 6.616574489084878e-05, 5.228213200766648e-05, 0.03728097031735454, 0.04846628534723256, 0.7425768391854524, 0.1691301704130065], '4gAlANEHRk0T04OKXNc9vy': [0.0021865380937227097, 0.00024074876633267518, 6.616574489084878e-05, 5.228213200766648e-05, 0.03728097031735454, 0.04846628534723256, 0.7425768391854524, 0.1691301704130065], '65g63lVQqRCZsqROayNak9': [0.0021865380937227097, 0.00024074876633267518, 6.616574489084878e-05, 5.228213200766648e-05, 0.037280970317 ...
#
#
# {'MLP': {'6zTbtySCRStJOv5xA4XvRE': [0.577, 0.06961934188005706, 2.0, 3.638296433737858, 1.0, 0.03120792712419322, 0.6836017677164138, 0.6408007001877362, 0.10526051065749294, 0.242, 73.998, 151917.0, 4.0], '6cr9XbO2yAJgTNa6XNRINF': [0.467, 0.21752781252857398, 11.0, 3.6497747342331754, 1.0, 0.032660782239548276, 0.6108519378331152, 0.6662897263900627, 0.10885440491208208, 0.0541, 75.031, 158000.0, 4.0], '4br0nM6NdvDKMJgLj44foR': [0.442, 0.10616019582839073, 2.0, 3.7450943674416712, 1.0, 0.04066198171888972, 0.6856189141391537, 0.6518042170255629, 0.10526051065749294, 0.111, 112.206, 126986.0, 5.0], '7qa14fkhxgOwWgJ2cbDTyc': [0.509, 0.1922718876471227, 6.0, 3.6285454150742367, 1.0, 0.030044121348376644, 0.6113946786876863, 0.6168059473032227, 0.10526051065749294, 0.0711, 84.0, 143500.0, 4.0], '11nkLTEsCUzxXLWpyuz65G': [0.346, 0.05002749359964807, 7.0, 3.700610376989635, 1.0, 0.042292912190251365, 0.669878553620591, 0.6392188385343897, 0.09984533496971612, 0.058, 129.445, 183500.0, 3.0], '40yQjVqMx52xTlY4KFZXnh': [0.378, 0.09285261701461633, 3.0, 3.696351468952637, 1.0, 0.04094998632895417, 0.6703901934373291, 0.6626879730752367, 0.10885440491208208, 0.0564, 118.209, 154992.0, 3.0], '5AciiCKJKTLKRrAPSrKQy5': [0.529, 0.1939206926373065, 6.0, 3.731268220605723, 1.0, 0.03101405352916954, 0.5877866649021191, 0.645531326618282, 0.10345870836822997, 0.0903, 124.069, 149000.0, 4.0], '7hYgGeMBarMRK5iGPqKGsb': [0.437, 0.17311261770864483, 9.0, 3.9075932083487603, 0.0, 0.02829586915484725, 0.39136618372866283, 0.5411608235620636, 0.11154137473290732, 0.13, 71.407, 105957.0, 4.0], '76aMjXNa94NuHTNC0BFoH8': [0.513, 0.06259914175651995, 0.0, 3.677034579746013, 1.0, 0.034594644764498965, 0.6749832099322741, 0.6032224730319582, 0.09230567078402614, 0.135, 74.906, 169567.0, 4.0], '4ojVtI82vjDG9gBEE29YBb': [0.614, 0.10345870836822997, 11.0, 3.7545969674669673, 0.0, 0.04602443831127925, 0.6486726904581158, 0.6444820085786643, 0.10436001532424286, 0.158, 148.072, 165459.0, 4.0], '7kfCTnxt6irtsSWWbFib62': [0.575, 0.058740495022600085, 1.0, 3.7304771477018637, 0.0, 0.062411260121397076, 0.6861225656229808, 0.6544063522435147, 0.09893994785490365, 0.267, 146.405, 107906.0, 3.0], '7aUZ3tEkoDN8qE6Rl6TfCc': [0.452, 0.04644073976537144, 11.0, 3.6216172270547684, 0.0, 0.03912455468405008, 0.647626665258136, 0.6512829764612466, 0.11243542932978817, 0.0507, 78.082, 140525.0, 4.0], '1hWZ0uScuJ6PSeoe2p4sKC': [0.621, 0.1275133202989597, 9.0, 3.5929994119689064, 0.0, 0.038836023785198216, 0.620038708739307, 0.6450068052320105, 0.10526051065749294, 0.131, 140.068, 132500.0, 4.0], '47ibywRXe3EGtaL4ZVhvzL': [0.594, 0.09339926425854976, 2.0, 3.7860515358661955, 1.0, 0.037199440989106304, 0.6820862332005203, 0.6580380034463774, 0.10616019582839073, 0.191, 133.627, 192592.0, 4.0], '4oNCXU6RZG6qpVDAfZUoEh': [0.617, 0.11955923505763925, 11.0, 3.777325218544523, 0.0, 0.03787365242808149, 0.6709015716126255, 0.5347374438123035, 0.10526051065749294, 0.198, 116.099, 128000.0, 4.0], '5483XAumUCO44oXXH5lxfg': [0.653, 0.12575120530556025, 4.0, 3.7206929940762516, 1.0, 0.060153922819747144, 0.6075892921982986, 0.6291418505840328, 0.0869113719892964, 0.0937, 120.033, 157681.0, 4.0], '1rkxyQH6y3qxysbYKo8yyI': [0.542, 0.10074990310014315, 0.0, 3.709294638856529, 1.0, 0.03816246109434886, 0.6703901934373291, 0.6662897263900627, 0.07807153542015544, 0.141, 67.994, 178599.0, 5.0], '1a2BXMnQbjArGITwt3bMD9': [0.591, 0.09066303489724215, 6.0, 3.813130416451793, 0.0, 0.04516455195437366, 0.676509539406922, 0.6429059641231987, 0.0980337402713654, 0.146, 136.406, 121765.0, 5.0], '4gAlANEHRk0T04OKXNc9vy': [0.392, 0.1773090149704103, 5.0, 3.801850932773098, 0.0, 0.03343477608623742, 0.6830968447064438, 0.6471032420585385, 0.11154137473290732, 0.179, 108.663, 182434.0, 4.0], '65g63lVQqRCZsqROayNak9': [0.646, 0.142367241286922, 5.0, 3.694463832407837, 1.0, 0.03556017539855088, 0.6657759837638133, 0.5993858007454709, 0.1881379421153945, 0.124, 92.699, 165724.0, 4.0], '41ial1TTDNlhaEuzpI5SAk':  ...

# %%
model_centroids = assignCentroids(names, predictions, track_data)
model_centroids
# Out:
# {'MLP': {'sad': {'danceability': 0.6526646554934828,
#    'energy': 0.4543480276999508,
#    'key': 4.774674115456238,
#    'loudness': 4.00146375432672,
#    'mode': 0.6145251396648045,
#    'speechiness': 0.13192325476031344,
#    'acousticness': 0.308542328527738,
#    'instrumentalness': 0.0008307691308665213,
#    'liveness': 0.14941126933801185,
#    'valence': 0.45485608938547445,
#    'tempo': 122.599971471136,
#    'duration_ms': 228895.9657355679,
#    'time_signature': 3.9608938547486034},
#   'angry': {'danceability': 0.6965556313993178,
#    'energy': 0.5082741172973747,
#    'key': 5.117747440273037,
#    'loudness': 3.9920900785967475,
#    'mode': 0.6689419795221843,
#    'speechiness': 0.25113548856164697,
#    'acousticness': 0.11033348977495892,
#    'instrumentalness': 0.005360688916530242,
#    'liveness': 0.18738041512376,
#    'valence': 0.46667412627986316,
#    'tempo': 122.8781280546075,
#    'duration_ms': 154407.9180887372,
#    'time_signature': 4.015358361774744},
#   'energetic': {'danceability': 0.6665794285714283,
#    'energy': 0.5858643533217059,
#    'key': 5.303296703296703,
#    'loudness': 4.0368059039689435,
#    'mode': 0.44395604395604393,
#    'speechiness': 0.14087972860114786,
#    'acousticness': 0.07368325613805132,
#    'instrumentalness': 0.04835053221027273,
#    'liveness': 0.17374706330365877,
#    'valence': 0.44572105054945055,
#    'tempo': 133.8632339340659,
#    'duration_ms': 192700.42153846152,
#    'time_signature': 4.0},
#   'excited': {'danceability': 0.8060215449202346,
#    'energy': 0.45587927376953236,
#    'key': 4.950461796809404,
#    'loudness': 3.993519469254694,
#    'mode': 0.5491183879093199,
#    'speechiness': 0.2053920427659463,
#    'acousticness': 0.09343306920944847,
#    'instrumentalness': 0.002259190347702067,
#    'liveness': 0.14948424717801967,
#    'valence': 0.4537083912678422,
#    'tempo': 128.7186248194792,
#    'duration_ms': 207485.07388748956,
#    'time_signature': 3.99664147774979},
#   'happy': {'danceability': 0.7257194949494947,
#    'energy': 0.5185572725968336,
#    'key': 5.608585858585859,
#    'loudness': 4.0035171029992185,
#    'mode': 0.5883838383838385,
#    'speechiness': 0.07715150121587021,
#    'acousticness': 0.12597313135021204,
#    'instrumentalness': 0.0008145050430619393,
#    'liveness': 0.18460889708547548,
#    'valence': 0.5936972222222222,
#    'tempo': 109.8164671717173,
#    'duration_ms': 182221.33585858587,
#    'time_signature': 4.0},
#   'content': {'danceability': 0.6398094840294838,
#    'energy': 0.42771731225600984,
#    'key': 5.479115479115479,
#    'loudness': 3.943573980746392,
#    'mode': 0.5184275184275184,
#    'speechiness': 0.15293556553581347,
#    'acousticness': 0.34837723672198434,
#    'instrumentalness': 0.07215442441673899,
#    'liveness': 0.16740043988390663,
#    'valence': 0.39144190663390627,
#    'tempo': 106.57454918918916,
#    'duration_ms': 197597.4943488943,
#    'time_signature': 3.9312039312039313},
#   'calm': {'danceability': 0.5565078955954323,
#    'energy': 0.20930238972741738,
#    'key': 5.278955954323002,
#    'loudness': 3.8170819864483017,
#    'mode': 0.47308319738988586,
#    'speechiness': 0.06746760388523741,
#    'acousticness': 0.5307459084670799,
#    'instrumentalness': 0.5377157144800094,
#    'liveness': 0.11480907725915708,
#    'valence': 0.28661814681892345,
#    'tempo': 103.28341135399674,
#    'duration_ms': 158546.02055464924,
#    'time_signature': 3.9168026101141926},
#   'depressed': {'danceability': 0.6207361803713535,
#    'energy': 0.4018906684758154,
#    'key': 6.3978779840848805,
#    'loudness': 3.9468689044043797,
#    'mode': 0.1883289124668435,
#    'speechiness': 0.18363184795166956,
#    'acousticness': 0.2374672461184736,
#    'instrumentalness': 0.0348315717005967,
#    'liveness': 0.140325068920971,
#    'valence': 0.334732721485411,
#    'tempo': 115.95461114058361,
#    'duration_ms': 200292.69230769222,
#    'time_signature': 4.039787798408488}}}

# %%
model_closest_songs = closestSongs(names, track_data, predictions, model_centroids)
model_closest_songs
# Out:
# {'MLP': {'sad': ['1CS7Sd1u5tWkstBhpssyjP',
#    '1fewSx2d5KIZ04wsooEBOz',
#    '5gub2bpJRgJP4m4MliqtdV',
#    '21WvAGxPUNJARcZoSqswd7',
#    '1jNyxG5S2P9gztbfAnrq85',
#    '3J5YrOvX2A0EA0j4BARQ9o',
#    '1pJsmr01tzKnFfjeCvzcdc',
#    '66aH9gXNBfTJUikVIZfzcA',
#    '6kl1qtQXQsFiIWRBK24Cfp',
#    '4dabR8urAgTIeEnq4SZZ8c',
#    '4ZT9FnbFu1PaBfV3itxiqT',
#    '1wAY6QsHpCJB7GaokxnPfW',
#    '1q4dAKCLDH4R6DBsB3rWDi',
#    '1HpAxf0kdqZSAisutLE5CW',
#    '1RHfHzmBrFEvmi4yRRlMiA',
#    '6u2nIkfg2qRm0EMkneSJfC',
#    '14nAQy3fHVzDb7LKxpS7Ld',
#    '4qiVh3U2Qgd5RPOWjZcbLU',
#    '5wGohqHx0ATkWkwYK8UcLS',
#    '50HxGXwYa2AQOevMh5O6ef',
#    '3QzAOrNlsabgbMwlZt7TAY',
#    '76OSY26fhv9aJ0WZTezF34',
#    '0L7sIDOLgR5COZ0iCncKNb',
#    '5tnNHmykSmF7Nam6aenBVf',
#    '3ZhTT6yjZwpPph5MIJ53XY',
#    '5WnfnSpuNEGXyEt78PBA6d',
#    '5bvnqVuq7UFl0txSlHpsfS',
#    '2ZbvTTHaZIYu9XhnRO44mr',
#    '4ja2gzrNh9VNigzoXfmbwD',
#    '2I8VTVp4LmA7Z4qZs9umOO',
#    '7uiBocndm12aKbsdnQ3Scx',
#    '7p4vHnYXkxlzvfePJVpcTr',
#    '2yUbCEiaolfSMluDo9RMmG',
#    '1BuZAIO8WZpavWVbbq3Lci',
#    '3lIrS1SvOVltil2O4DzrCJ',
#    '4qS2KPWvsQzLvRa9oCHw41',
#    '4oM9DGUTrRaXJDypxxHztZ',
#    '6Nle9hKrkL1wQpwNfEkxjh',
#    '0ESJlaM8CE1jRWaNtwSNj8',
#    '0Ev562zA4pmUsBqjxsxxdx',
#    '3TpBefRZ1vFcOH6z57PQRI',
#    '05aZ9sAU1YXndHv0FMi9iW',
#    '6NGTpYB4rGZT41FuIjCkGC',
#    '2NAZcL9tLUkdMMb5v3xFVG',
#    '6Ksu6my1tJEV5QoVzAlqTi',
#    '5ffntNJnJOeFv7b7DCd0Bw',
#    '2LNMhZ3YijTO7USmqjgJfG',
#    '0UgavZ34yLBu8LtA6Bwxch',
#    '6bkSgfytOXAt8KvtAxLfe1',
#    '18uwL0vNUanqZH0ro2QcOP',
#    '0ErItBOhcHJahcQ8BGqk4V',
#    '4hxfqUojJ5u9SyAjiXevmy',
#    '17uivGWu6kfAvH6UgR7j4x',
#    '34I0nBvoE0ZXmqbKiJ5BWS',
#    '2iu60eTIm2py6MaoVMcBAR',
#    '4uX8Wh4wxpLne11BhoHs5x',
#    '1mea3bSkSGXuIRvnydlB5b',
#    '0WYbdsLQeIyKaExGoY4zS5',
#    '7tjnncMvoO6DRAk4nUdyiL',
#    '6TkwBmyNs21ihKTi8Bp0eo',
#    '6AsyKu2Ia2lKJC07JanSw8',
#    '2l7p9PD6a3EtenMS7lpnkA',
#    '0stCJMrBXd0a8apHTFpMhu',
#    '6m6Oy3F6GG0zRwH03rWmTv',
#    '3nAq2hCr1oWsIU54tS98pL',
#    '5CE0V7z1ePOZQNJNpWxYGA',
#    '4h8VwCb1MTGoLKueQ1WgbD',
#    '0nrRP2bk19rLc0orkWPQk2',
#    '3KkXRkHbMCARz0aVfEt68P',
#    '5kqIPrATaCc2LqxVWzQGbk',
#    '5SeX6wQeUsYKNnuQno9slB',
#    '0H8XeaJunhvpBdBFIYi6Sh',
#    '5sCwso3aURYAdieWEFI1nE',
#    '71hZRkkUaEMEKGVbHCGiby',
#    '0RiRZpuVRbi7oqRdSMwhQY',
#    '39xaGZ9mbU8Coujwffsio6',
#    '0A7ekpPTnu4VpqMNy3LJ1r',
#    '5kcOXucLoFtzDYXf6uI30N',
#    '3nPxnMPQG3J8ndJqAetZya',
#    '1keIwLlHg0VZhoQQiTb0Xi',
#    '5zXmmhtXrhDbYnScaYpqZg',
#    '5wWMdkPkZbtUgrkaDINRrt',
#    '57QievAWQ13DWl20Obiz8E',
#    '6ILasKSnspGyJ5plgJTXlG',
#    '7m7sXV4UgUbq3GgPKu2Ryr',
#    '2YaDRtIlQiZ5WDDB2YuEOC',
#    '2lHGDjzDAGqVkbGMnkgvyG',
#    '26OhjtaTamFocE08t83ml6',
#    '7IHOIqZUUInxjVkko181PB',
#    '0T5iIrXA4p5GsubkhuBIKV',
#    '4E3qImtJzRqLt8ZZyLceOE',
#    '6OxmohmJM5TUxKVYVKAIYV',
#    '4ccv9Mfcsc3MpaSi9h9tH6',
#    '32xx0fAv3CIeGmNaWTHvEF',
#    '43mwjiAXLMqkOv4vtlNweU',
#    '4TIqzdAssasqx3DAe6cG9J',
#    '4uOopYeRmPFd3taXfzEGP5',
#    '61S79KIVA4I9FXbnsylEHT',
#    '3JVTsvTldB6arHVlmxmTnM',
#    '1DbeslBYnckTqqTcc1Y2Tg',
#    '0uFvvXbmGIXlf5ZgtHyYpf',
#    '00B7TZ0Xawar6NZ00JFomN',
#    '0BKuCr5M2nggLQnUjllayK',
#    '2scmPxlPxRZeXs39SgAw7n',
#    '7kgKHe6ZxLEg83y4LiQvB5',
#    '5m0eMnsWwzgGsUxe1mhFYR',
#    '6mxz6tKfJw2RvzdowwDELj',
#    '6Zc5f20q7sOe1IC1c1jQvZ',
#    '41uX0L4bro4KfKtDIIEFFe',
#    '2C6WXnmZ66tHhHlnvwePiK',
#    '59PYPDxTbqJpiGfyogPb5h',
#    '2IRZnDFmlqMuOrYOLnZZyc',
#    '3UAHDzPUkArViD5ZZcRPNY',
#    '5CRkUL8PwtIbYCUjXUkZCh',
#    '2HYvkdq6lpFXkVz9Tfqi8r',
#    '2kuYZZvjwzYWPA8L7ICFXn',
#    '0Aa3g9EQoPNt6PiKjaUeb7',
#    '4AO1XhrgJczQ9bNVxdfKQe',
#    '0YHWj5wYTjbENOi7cWGSpK',
#    '76pUKeKLQuxjFFfbXJ5dif',
#    '3i6sCTU7ENlnHpHvrHUitW',
#    '5TR3sdi4QH0qwIsZ6CqJa3',
#    '6U0FIYXCQ3TGrk4tFpLrEA',
#    '2KvHC9z14GSl4YpkNMX384',
#    '4KyCV8JfbknCNM9MqiuKMv',
#    '410ZZP746AQeiywhKvXWCo',
#    '13ZyrkCDmRz5xY3seuAWYk',
#    '4TWflhgevIGo448fWc6mQq',
#    '2MJdgSby3DtSS7bUJx2cly',
#    '6p8NuHm8uCGnn2Dtbtf7zE',
#    '3AALcuKu2uN5VChEChnD7v',
#    '44Gmc28OqMon8yhJfo3Nze',
#    '0fABHG5a7RnqBlOKOwhWZD',
#    '2OsDoAzo5SGq10qwmKSQBv',
#    '3ovxoxGOrctXFXhDECSNBL',
#    '1JKcdDCv8Yk39VRWMxx8Lj',
#    '3Adr6spLsf2Fxn90fr7u3z',
#    '4aSEMyeOX4bORHIRToPcy0',
#    '5bgwqaRSS3M8WHWruHgSL5',
#    '3EApebexZ7YqDIqw2EMTDh',
#    '3A4cpTBPaIQdtPFb5JxtaX',
#    '2QC2PTvF3yONXlvih301aR',
#    '5p1QEUGcMihZLQ8dMUsAWu',
#    '4Tuk8IBQED9II2uAzN6HJm',
#    '1tAutlhI9FwnKn7fVgmd5P',
#    '7mVHy2E0yV3oTnV0OR5uMf',
#    '7BlBVFwvbWvcwNcUarQmjk',
#    '6UHn3RCz0gFk8elCDzhLDZ',
#    '2pg2TiYo9Rb8KeB5JjP7jS',
#    '1f5cbQtDrykjarZVrShaDI',
#    '3LnOF5n1GOs01siYZXzS3p',
#    '0CYLDwvvpJQySLA5CvqvSl',
#    '4paAidoE8VAemwU4jgCc6l',
#    '2jBQmxZpQxF8jJfEdjJ9Qv',
#    '4xRxYWgAtL6pzRz94GlZlA',
#    '6xTU6B6nFwKKTSZ9ySXS80',
#    '0RySKi4j0iW5yS116alcba',
#    '45WkcBtgPS8xulUwEg63X1',
#    '45wselE9lcQ48i2GbAETWx',
#    '12GEpg2XOPyqk03JZEZnJs',
#    '75gbML78pDH3T5dvgQCjCe',
#    '4S2uhQE8L9V6p7rj7SiauJ',
#    '6gpcs5eMhJwax4mIfKDYQk',
#    '5X4XAB4dagwoPgAeFy4OyW',
#    '5BQrp63SHCVf4bzCzJePne',
#    '7vkL4wrBEmzr1wsiWRd1zO',
#    '6h4WLS1E83VT3vplRJgroK',
#    '3FAJ6O0NOHQV8Mc5Ri6ENp',
#    '3yMC1KsTwh0ceXdIe4QQAQ',
#    '3Kwdm0iLyEiRB8InsZoo6n',
#    '35ieKju5aLWFN5UgfJ27mL',
#    '3ee8Jmje8o58CHK66QrVC2',
#    '6HilF8XGjLdLIZa51AVFux',
#    '3fx31TjnwvwZIyAGHhOhA1',
#    '3U4isOIWM3VvDubwSI3y7a',
#    '22DKsoYFV5npPXmnPpXL7i',
#    '1Ci4wASMY4xtKVMeHA6Sd5',
#    '6Tb8Fse6LfJ0CRZVlNjHF5',
#    '15qKrPi4Kg0z7g9HlwWyeb',
#    '359krpyCKcFF8SFvqWES9L',
#    '1xYpVRspgaLxdJLOTQkTjg',
#    '2AGUFka8kBWCM47h5uTlDb',
#    '5quFr5s5PXYfUX5jV2EBZ1',
#    '7dt6x5M1jzdTEt8oCbisTK',
#    '06C4MfPcn73OF4g7s8Blek',
#    '7rXfgg6jbK89XINlgcB8cu',
#    '09ZvDOJkKi76sig28txpQn',
#    '7qMRmcVM1ki7z6YgiPmXrU',
#    '59nOXPmaKlBfGMDeOVGrIK',
#    '3v0BS42izsEA46fZogGWrS',
#    '7wrDRQgHlvDnimrRHfQZxt',
#    '65NwOZqoXny4JxqAPlfxRF',
#    '6r027Faonff84hxFMjMbIH',
#    '5bHYMuK6lJ4wAX0tM6Wlpa',
#    '63SF10lPoWA71bDYYzxfUs',
#    '2YK01AIIWuywG24gsbuizE',
#    '5GDtkgG9T1BDknHHyDtghv',
#    '6foY66mWZN0pSRjZ408c00',
#    '7FoaeFKnjoWU1fhASVwgfp',
#    '2Zy7XVdxyZQB8xp5xbpJdl',
#    '3BUWNzPWz2mDbptZmGEXpB',
#    '4jtyUzZm9WLc2AdaJ1dso7',
#    '6LkawpJyy0TZJ6Z41gMVyy',
#    '6LxSe8YmdPxy095Ux6znaQ',
#    '7oh4w9MTAb25HD7Fo52mO8',
#    '1Faq8G2y56A8fRv7HsLq25',
#    '20MuVazoNMv6xjKPnRFOxG',
#    '2CRHhpa7R4ADEHseme3BfJ',
#    '7gHs73wELdeycvS48JfIos',
#    '7iFtAyU9ATc7GwBntnGmJv',
#    '2VfMFlfRbk2BAQ9sBZALg3',
#    '6EuE9M1viu9gkdFSafia9o',
#    '6m49tZii9UUttOgDozxjI1',
#    '3PAptX72PPmjj1Igms0zjo',
#    '7BKUWh5sdtdS17crohRe4L',
#    '4H7WNRErSbONkM06blBoGc',
#    '6vWEAOUSxohKxhp0K1BsxL',
#    '6iIgdvJREEhUmLz9wJnMlw',
#    '6IaieqiCVvsNvEt6Y7yOFa',
#    '1kaxyXcAi5ZHF3Q94QXsHK',
#    '0K2UmT0JOcEaLssWda2703',
#    '5SzhkC3NGjcIq6Brs8pSj1',
#    '5maiP9UMnTSgoxPX8X3bdz',
#    '3mDaCneJoPlAexIC7cXCFV',
#    '0Ddk8Ha9xW6332fYrMVtTa',
#    '0mBP9X2gPCuapvpZ7TGDk3',
#    '4CANqU20rw8PXzYvocPzp7',
#    '4XiGKQqbmnMVxDzUj6j3f2',
#    '1L4MQJhKyrw0XiF0n0C2hL',
#    '3HPygYwlZeehBTDZXMhsrR',
#    '5YCbupYkaAOpNpWTVK7uXZ',
#    '0J6I0Zgrh5LkwgUx9zJ21h',
#    '5LG9XvX0mtdAVvjS2dpVji',
#    '40KuvsFD0zpUFuCcmt5Xm0',
#    '5O99fLa7gqlYfVGfPXZWq7',
#    '0SuLAslEMFZAXf0SwY7syi',
#    '1KVczjazCcCCgM3gXXUl47',
#    '5YAP8zpqj1eIX88makBjDe',
#    '6OyDjQiFgIX4JnnfQ9zYf8',
#    '70hDklZStSazrExPjHJPfR',
#    '2fKsU9ECE0rDjRoHop2ba2',
#    '50phRe11Y2nC2N968jVU53',
#    '2rGgIteiX209jWcsbS1MXq',
#    '7qiZfU4dY1lWllzX7mPBI3',
#    '4axYWgXASdsCBHuwInAubT',
#    '07VJGBnywGutMZ72kRyEop',
#    '4cxMGhkinTocPSVVKWIw0d',
#    '7kKOQeNAFSHTihMD3jj1l6',
#    '6MjNilJCVKJq0LfFvo5jWJ',
#    '4dH71jhtwivDcv0nSzzxkM',
#    '3OKjDHmSJVKOn6V4hCR8bq',
#    '1bx4Jw8A7GQtImIQGccI6D',
#    '3rOxgWzyypJIRFCDZHLFIS',
#    '6Hj9jySrnFppAI0sEMCZpJ',
#    '2nBI3iWLhupR7LyAJ5GGkE',
#    '4iRiKeQRGO5etc9rBughYn',
#    '1AH60dMaEfNjzDoUIFwIQi',
#    '4SZepBIPDRwPaHIjAKwRDb',
#    '2yNCD3Hs8j30hVZoH6rD3n',
#    '161DnLWsx1i3u1JT05lzqU',
#    '2hIFuoXhzcZGvmdtSE35lc',
#    '1nO2NjuFkGaAWcMdJ1pNrp',
#    '6mapJIPnQ23RTAevUoE0DL',
#    '6SPYOjTjqvidDI24Hy9lwX',
#    '39Bq9cOTO0H8M6P9iKLVdq',
#    '0TCnOEVeLQMXOUrpPlM7uY',
#    '6sTDhYVVXU3HSDuG7mBLRU',
#    '3DbBgbnDUOml329rAp2Tbr',
#    '2At0XB6Jq68CBQLKvdRP6m',
#    '2c44NyHXDy1lIfuoSOufVi',
#    '5Pgq1Gfeth2CuUhyCXwlfC',
#    '4pJ2Mrjfv3Y33P1BLHLg3h',
#    '0NaNbWaGY87JEfdgB3bf1B',
#    '2Gnsof1hvZzjE1xdLRpjtf',
#    '4YYAKYdNI2PgOItxRVmIIB',
#    '2Qr5PWUt8XycAAv338LicY',
#    '1sX7O0JfNVLrsKeLit5p65',
#    '63wxAGw6zp0Y2EcXQNUrJj',
#    '6EW1fwOk4JHmTZKINZsyjB',
#    '15eJjGIuCDEtF6ph4Hd3eR',
#    '7BKLCZ1jbUBVqRi2FVlTVw',
#    '4RcoN0Mr5EfezJqpkQc1z0',
#    '6tfEKQWSonINLZgXEQ9aRK',
#    '7w2R9UtQzGu891Vuqh7w7Y',
#    '2m3G4SXZiJEOvqf3s0s9d8',
#    '5AnVuHLmgipXkFmBvj2Q6H',
#    '1BECwm5qkaBwlbfo4kpYx8',
#    '6pyM30WDpG70VTfwoQg4m2',
#    '5wabVKcJepqDkkthpTGW76',
#    '2H30WL3exSctlDC9GyRbD4',
#    '7r6aR2f57resC5r93LwMfK',
#    '6Ofi4XaDpvGA8q50NjDwR2',
#    '2ktxr00GpTtbMNeBjNeY8D',
#    '7xV2KiZcW7oUCUyYWzrxnC',
#    '7fnW0ZcFWAHaMGfCPW1gzg',
#    '0oBjCx63OwKT7anxNGO48A',
#    '1eW4XynQ3uk7Xi01hAzedv',
#    '2Eg5fW5yInLRGszS4s9eN6',
#    '1MUL6DO2gVimj2YrVedubd',
#    '3ZdJffjzJWFimSQyxgGIxN',
#    '5E7ifYSrZWO3GOxaDXTaNK',
#    '2c3qwFINQyRGwyqI97UQiA',
#    '0oPOuDmmkVp3h6puekhs6P',
#    '4MwhUpDkOOb4UU7BtKznlu',
#    '0dbTQYW3Ad1FTzIA9t90E8',
#    '2SABT4QZksW0H6bTCkBaxC',
#    '1mQI744KrltnCU798zIGEe',
#    '5PX4uS1LqlWEPL69phPVQQ',
#    '1xGxSCtX96DB7inpF2wKIS',
#    '4H3rqFTUsyeMOLhTXjxmDn',
#    '6fTdcGsjxlAD9PSkoPaLMX',
#    '7noud145AHZGg74vpWOsCa',
#    '6QNFQJKlZUKr0xlGZ74CZJ',
#    '2eAZfqOm4EnOF9VvN50Tyc',
#    '1Tnw0ItH1Macok8gblnPPd',
#    '0S26xmqTGCMH6ptrbQ8Gyd',
#    '2rMFawCg4BW65jzbwztXAV',
#    '2QoOyCFpDo4NblMLP7vBRT',
#    '7E2C5rBLpCKwQlhJPVFBRS',
#    '0Dc7J9VPV4eOInoxUiZrsL',
#    '1TDeDFUYHjZKLsO6bzoVg1',
#    '68lOQPb5tX8U2cQRuas0L2',
#    '3sp3wHVuQ3CRtsZykHDtKq',
#    '7JYsArznYOjX2jsrT3UEnL',
#    '1SGt65i9AnXYdDQt1AtDRH',
#    '0ZwHNhwxDhUYHYkSkHxMf0',
#    '03ZkvqZOANKndGXfAAPywG',
#    '2IQjNT6EXEEJhR3x5KnlOU',
#    '2RuUAwOz2vyArTaiMQUL7j',
#    '3WefHNGtjexZvi66ZEx9u4',
#    '1ysDVWxBj5Set0fA05TcyP',
#    '7olw5gkH3R79UG2NFUVixB',
#    '733c1CWmIGymoQXdp7Us88',
#    '285hMzLhJwHVLe9QT9qilk',
#    '38xWaVFKaxZlMFvzNff2aW',
#    '3r4S1J4YCkx2fuqH2eL9fz',
#    '2YALU0elzWXiee1nhHSWR6',
#    '6jQdrnnaQnoPiGgDEn0xcM',
#    '6GsZ4HTLTKZR9PHLDMJOfO',
#    '1j3SdMJfeRJXycCp50boYE',
#    '0uNConQbWsWTksC4y3Alnv',
#    '30z4LVkScpeNhwHFIB8Ewa',
#    '5h66wqaGklsSa8eSxTwcJT',
#    '1GIYmwtBbPSHrqcSaukZck',
#    '5Cg98kiDYtCEHmjcKD0CJD',
#    '5mHdCZtVyb4DcJw8799hZp',
#    '2QsZVnbWVSjKMXK6K3uRBL',
#    '6rB9te7FuWMxFYKEWccFAQ',
#    '4HEVrEnuR0m27G6gKHcGAi',
#    '67CZNsG3SQ1S8O2BsjTo4R',
#    '5XqDJFVCyRTm5J7cIfRmR1',
#    '1k691v8ChLgDiuLLKnjyj6',
#    '0KNvJzxdbslBddN27BEhfm',
#    '5XmBjBjVxyhZGK7tR4u7GH',
#    '661c0RssF9QbkyBoqcwGRx',
#    '5hNAgr4yRjR5loFVRcwYgu',
#    '5aR7Tk9BF8PjLJvKW6IBq1',
#    '2JzZzZUQj3Qff7wapcbKjc',
#    '6H0AwSQ20mo62jGlPGB8S6',
#    '1F1QmI8TMHir9SUFrooq5F',
#    '5oWI5VAgmJxHlKnsLjPJMA',
#    '2nWB8ZpA1lxulicEUzTQ6W',
#    '7e4KQkp5ZR1gXCAalRjX6B',
#    '3dhjNA0jGA8vHBQ1VdD6vV',
#    '52l2T172qhQASwsAK1C7yL',
#    '4hqOmrCCJKyiuwDexd8c2t',
#    '02pf9lLM8Nb8l4u4ts1GWb',
#    '42zd6DYQ4o4SECmTITrM1U',
#    '5g3InejbvUCMmZUOyVvRQb',
#    '4A7IwGhXmUCyrjPRZtOGcW',
#    '5CM4UuQ9Gnd6K2YyKGPMoK',
#    '4WCgIZ1n7I6yRaAQ9GjS07',
#    '7wGoVu4Dady5GV0Sv4UIsx',
#    '1OmcAT5Y8eg5bUPv9qJT4R',
#    '0e7ipj03S05BNilyu5bRzt',
#    '7BBabm9KfG4w7huuwmEMAs',
#    '45bE4HXI0AwGZXfZtMp8JR',
#    '3USxtqRwSYz57Ewm6wWRMp',
#    '3SZqA7rQvROJsCbUu2v0xa',
#    '6imkvepCHheIMhxdbxp53M',
#    '6Mz7ULRwNSCOdut6M3tNs2',
#    '1dWpEnUYgYkJHMT7zXKMh4',
#    '2VdT56BGpdqNHUgOe1j5vc',
#    '6hVGw7yVUd2bpdHMPCWrtN',
#    '0Ifg6sEGK8dH0XDD4pzKTl',
#    '2Ee9amLUslOwgoJWZEpSSD',
#    '6iaSML1PIYq936g62BDtBq',
#    '44ShclXTOOnYtt5CnCDeGV',
#    '1K27rBQI8VR2AdfjRjmdJP',
#    '127QTOFJsJQp5LbJbu3A1y',
#    '466cKvZn1j45IpxDdYZqdA',
#    '365wwIjijQdlRJEjUWTidq',
#    '0RbW8kWozrVSIGb4V13o0o',
#    '6xkvFmA6FtoqXWzp8QZyRL',
#    '62q03kZpF2r4d8rfLcExsu',
#    '4hQhEDssi8nxX3J8yGg8W7',
#    '6cwhJE7pYWON7vv9kwVvEt',
#    '3vS7px4CSV1I8hP5MXEdk8',
#    '3A2OHirUAlQp2x73BJlEDA',
#    '1QmFNu6g02GfeFnyvEejr3',
#    '2Lhdl74nwwVGOE2Gv35QuK',
#    '6LUE5WlMgrpLouGxzJAUVv',
#    '5KDfDLEaGAQ2uyuzsWByVa',
#    '0ZYNW5SFHDI3zLr3m0Nu9r',
#    '7ovOQ0x2mgakcGodDD1BPU',
#    '0qFX9pVJQB4lBMxRoFXqGr',
#    '7sdqtgsO9zxvKdrrVDpaNu',
#    '333jqman7dlfB7QG7w8Y0j',
#    '5GmVJbrzQA5Nkcz9Ykb9T2',
#    '0YAQnYt2oB8OdoaeqnHyTI',
#    '5g1cV8vAkt1ihjwlW8DWrF',
#    '3jWIXPUA6KAHoatVUAaxBv',
#    '25yQPHgC35WNnnOUqFhgVR',
#    '1k6GEdfONk9Fs6JgrC8aBN',
#    '16aNJYinJv9AAetWD5yJen',
#    '7LYgVPxRvlN7OavmyrnOGe',
#    '40tlw7ZOXCh1U0mvQQxtQO',
#    '3aC9IY1oAAb0WeFeYebriD',
#    '2vWGv9PLKjWfBEwyZ7UBsF',
#    '6Poyf51k7W3NKnsGwAI90B',
#    '2u2udGmop1z67EPpr91km7',
#    '56GZHQ4E3i9w9xgRkzitd4',
#    '6wCVcqWX20n8kAtIK9PoeG',
#    '3s9f1LQ6607eDj9UYCzmgk',
#    '6swTp6IlJ4z6Sgq4POAmkb',
#    '2mmUoyPxzbxehpfm1TpTRK',
#    '41MCdlvXOl62B7Kv86Bb1v',
#    '2k0HXdTDW28JFAaS8TaHeA',
#    '6Yqmv7XJLCrQEauMbPGZSw',
#    '5u6vkDnOyaf8LsteDAj2ub',
#    '6fi6gDXhy1jFeiMKrhrIyC',
#    '4bvVvzmt4s1saVh2Es97Yx',
#    '0Arl6zwBUJH1IseGbvNeM3',
#    '2tKXH7NdVrrjDvQrv9CCVd',
#    '6GNifiuBPrKFpwNBYnooFm',
#    '0bM3UGp7nctTP3cowdiDU8',
#    '5IvdLxVB8gwwcgnEkXSSW2',
#    '4s7U2mS26ab7GFtgeUcwKA',
#    '3YuWWb3oN9ysDJ62h675BW',
#    '4OTQAmLs7bmpbYyp7pjRaq',
#    '1ygGHZvhLZh1firRvAOLu7',
#    '6GmUVqe73u5YRfUUynZK6I',
#    '76vviJBqmRdMMb9u9npgfj',
#    '0WnV4YotgHecDIzfihlcjn',
#    '0U9FwCnODOJI8uhqbfDEUM',
#    '6habFhsOp2NvshLv26DqMb',
#    '7mOVlQvpqrji4h2CsNWFYk',
#    '4CPsMAG28OgzzDk1DcOtBx',
#    '7rbECVPkY5UODxoOUVKZnA',
#    '0hGShmLW8OxtW5J1vv0iE9',
#    '0drumuKkSeMz3CH5kGfOEl',
#    '5aqUqSq0SqGBAqEn27PEzc',
#    '3V8UKqhEK5zBkBb6d6ub8i',
#    '0C1T6YOwB7MMzspV0UbKKA',
#    '2VqKx3HH8gaZPabNWYvksy',
#    '2S3PBAzoPAxnmdOtdEuaLW',
#    '5AebNkVaY2zcdNFCqPBIV7',
#    '4at3d5QWnlibMVN75ECDrp',
#    '32lItqlMi4LBhb4k0BaSaC',
#    '40Hf6BV0EugJhs6BgzG35Q',
#    '01B7fVPBPrrqDh7CiGSIaq',
#    '2Jh3UqxnHJMyzMzku4uOtE',
#    '6Hgh47WXVKtXN5zGOu0hjI',
#    '4qZmVQw7vABIHChMfaUeZ6',
#    '3Hx8hoMtBcIj2vbS9hCOvy',
#    '23MF54AtVwpMkuQb4R70Rq',
#    '3dyDvQiRXHqnn4orAlkk6T',
#    '3dG6tjetoR4GMmUGZUprLt',
#    '5bARj22nURPaa84RvmOMP0',
#    '3VamXAvVMczcS2PTYtPfBQ',
#    '3rpmKDJk4ZUF8QAr2XaEnM',
#    '3KMiBz7bEb7C0vk7s0vCa3',
#    '5zWOqc9si4XnemdxZH4WGG',
#    '1tox00Nusw6t09cjhq5AF0',
#    '2HICdPKr1U60RWy1Zm5J07',
#    '4dpdRKI74fRMCxFT1Vni5R',
#    '2Ih5xNFMnO5WvEXRf1xCCX',
#    '4F1yvJfQ7gJkrcgFJQDjOr',
#    '3YfNhioGntblm6ciPsCwC9',
#    '4coITt1FG81SBmqJ1eSPxO',
#    '08UIiWFpJDG5IvuyYagkOS',
#    '34XwFfq1XGOF0HHyVQl1nx',
#    '47mA6f44zxLtdATOoY7GjN',
#    '5VuxWXbt7XENQCtE9TzpTv',
#    '518miTxc3a15X7HB8FgJUW',
#    '4EOVChDG9c5HX5jrNdBDd6',
#    '16Ah4QqH4mgYVXqfC4mdSd',
#    '0pzTOXD6nlcp3OlvmcyPKF',
#    '5k3xZ6bXIe0jFJ9b9Jk1a0',
#    '2OvV4NjEBRE9v8Oo7QeUCq',
#    '48sVPgGv1lux3LbGtk35iS',
#    '2sOj9vyd6yiss9W1IK6chU',
#    '5rZlwNFl01HqLWBQGryKSm',
#    '6wwruKU956ldDyz55DZTt1',
#    '4gOd2bxXpw32dhqTOMCN6u',
#    '1cCXT1cErAY6tmIqHbodrt',
#    '6g1lGlApRBJD8pPNmMgQ9Z',
#    '29ZZAShKhwRUuKULSNtxX6',
#    '5EuKpn4RsDC1UFVUT0G269',
#    '4eVAlCGYvDOsI0jCjdxvBD',
#    '0t3ZvGKlmYmVsDzBJAXK8C',
#    '6MDTpYxPFL0wtFd0pjfKws',
#    '5IhsQZLczOpo7YBZUnJUud',
#    '3psx3u5uPAG6BH3k6l8gre',
#    '2HbKqm4o0w5wEeEFXm2sD4',
#    '1Ser4X0TKttOvo8bgdytTP',
#    '5r7WvQtyPfy1xch5zMgGRp',
#    '4B7fTyj1FIPvP9tT5X3DnR',
#    '5T490vvoFNU6psep0NPmxs',
#    '3mCYIQ9zbuVH2HXyBGcy2t',
#    '5imShWWzwqfAJ9gXFpGAQh',
#    '4Q34FP1AT7GEl9oLgNtiWj',
#    '2Mm9FCqnjH9k6JfOvr3Hg7',
#    '1m69ELEgE6k5ZWsap40ozt',
#    '15eaTEZMA2CqOxBvyuosLI',
#    '4pdPtRcBmOSQDlJ3Fk945m',
#    '5MGeW5mHnqeJiM0NPBbkEZ',
#    '4ZUNw5tDBZTOqzPEVIYyOy',
#    '7iwhbx1YQcQ675DTj6AmAb',
#    '7x0c2xT3bNVDbFnsymGiPI',
#    '177WEvlLsCc0FzCTWslawr',
#    '0JP9xo3adEtGSdUEISiszL',
#    '0hiHNxqKGf3GZgVTIOAiiK',
#    '4KX8vXbouybtUptEyYxtIk',
#    '6RWa3fCOR5QQrQ9A3Wd3KR',
#    '1jEBSDN5vYViJQr78W7jr2',
#    '6osaMSJh9NguagEDQcZaKx',
#    '6uNuT1YKpKjgZOOKiY4Nmf',
#    '0xDqsk2flEdCrGEiGRbPz2',
#    '1cYdqcPNaucHnvF8S2Kl9L',
#    '5Rg8SptHd3tESvn4fzAV3i',
#    '0RjJSBBEolCDJ6wDiuVCmh',
#    '60hveqTyBC9rlBXu5hdxk1',
#    '27XMmSWSOXJ7eVb40tH93T',
#    '766xt1cqAblYahe0gyWPh8',
#    '7kvbLCrZv4aOz7oafDupzT',
#    '0gTqEEZKoCn53BZAU1A4DG'],
#   'angry': ['7tcfGGpgfIt2GiEAUa2BXY',
#    '0deIDdzX3P5svUOADWfWVu',
#    '0ypjMI7vHiDP4sLB1C0Qna',
#    '13E2LxjLkusP9TqbSTGTIz',
#    '7c2FM0OwRpWGyCtOVltvqi',
#    '3umPlMokEzAFxJO33tNdlY',
#    '2ztyTz3H928W2bVb9qXBlB',
#    '5NfFiV4oneo16S2Hpt7WqE',
#    '0GpaZjcvRnIqVrtLqrzRdp',
#    '40mjsnRjCpycdUw3xhS20g',
#    '2XO09akA2Ymb78gMjVd8Q5',
#    '0pn8eHCvZsBAF9Y9wfv4rt',
#    '38TqlPI8PIVJ4AOXdRHKUh',
#    '37zJ0VBdZO7G7LoSjLX1ES',
#    '45npF3MKvCa1sO7s4y7qBf',
#    '16q7iofxCkvWBKef4fMKf3',
#    '3EvKRA9ZDmZ0RL3emxE884',
#    '1faIb3PPSzEifCHUOJ691R',
#    '6zAFHVV4PKSiMNvw80D8qZ',
#    '3o1a1gcKSInPVgH5GmITxW',
#    '6rCgAmLp3PTizfjW8zpa2q',
#    '78QR3Wp35dqAhFEc2qAGjE',
#    '1BxkZE73h9BN3qwuA15TA3',
#    '6Ozh9Ok6h4Oi1wUSLtBseN',
#    '2Tq63TjpS5euE9jT1GWleN',
#    '4VA2prpKDv7ywbnPFfPrWS',
#    '3yIfEnGku3jurcgBVO6dOF',
#    '0Q2n5yzl2XRqYbV77tZNYp',
#    '03jnWnj2qOrYofsyCTuHC6',
#    '4AOad01gIwmKEHleoTdU4g',
#    '1BSMGMoPK6UnK6hfY4gMMp',
#    '48KTGG6wBPpleE5KsTuiwy',
#    '0QinRxTfDx2hlJVZeQEGJU',
#    '6bGwKHXHNLmTy6yt147FPh',
#    '7166FiVEnGCG27MITo4kXC',
#    '2gyYjQWXKxemhAyMPgctIx',
#    '57qvqFm7s8ULbFdkpqBlcL',
#    '6ioJIbTdQEpbvkTdPuwhF5',
#    '5KBARWIxeMGkvUax9VtVC9',
#    '3q6ko6Otby0KfQVHhaKisM',
#    '4PIFHcMwQrebdI6A2gS17t',
#    '4KW1lqgSr8TKrvBII0Brf8',
#    '76g0tNmC1W9HERRVpcEJso',
#    '6l49ok5R3sjwWRcCYi1jn5',
#    '6RU63PkecROxN4myEj4KMC',
#    '7KVPsVMOK3NL7subwJ0dZj',
#    '7rjGZWlqqeEMDrAabwZQhr',
#    '5BojMTUzwug3YQ21nThLhv',
#    '5eq8CDTzJIOq0aMtwbp5Gn',
#    '1ixbwbeBi5ufN4noUKmW5a',
#    '3ZsbSopfR7yCEaj8BCEvLi',
#    '4YqWDFbyXPih0e0zkScXmf',
#    '4vFpwBCCKgzHlw8U48MYdS',
#    '5MPPttjfGap2C6j6eKcO6J',
#    '2nKYHpmwjLaEOXS3o7QMiz',
#    '20m7W5dGNQyXLqr7BVasmy',
#    '7JuB63pWkmxIxSazNB6F5m',
#    '4NexTaCZZ7Ehnf03A6SVjt',
#    '1sOfCUi9krfHpUONlkIC87',
#    '6TrzifGqGOc2DfBbiXQtTz',
#    '2XEsbmynS9dLSzNSuZzfXF',
#    '16g0MvK60Z79npuD4wvh4E',
#    '3au0pvHqcTtszysswan6AO',
#    '6FG3Th7J72vwIfUqVGSQ9z',
#    '3HMwux9aUUgNyaZLfKfwpK',
#    '2oVWxQ0ZVVhNELBGi30Zhe',
#    '2txxneWmDggnj8J0IlA4ZF',
#    '1D9XLqQp2YYiOxrr5KLb8K',
#    '0ipgd8PPFza3NNmN3Rn2uF',
#    '6LcauUZjF1eXQrgqMUecHX',
#    '2h5wkA3keIclvfAJ95VMAo',
#    '4HDCLYli2SUdkq9OjmvhSD',
#    '2A6BUUkV6TgT4QdLCXIDPl',
#    '1GT4i5dtm89tSc8eaidpNf',
#    '3P9P3Lq1IGsyhmNrnank0v',
#    '6JXFDTCAIe5FfiiQYeMgh3',
#    '0KBg8fop4DsefGLKkkuenn',
#    '4oViDMf3xLwW8Ne4lp26mC',
#    '4w47S36wQGBhGg073q3nt7',
#    '6TMwCGsTOlt796wpmiFIt7',
#    '1fvCggAYrW0VtCljtqv4h2',
#    '2UnYYdvyWndHU4yPdoyAtZ',
#    '4adrh1YMaPAhtqalhG8hIH',
#    '3xWwPvpAv1HbKFmTwf6uKR',
#    '02mYw61RoS1vXvkD9Q5dpN',
#    '2ZlABhxMMa43COmZ97kKsJ',
#    '1jNKhbKmDgYSHHSCEeMXey',
#    '5Kwd75iAKLEMncFz19aYrk',
#    '3IaxObCWKEaGtIT78GsEpP',
#    '57ZUX6TNyKLBydAdVVd02x',
#    '3v84EI4rMdsqJ95MxwIjQa',
#    '5fcM0StdQxMjzulVGhFkHN',
#    '6gbiTbclnHlmSIPfmF2zEc',
#    '6jw5Wci5VPexbB1rCuGxoY',
#    '3x5F5wMcutQ4Fluez44tZm',
#    '7nc7mlSdWYeFom84zZ8Wr8',
#    '7cZxllNvqJrFaU4op9YvK6',
#    '696DnlkuDOXcMAnKlTgXXK',
#    '4VzhdfRpM2sQjhzwYWjd30',
#    '36n3hAFlELgqAU8lG9rmiT',
#    '4MAADpR6MjelkaZqe3Mgnv',
#    '5uKHTLXNcftXtYfU7j9cQ6',
#    '2WX8QMtZVO20ywltD9BoeM',
#    '3XLbDUB5BX2WqL2qoAsvtb',
#    '6ZBqCuo8fUGSZJGYR9LNwL',
#    '1vf9F2n3KbuMQrTq36QLJH',
#    '5jd4jhBSIU14CKHN7gGl7x',
#    '6XkLPzkKzPhpr3hrvl1TUq',
#    '7bUcBztfGqO7cSI2gMZeCI',
#    '6ikCQEYDC3MQqt76WFhOBf',
#    '3GOZyiebYv432EnVy9XwzE',
#    '2O8gSQ9z52tZSLJnuzjkcG',
#    '00qca3mz2Xqf8NkrLEQPv5',
#    '5m0yZ33oOy0yYBtdTXuxQe',
#    '2QsBumpwD0xDeTya3zzLjP',
#    '2odsPaEdu15IITD9XN5qWs',
#    '0I18FtUzsemLMXQUqAlyRB',
#    '0p0jvYdazuWBMC8QacxpUH',
#    '1sPLURKAosM3Jampgp9AWq',
#    '67fNrBUMc7iWMofdCaoJV9',
#    '0qoxr5PUFbDqGLHIpEnWAr',
#    '71hBQ9qHsZU2M3vDF8MtaN',
#    '05YWwf91PR4BxqxAXZGjSa',
#    '4dASQiO1Eoo3RJvt74FtXB',
#    '7qUJQSNX9QNf46CC6FgH66',
#    '4n358XQMHXd0xi6NazWdxr',
#    '64o5zHN3gLrANlEUFJAaI2',
#    '5nAAe53BkjhbSgEjT5diyi',
#    '6Gy7rXB6Ku5vIWC7WGWsl3',
#    '1tKdNx0ZsnFlf5h5e0if61',
#    '2oSG1lrQZHUSs4hhgv7Imu',
#    '5OjLmBBHKM9bt99wYGpmTe',
#    '74lnM5V6ecvoTPV0fvptx9',
#    '2smEONp56oIB5aTmIuni1r',
#    '5pQZullzXsixizZmBcmXhy',
#    '5ZoOWnKOxm77heTeIQrlDq',
#    '4WznHDEzfBcZOVFFNkDUBt',
#    '3EikYy40GMSp8l5mDV6IQo',
#    '2xB46Bj9HZ4cr058yN4Pla',
#    '1Y500yrabUJY2mIQS3RDt4',
#    '0uinQuLSYDMua89kLVVnjv',
#    '6DntjiYzCMQ1hCIZSvF3NA',
#    '3hgH9BLsMcj5CvaPnnc1AJ',
#    '61big1BzOklF2jK5t4FzZ6',
#    '04emr6g1YI9iOjVvBM0qiQ',
#    '6eec0xaWznfjDCvbt6akqv',
#    '0kMXQ9xqVotFY03OtYO85N',
#    '1RrQK0BIyxZaOooNDVSEaZ',
#    '0ycIrEpkyb4lrqE7M1emju',
#    '3NnINnjKVVs03xat0qLQFx',
#    '1cAXXqdIlFs5Fu940SYOZ7',
#    '3IGX2zBWkTGi3EfFMYzJrs',
#    '6rDaCGqcQB1urhpCrrD599',
#    '2qHaFxrDldxWUtIy9qaTM9',
#    '0lMdefFBuqbZ9NJzZesqVD',
#    '4Ami4MTReWxztxGW1ZmOk8',
#    '5zEeiQbazUWskpZNhnh6i2',
#    '5XIFbLsWQb1GSbORs9pbXC',
#    '7wpyrkjEgz7W1vNYDxMKrF',
#    '1jzIJcHCXneHw7ojC6LXiF',
#    '1Ln0KAumoyNYDefSPWY5gy',
#    '09FfQO3PqHO4HIJL511Ksi',
#    '2e2yYMQwKzWzXmdsbu2bmm',
#    '0zmxfTBEHvbHN3ZyAh4Sko',
#    '5w2HXlDs9XjZxbXKIO4Gdr',
#    '4rbYZZkMTz1TTty0if3oRv',
#    '1BBwECyBZklj6svVFlIi3m',
#    '1rtaHauB4l1OFtD6thohhV',
#    '29tc0GbW0pTSBZSCZF3NWk',
#    '4pVJPCOsLysyyX9bhnyxxA',
#    '7BbJw7SeLDxB9ywy6EZjA2',
#    '1aYLZv4l7L90l5gDoOpZpj',
#    '3WyRgi8CzQnhzO0xw79tTS',
#    '27HQlJ0Y13dMLHSefcYvnM',
#    '6YSSwMdps4VRdl2PJ0Jc7f',
#    '3040Tr11Vs70U1KE9ecwLH',
#    '3u8bblcJtOxxmGzJrviWLp',
#    '24dFRDzAwXDOVpG4JVRSTz',
#    '3SsJ17EnPIu1B4GZshqjIS',
#    '1zZEly0sLmyDm75c1pAqYf',
#    '4YoN2mgVecLrqrhfrNyYM4',
#    '30vAfL9Wyu2fu07vdbZ1Xt',
#    '04jxsgT544zJAb6CeGUwDm',
#    '5l9A0gsS7w2GcQXQr3zxiC',
#    '2sHekv6OdEiO4htSjdB9j4',
#    '3NGFypWpVSufwD7Ve6ZycZ',
#    '4KIkADzoVm3A10E9qyjsQ5',
#    '37M8XgWP4dWZGxIyImFID9',
#    '373iQzYhS09JcQ8NrTU6D4',
#    '1sl1cpix9GnwNwaVt04BIu',
#    '1DdgqEZk4Hqfpl3drdXJun',
#    '2PCKWNZYcwyFKd4lVRWE8k',
#    '0WLhJ2NBuZHuoHY8pLVHJ0',
#    '6Gg1gjgKi2AK4e0qzsR7sd',
#    '2bqIGBffiG9JdanfZbXFdd',
#    '3f2Snelrnhagi82TeIjs4n',
#    '3M0YCNnL2IKwjDDIGrVW7O',
#    '4s6NZMKnoILZkxD3zO5USl',
#    '3wtHVrLtWcoNLjNj9OyScM',
#    '063EqeOR8SgroYDVkyoC2j',
#    '7pxG8OJ3hbKRqHsNe0Ljmj',
#    '75dLEqanQTupF3dtP9exT5',
#    '0asxiZ68X8m2wuJwsabF6d',
#    '2CgkVM57rCCiELvMWa1rpV',
#    '2UVbBKQOdFAekPTRsnkzcf',
#    '7iUIMA4pI4YOIZKzU9EOZC',
#    '5cPvON926WlX4q6PBD2oYM',
#    '44ZJ4hLD5onikKsVLQaILr',
#    '4irYeuAi87yyGHcI4h9s0x',
#    '17tJRMOZ181DjZMT4eIbSp',
#    '2ODUTBkiOWoYSUjKpGJxQE',
#    '59XHPyb0MTMElZpkG0Wp69',
#    '0PWQqF5PvqRq0OPLSH0FKI',
#    '4g32MdRoqwGKQd3NXIRhpU',
#    '0VlpgNPHWCyh8xxLcaK2fp',
#    '3oqPlAAVT9JM9oF1TVfQzD',
#    '5rHfU6rMbTlSjR15UCrriR',
#    '2xKQj6P0TgxBVaRiojP2s2',
#    '6nrPRHGdz1ytpX2ZBZ4RGU',
#    '7i72BvjsQ0P0iYs0xEoRLm',
#    '4XslNXIadAFZ1PmbELe5TB',
#    '1CjgBZsDOXNUs9aZdzOqSu',
#    '5S0QZGDvhgdED2WJGgxBKb',
#    '6j97zG4DDrh3oUa6rZbFOs',
#    '7e7Iq9lhisbqgRwxaCVvYd',
#    '2NyrXRn4tancYPW6JwtTl2',
#    '3rLIFJmJNoDWd43ayQHCEo',
#    '5ujIKl4PDCqxU4t9xv8XNO',
#    '71SEHJPt1iDwGkBhUOAXDP',
#    '3tnJIJVNuVziKgY38J2HZP',
#    '2ZrUwNP8q29wg3VpvMI0t3',
#    '0RJPcHHwu7aKRroKLUNWky',
#    '2NogS7n5nLxYdJA3KV6Gy7',
#    '103xWcm9VB6V2tbfPvh8qq',
#    '2VKf0WEOpq06JE5PTNr9wa',
#    '5cHPAqi6V5JPMy0vqS4lK6',
#    '4wTXKpGKv73CBKcip15S00',
#    '6Rtug7pmJtXarD0fTtRlt0',
#    '3YVeaqhSFth8QAL45wO19L',
#    '5Xks4meWbkd8vjWsxqYeNF',
#    '4dVpf9jZjcORqGTLUaeYj9',
#    '5lZsh9Qf7CbHI9Fcc7Zcsq',
#    '7f6CYOMT6sXv35ZTJRtXtA',
#    '1ZRjLZcNTm1vUgrexBp3px',
#    '39u2PsqrAZpZ0KPx6CjasV',
#    '1DCLOAT1E5NDZDupAE95ka',
#    '1ahRPMw2Cpv1HfUNW8Ykw4',
#    '3hhs1XHsWvbH0mP9D1BT2Z',
#    '5x8NgG7Ya18m9wafOvvWYk',
#    '4CuxcBpQnw3Itmp5VQoCHj',
#    '1b6rmL3VXBgYTbn61kM8wT',
#    '4jkQY3kryVNYe4jGJ3nChu',
#    '7oLKoGzQVwjZ91AzCn560T',
#    '3ExGZwDIQtVLkxNwal7Hx3',
#    '48t1aADyfDbDA3TzxqQHrN',
#    '1Yt5ws5j7JENlip4XbLZgy',
#    '170DNUSnQRp1tGpppF26pA',
#    '4eAMcGhHBs217Rm98QYNSo',
#    '2d2YqYmOBBni4tPOrBJmDQ',
#    '1xznGGDReH1oQq0xzbwXa3',
#    '1zi7xx7UVEFkmKfv06H8x0',
#    '6JPhRNrks8KBuYDPvbby60',
#    '1BpKJw4RZxaFB88NE5uxXf',
#    '6NXqSpbK8xkfOZRTVhC5nr',
#    '6vjf1uJgfOLnzFCxWBdbch',
#    '5Vw93DRw0NYgrBjzdMG1U8',
#    '6DlrQcvUO7lg5vKgMZmG7F',
#    '5aUJonYqwhmvgNlWQdH6P1',
#    '2xEvCnhZMxvvRwaF4le8UV',
#    '47WaynXajQu3fPsQo05iXM',
#    '6kuVVW6VGn7HPwuPAL290T',
#    '0oYVpMMTRtlrNiHDPfWL7q',
#    '5TD2xyZlYdkQ9UA8eT2TKL',
#    '3ysekpjPtqYR1YvW50KOBI',
#    '42AYOB8feXIDh7FaiId3pS',
#    '5dPz35akJjPqb17yeqNwqH',
#    '7f1zjZG77S891Uv4O68yfk',
#    '6K2anECyrckidwf5wxS78Q',
#    '68UU9oaQtMDnh6PRlW842H',
#    '4LpJtZYrpJqVCt11HciODV',
#    '5HnxL39pSgVVQMLP7WnSfv',
#    '27ZZdyTSQWI7Cug2d2PkqV',
#    '50ceCGZ3oD3U5caQV5bP6f',
#    '75N0cen8wTAlL5nPFprGoE',
#    '3AEgic4yp82NxMWUjHtxnO',
#    '6vQnpXl0KvwTfLpIhoOLHc',
#    '1taKClbaJhl9FXdtM4hNBe',
#    '1XhNV4snLHYwZVeaUoT0R3',
#    '15NvWexLBzx8l0anZ6V2Yb',
#    '1dIWPXMX4kRHj6Dt2DStUQ',
#    '3iwt15Ynm0cYicIGQ9hAr0',
#    '3zuMEteRKyQCujA5CiS1jl',
#    '4huBDGP4I3S0pYI0EaRN1c',
#    '4DvhkX2ic4zWkQeWMwQ2qf',
#    '2YUoLKAoec6DQJK4q8NDvf',
#    '3CS9KbKRetHgdl2t1aXIey',
#    '7vYPWVc85PEmPjqcrNGmRJ',
#    '5rU6kDNXZLXIinFezpbWbO',
#    '1nD7jf1wHajkkOroyOCrDz',
#    '4v1TTTCadimzZkTuDTnYBc',
#    '0Ryd8975WihbObpp5cPW1t',
#    '13LrJDJhegSLCZzqd5InmU',
#    '5bBzkJE9BqYTL27webAUCw',
#    '6Fr7f5U4n2Ip5QKNy6IJOf',
#    '05MV6P7UtbzP02gQzmvIEw',
#    '06JvOZ39sK8D8SqiqfaxDU',
#    '1I3ZAmPmbFV78oNKnibOiW',
#    '0hZAwaGhANCzy84BJHtILG',
#    '7oJrVhiTPZGBXWPwhxjy9S',
#    '3zmySiBrjkMtbbtKSff2Pd',
#    '1O74puD8I4KuXaa9N5j7ME',
#    '2wOXxtHZgRkkrkEbKLzzqs',
#    '1WV88Wh4HVWJ6r4YJ3FzU9',
#    '35Rbqn962gEydsN1VKOC3T',
#    '3R9j8urSPiBbapNbyuSYkE',
#    '5hJ90ntu3AiMslvAuUR2Uo',
#    '73ekBE1ZHp8ySUaX0YdCtR',
#    '0LH7ijaQi0ybY6Oe4SCLo1',
#    '111fU7H63Z9mK1BO8aM3HY',
#    '1MIGkQxcdAt2lDx6ySpsc5',
#    '5PMgd0V7c874zDCFMtTbTT',
#    '1rlIrbWboTRGeKfHhgbJRZ',
#    '4Iz3e22hTN8B2koCpPuoUD',
#    '0z36JaXXoFXuPuQucKEsdx',
#    '5PIfH6BzcmH04RDmtzF0BN',
#    '5Qx9hngUBr30JFrNua7yp4',
#    '3uHLOJ45t4iS9fFpuhhKSs',
#    '78KiqdSnQIGiJzOJRQMs8G',
#    '366DLDHAnvMnHP5ECYt4N7',
#    '4jtkMB1q0M4icd8Xnwpiwx',
#    '5fbHRCsGpFIOLRtlhCRFDR',
#    '7ijXfR09g8dImpTI586m7k',
#    '614OkajfRPH8V0ugNQnduP',
#    '3c1sfDYFzlTGTnyVjUZNl1',
#    '0baYVkFX4vIXXmIuHRWXDN',
#    '6tRfQqrwVmpC5X625ASBlc',
#    '25zlnOAzbVoOzIeXSvQFf1',
#    '6fI3tBVND8zUXZi9rr2Yps',
#    '1XJBDDpeuZaj5fvmwhdIMw',
#    '2D6vfFZxQ5YzPPBODls1a9',
#    '2oMOqX9k4k16odibNkYyrD',
#    '6gIM8RWaTNL96Juv4gPSQX',
#    '33bUxQsbrR2Ue2sS9o1Naf',
#    '0bScrxcpjxkg9Md10zRjF7',
#    '2WrL8vwjup2a1lNsjWeFst',
#    '7MuhbSNErlmQAGRzhnnIjT',
#    '7km95zsDFQluKPA3Morwb0',
#    '1PV9dtzC0wyx71YwoGDLiO',
#    '3wFnBRnYgpdoBQyXl3NxoH',
#    '3HxYOwZZHZn5mC1drqPQqR',
#    '5nAkJ0CWpvGRf3MbOpwSfl',
#    '42Q71LGgYI4eBdebWn5m6D',
#    '7foypmc7KZyU716Yv63BPe',
#    '042nVrQvpEVrsrW6yeeHB2',
#    '18lkWhwmY0fVVv40eCxohv',
#    '4YiY551vHi6glMtgVxuqAy',
#    '4kRDKdNS9K7qX49fpnQJkW',
#    '2uxkxtKbBvHKaERrn6IGUc',
#    '6S7JYWOfGE5Sk3L9cAlATH',
#    '43CIWpJaJHRcI4mUSjqgc2',
#    '3STqgOS8Gnn0BQFHVbMIEI',
#    '4bvNwqjzJbbmUDClgpCTG0',
#    '6rdKv5xmdOs3zsg6mpBK53',
#    '7bTSZA64kmmd2biBbcsCUk',
#    '4ubJpfJRCJwTnj7lOsZhba',
#    '2qfPBPq9BEVEd1GF4UH96H',
#    '0BFGDkrXAneskCJdudSCro',
#    '0LlFMKD7MAHwOqkIBsHui6',
#    '5twXMRN2AEXoyZ90qLW58O',
#    '5lw8Mgb4LyhriPIC86gV6e',
#    '3gDRZkL8YfzpZg1N1YsW5x',
#    '3thLnNvO9IctWoccbsZyJV',
#    '6BvtitRX5lQC87YlA6rq0n',
#    '2UslPu1Jo7jIiUchu9QvPv',
#    '2zR8U7MLwxlLf7xkAew9BR',
#    '6AyF6EkfLHufgTW2iKRooa',
#    '3mUk1wiSBpiuK4oSSyDmTQ',
#    '5AjINjwKyRvQJhSe2zpPHi',
#    '5QUMbPfDB5SgbArt8D2Jw7',
#    '26zcbVfaxpenVvQ3v0W5Pa',
#    '0QVvkAOstRG26pVYN95CeL',
#    '1v7yjddEltY6J51Wx7mXTa',
#    '0jtsTHyFUH1p5sBC1J77NV',
#    '3V0assD4Gg4BrXFzDrcWVj',
#    '2epnWVNLZ00j86YG5X62Hx',
#    '2yrdwMzK9HL3O7dGd79yoC',
#    '1yz5JrKSkTyOpEa1iJpmip',
#    '1H7KnK26kc1YyellpbINEn',
#    '77Xwqkw7VrV8E5FCq9JhO8',
#    '1wJRveJZLSb1rjhnUHQiv6',
#    '6iIQFnknhqitV3qJXICseF',
#    '7floNISpH8VF4z4459Qo18',
#    '40A28bQyxfjQWmxh9ypIwg',
#    '5Pm5aqS8l2fytzhix5Pucu',
#    '21UkXrc9kD48rNpTMI2ecz',
#    '1es7SpekMUeMAIlG4iEJKX',
#    '0CnE69w3UHMTH3r5LGbAjP',
#    '1qfBvt5NoEv7rQD9yzXVsk',
#    '0nh0CYu2oWeHr10rwgweTc',
#    '3cjH8FiSkWc7gY1Sip3WkV',
#    '7ihTrFX15onWzNwCHCD2w2',
#    '5t6mYW7GQeBrCphuAXZDFl',
#    '5nR6MBAFCdusf8C3BZGtop',
#    '6H4vsxNsm2NsV8pBAb5WnU',
#    '6U9OkV9oa8kN8LyBGf3wvJ',
#    '6saIbmjLvaqhS7yKP8jAk2',
#    '1Kg99KJWHMNn0IgnEwvWR0',
#    '2WxUIiq06XXPYWl9YcRJnD',
#    '795VzZodMdZzC5fXMp2L3T',
#    '2iObjOsy2vpsariW4Y7hQg',
#    '0kBqgeRsRdvvFqMpiCYRNg',
#    '5QvW5lK6mkfTegpAK9JOO7',
#    '34Aj1Yn5hEZKmRKkfRQNAx',
#    '792HwhrdO3ErRKL5yRe4Ge',
#    '2IoVnTEyj8NdFBpWoEFrMZ',
#    '4dOmgE4ULbySxpeGObN8RL',
#    '6sFc3Hd3WPy2Hepop2IIjd',
#    '6pUBrvKfJL4qmn95mxU7rC',
#    '3fK1ALymCKkWjVPTFWFDsl',
#    '4eL3XeuGaEoVT8ttDh3hwY',
#    '65Mnqq7nlnL29EnVnOVFDM',
#    '32aYDW8Qdnv1ur89TUlDnm',
#    '7ynAgAdnTA6gIpCHwQTjRK',
#    '24b6djSbUFQtXAdyb3FMbr',
#    '2VGD6mGeuv6aORaU0vKsHB',
#    '7cWmR9RLLMY6bj28q4bhvz',
#    '2TG1SJGxe3dsTqRl15Lyle',
#    '5QcTwY2zSTX2hrVj2oHIbu',
#    '4aOOExMBUyxKnEYb39SrTg',
#    '07FkzikE6FuHIa8Ma7zJGc',
#    '7Fos4vYGRc7HYzzrKCEzAE',
#    '13K3BqdOYYMepkNQPWL1DZ',
#    '4lAQfuREAHG8IC0PiiigBt',
#    '2KG4X41ARZad7B6XczCvgc',
#    '0aWMostcnfyjuCEcO7sTz5',
#    '2vs5ubqg8QUbfyWZpMfvWe',
#    '2QrXzOqLCVDRZHkToA0tSR',
#    '5Vp7xBUxV22dCkvUaCOjES',
#    '3dnNDWgB0FAgjy9K1rSTKn',
#    '2c3FyNhGHcvGf6T3L7Gotq',
#    '3wGXyJGsCf1myH5MooQIqE',
#    '5f9JYuHSIHjp6rggue13RS',
#    '2w0ZyonrOZUvYbmiyS3pTE',
#    '1PL4eTnRS9bdjDtPJrmj3Y',
#    '3CSv4rNuCPcqSA3UhB1it1',
#    '3pBt8B92anUJVIllwPrIuR',
#    '3fjQfBYx1YNFGW843cE25z',
#    '0qI4TYcBno4YBhjuH3HV0A',
#    '4KXDT3pmPDB9IB6hTUoGpd',
#    '3KYTIo9pu84SbLL53iGew4',
#    '2b7rt5gCEy2p2zTp656s4U',
#    '5GaI779eVPipV1XJsyNhpj',
#    '3X6YJcqTinaNraRvojF62K',
#    '19h1LNf7idduUW3jBeswB8',
#    '39M9NokmUeFunaUNoCIsp4',
#    '3sTg6zZknU6fE8IXokRv6d',
#    '3yKJI6wr8NR0ITCLEW3nvc',
#    '3Ddny34bFoYBb8dIGq5lwp',
#    '4CYcWr8Pk3aNfQ03AUUHew',
#    '1mZbEtVS7C2EqiSsN7m3ie',
#    '6BdgtqiV3oXNqBikezwdvC',
#    '2zkCbezif5Vb2XeCyFaEwn',
#    '7FW4HUo39yRwGVxEoHqTa4',
#    '2NRGaA1GyCmTYfm2GRPkUe',
#    '7KELx1RRB94Fj9W6X2spLm',
#    '48NWUlHl5qWOvDKrsoox4L',
#    '6NsZoRD7jKxx97Ch8kTDAL',
#    '3KJ7n1lICe3OZuuwZQlWDQ',
#    '5274I4mUMnYczyeXkGDWZN',
#    '6heRfvHrUIIPx9TqRg8SCq',
#    '1tXncn8RYWcTfX5dJoYQG4',
#    '4wuMS7NGVbU7hdu94K5icd',
#    '7CkbRn6S0itJqcqn88AtSV',
#    '7cWh3ScxjhvasLI0CBRoZk',
#    '7ibRB2S2WOfPKSvYkhcYtj',
#    '3szf2z1Cy1QMrtHrbn8rz9',
#    '4uloft7ZE54WflsuqFmjC7',
#    '5u1n1kITHCxxp8twBcZxWy',
#    '2tUL6dZf1mywCj5WvCPZw6',
#    '0rLfccUtmbhlmTAOzc4gkT',
#    '3calQ6T24KiVOWlRKr7rfl',
#    '5rvNne6LhzU1P5uzwHQ9fB',
#    '3Uvi9diL18dYSUc3vcKk0n',
#    '4RQvgOmRgrrfrkCqAvy9TE',
#    '0jqLv5PuEUA0GthFjdtlS1',
#    '2CDcXWYWilHTXrsOXJza8n',
#    '3QlGCK1iPGmIb0HJosdwvR',
#    '1hmiQTBi1ucDbqs0KEJ1c8',
#    '5HCyWlXZPP0y6Gqq8TgA20',
#    '4v3W97RqEN0kgaLAre1pbJ',
#    '77GoToROOVIQZidN1naoOF',
#    '6irE4Fbjbry3czv7mTxVSB',
#    '4i34XQi9VQK7YQWyXM0hkh',
#    '5TJoARQMENPzacGbxF2B9F',
#    '0yyiXNPik06E8YOwWZoY8i',
#    '3O9Be1Fv6liQ6rmcBF7vv8',
#    '0OnOA1I97sZJZguLRNOEqx',
#    '3k0466XwffkAS35ofvbg3G',
#    '6OTClxme7EYRZGO6An3SMc',
#    '4VIznE5GISZrFlTxFNE7Pc',
#    '465eCPwUAz2qz7IdQaxUui',
#    '2TRAOLPQMvFM7kq8MHyizc',
#    '1W6wxOOYyJyyok8fqYSZ3m',
#    '0D57r0pP7et2thTG95dvlf',
#    '4lTiuD1DwBKo4L7wqMkD7C',
#    '5StM7ktQ5TIstPckmRbWWH',
#    '0NTypJrNfmemkF1GevCWSf',
#    '0yL0He951vlMYygPzSEEJ0',
#    '64v1g2HcPumBz2Wd1rT56b',
#    '2IqgN6QzmP2TGgVtqp0L7w',
#    '1WGRoqWrqDkXifw5JBayUi',
#    '7q1ikCoQLytPP5TTzDy7JK',
#    '5FwKBU61DSOW89d23NUzI0',
#    '5V1QsNSEDF7YmNBhSKhE75',
#    '5PTG6rrL6EPFD9E2QMI2pl',
#    '0aQ9hY1hXW7TI5rGTWTiJ6',
#    '510mvRgE4jLSsJcBh2pH0j',
#    '05t7JMip6JrLuSrMV5yYjX',
#    '45bXTH6SuR2MKjypu4ksNz',
#    '1U4mweNwisxNj23ffuC9gO',
#    '0ZKKJTv21zJpNrKiL0LYyV',
#    '6MDdceLYec4AxohmorE4vH',
#    '0w7IgpqkxKyRBTqGuQbZNp',
#    '52nTQQahs46s1iHFQ3Wv5Q',
#    '46yOT5iCvvQsHakl2aHhTN',
#    '0z5ZPs57J2KERwM1tBM2GF',
#    '6r6LKD876hNuA1s3TCwxXy',
#    '7HIykrQ0wE27oS9fmU0zTw',
#    '01Qb6dN5suQNu87VJ1mIpf',
#    '1EOc4ZIIpQfJyraqEHAm9j',
#    '7iG6aXHLFg9tBzP6OIyuJa',
#    '2rLdMxX2E0X2GG8xOCrR2e',
#    '21IkUVkA6PSpgzRRGceRmF',
#    '7j8vHxTp34MEoSDLG51sWo',
#    '6kcreirHsB8RNewt8rjd4X',
#    '7n0lXKEOaFxrAU0R93fIQh',
#    '1luVPNhyJQbG79KL7ickl3',
#    '5PUxWxXQEJJidGkIVIF7Tq',
#    '5Q98gqWkpDY7hfDa3Ho4ch',
#    '6yz0Jndhv0QjKdpcEMbOjz',
#    '3S2UTs4WCwuSPLqWuRTvAR',
#    '0Ij78RAgPFxeV5xPkvfJGO',
#    '2uMTscYuCT3BZ0OCzH3MwN',
#    '7HdNB8nvJOBwHa8hIkzvxp',
#    '5ojtht0AsyXcy1Fv4XXsRV',
#    '2KVIbpLNO5qm4wbHwBousj',
#    '5LyK4EaVofQjOvJ4OGhdfv',
#    '5J3LR9JWrZIUTG7UGZkIKg',
#    '1Bp5LdIxR3XlprIigqp4en',
#    '1xbtojAZsQjOgiGdGX6ChU',
#    '1lOe9qE0vR9zwWQAOk6CoO',
#    '3p6JF5nt0bZOSgZRONNZp0',
#    '72kmmlWqS2SkIVwBmawtbb',
#    '7hCNkUz1ccCzsoiTxRDLzO',
#    '5rgCPO7k4kvWsuaCTwqPhs',
#    '4UBicDBC9UqwGau3sWIw86',
#    '6Rsx5Gn1HMVpEe4CwIBSVM',
#    '6lKHWsIniRhG9xFBkD4mp5',
#    '0GtDUjBoDAqaJbJJlDWvvM',
#    '3aFvEbUYAOiv8mOOnGZ89R',
#    '0N0h5lXc4HOiLgGb9EZi8m',
#    '3uHg0XdV0H1cMMHSXFbnJS',
#    '6tByydPskASjm9jTPkNQq0',
#    '34PhB0kHT00utubP3aTau8',
#    '3rOZKd4FOb5fA32TSd1IiR',
#    '1JczBx5oXAnPBtmGeW3Aik',
#    '1SaxT2eggG2xalUM21tUSw',
#    '2Hv9wGHbkfIBScQg4Tti11',
#    '6lW7DekifBZdyDSAXrVDMm',
#    '22An65gG31JLf9n18qjdhZ',
#    '4CH66Rxcjcj3VBHwmIBj4T',
#    '1AtJv3Zzf4DA9UfX822V6D',
#    '2mzlyJ8Gb8cFMJvfENKnJQ',
#    '0ccUI8Zs25jqWr6vhRGfeQ',
#    '3pU2KkdQkI0lVjVInjFhgB',
#    '0gmYtRyuvRKpd6cCApSDTh',
#    '5jbDih9bLGmI8ycUKkN5XA',
#    '6dlikXSUYtmt2AviTTZuwZ',
#    '0YNnj5LVDkp3pU8uhP9Dt6',
#    '4BRlQ1wbTPn7so1ujJTzrD',
#    '21kOVEG3bDCVphKhXL8XmQ',
#    '06fpohb3cN7BzTwqC3M7eY',
#    '10sX7AMZOVbM2N0FruoDZS',
#    '2QpGZOhTCHHiKmpSO9FW4h',
#    '0oSVZClSSfn4aacXvdmkuj',
#    '1h6OiyF7bf4jifbw1s7mVD'],
#   'energetic': ['4pLwZjInHj3SimIyN9SnOz',
#    '2BSbCCbaSCzkOEZa6N5901',
#    '2UJwBbKGaqbh0pQZa5oGzU',
#    '43DU2GT0RZcYQC090D8BIT',
#    '0ytvsZOerGzUWfHXVT2Sgy',
#    '40uMIn2zJLAQhNXghRjBed',
#    '616cbA6RE0erFWHfzbYj5g',
#    '4apiNNK0jp9uqn3JDG9My1',
#    '3YeJXuRSNS5FYwOsDu44kD',
#    '3x9RokAqos6LqGni4E0TyB',
#    '3sI0ekqQTE7NxdZhNFqF93',
#    '45Egmo7icyopuzJN0oMEdk',
#    '4xIhSUJantE6BMl3u8dtCJ',
#    '0qrXdF1LXfJQunk6yluzsp',
#    '1lUTmmPMAsxZBR2iK9CKDF',
#    '5tkDCf3xKRZjT5RbCb3sZB',
#    '68Mb2yMSgziVn02a0y3LXM',
#    '3qzSfoByowr6tDfd08b0T0',
#    '7CWiWkccuRRdrmaW6AjVEf',
#    '7beAh9FEDhV8VUQ39fwDyf',
#    '0MrRAUcB8AZiB9ue2VOBYe',
#    '2RI6gyxYWRQgvsBqxNgiJB',
#    '2KeKdCw71RYkItxXeW0UyQ',
#    '3PLMpwjYP0l4Gmu7fsTgw5',
#    '3QqJ44HiM84iyZS0G2IKIP',
#    '6x8V3kUNlhVbwRbVP0QeSS',
#    '1YcwSSKEENaYtCnO4QScR6',
#    '5yDRQtYFcJogy4UZqrhFT2',
#    '6ViOxqq7aLe3lnfVTXH8LI',
#    '3doVAxeH3SgWtlRMqR4eLi',
#    '75L0qdzRnhwV62UXoNq3pE',
#    '6S0HcckkiDavLekQGotRSM',
#    '5yZfUh5T1sQwwjVqyfP4wz',
#    '4m5I2K5aWgqdFQx2KHe6AZ',
#    '6SqqsrQBdYGNuLJzo6oRQY',
#    '47IySiC5o08gz0z5VDiH93',
#    '30MdAjBfVTvBCS3vID38At',
#    '2Y0wPrPQBrGhoLn14xRYCG',
#    '3TvhKiqTMRNPQ1Af0pWD46',
#    '12NfmygEAtGPW44LNftXvo',
#    '6OaVWaGfhXn70ZJfdVcabn',
#    '2c2csx4OTYtbkzvbSTXlGY',
#    '6gNebIZdqveOrVehCmgE8b',
#    '5cgEadiGKjtTP1Q6NJqVP5',
#    '3zJTXgtzn4mr9YYanvSGfp',
#    '31yydnZnSeCwkRPY7tlgQJ',
#    '2DynJ2cNsW35sTJCaRcb70',
#    '0ulSIUvy5rSdkTEgUbJzm2',
#    '0LElIcqYsk9bkk8v5EHVbc',
#    '66CZET7xIKKqfb0gkB8Gy7',
#    '29TPjc8wxfz4XMn21O7VsZ',
#    '0dWYd84A57fPNoxv8OFwCD',
#    '3usM520kfIRpWNaYOwdnYI',
#    '7lxZbmtC6SkUc2yXBgDOdO',
#    '6HMHgBHdLBQ0QYIaOp2gse',
#    '7LCe5qMTozrYJIizGmR4Vj',
#    '6GuySCC2oW1eIQmbBrUVc9',
#    '3PfIrDoz19wz7qK7tYeu62',
#    '6WrI0LAC5M1Rw2MnX2ZvEg',
#    '11KbfD4E69jI6NzDih7iou',
#    '3BgL0IcxKAd0sukooPIVhA',
#    '7uzavrfBpzCfMgmSxcq99U',
#    '7aMCKdXjQAPV8g8TETYVEw',
#    '2CAqzumDVPlw6oNM8G24ty',
#    '1gbUrCmsJchMppBeC6wL3r',
#    '1oUudyBYVGMIC8JXeIsFzq',
#    '6vkczNPCftHsMJpjYYiXDp',
#    '6bMIExEulvwM2X6zsuiYwr',
#    '1RuedKcesWSjeRbxUrFVWp',
#    '4G8gkOterJn0Ywt6uhqbhp',
#    '4KD6CYSCX2m3rxYdQQuyYP',
#    '76peqTD79xDzySA3SyWzs5',
#    '59K1LiDT4btNGyOekA1ghR',
#    '4YqiqOr3raVtOeA0moroQP',
#    '0JYAsQJWIuaYUvZGF1qapT',
#    '1Knctxx9vGZxpZfF66BIEa',
#    '195gauSXE6Q2IKmCrarHut',
#    '0rZ3xYyjHM9B1IBD9ixZ08',
#    '0dkajDxFMp5FT119B9dy3C',
#    '3cvy5GqiSoyTtPuJhByJF9',
#    '5oeKHrUHPT4lUKrDRVlWNp',
#    '58TaFP5j5i9swOf584yon2',
#    '4Mw6KRVlQE0Pvcie7cslE8',
#    '49Z1VQivkHoY5KGdUwMv5i',
#    '0adOv7C57abcznr40leSHx',
#    '500mvzh7TRZ0YdnVeHhj8b',
#    '7cpnqcFMN6Z7yiSOZyzGMU',
#    '3kCwyvhvVTyehIzYN2I0nF',
#    '7bIq1v8svANsAys7I694Up',
#    '4yoQbSPoj8H3O8M3EKvC74',
#    '7wD6iRghe6SnKHkvHqpnC5',
#    '5DTOk0tCrmicVQP4mc6hkr',
#    '0vjeOZ3Ft5jvAi9SBFJm1j',
#    '7z35ELbZv0zResMSqwsoKa',
#    '3QT7ruZDodBTndp0q0EpW5',
#    '5KNoyjCDbXVPhzAX3CZsnC',
#    '1gIFVl1aHTD5A3TPKtOTVC',
#    '0AGKwYhuXJmnZtPbMdV1Lf',
#    '2KpCpk6HjXXLb7nnXoXA5O',
#    '2yuNnbs1GxEROw5sX1keGb',
#    '43IfdE75ficQgsI8QGBvwb',
#    '4Q8aDd3H6LF8t4eY7So9O8',
#    '2yiEd5N2cj6BwxWFNIIHyY',
#    '1EJIcDYXwSqipW5dFe4uJz',
#    '7cQnIhLin7koR2sO2bt2KS',
#    '1PVza5KmhSJhz12OewWciE',
#    '5NQZ43por3JzTMIsq4i8aM',
#    '0dQO6DOVHvrfl7DQwO97RE',
#    '2s4fNa1Rqam7rGCSn9Gj1j',
#    '2AUdkFhVlngknqGHu30VJQ',
#    '1pChm8ih9LlKhWncBJ6HLr',
#    '1E0CZWim9mfwrCkXvieES8',
#    '43HrWjjYGP8kXqjThk618V',
#    '23JWyjMJe6snyIqlORwLyH',
#    '4VLTxHOyFX5FRtkpsFm5Pc',
#    '1GxHeBvQ9935Dd3cSfsfBa',
#    '2igwFfvr1OAGX9SKDCPBwO',
#    '0ou367q5bmco9pZNxq80iD',
#    '04MLEeAMuV9IlHEsD8vF6A',
#    '0DXgUpuBTX3RqJS7iM59YC',
#    '29uWfSrklmIxzRIqFFK9jj',
#    '5vDvBD3ReINP8dXUplj477',
#    '5En0gXQk01BaWoT4q2oVbe',
#    '2WwHWskRBGBVKB9AlWKy74',
#    '0eXWlSwrzgd7mtFZQr68LW',
#    '1i1fxkWeaMmKEB4T7zqbzK',
#    '4dTaAiV9xFFCxnPur9c9yL',
#    '7pDUFFF3J4WEu1aZMW4M4b',
#    '7wqWSTBpYjsFX4JDDQaU1w',
#    '3fPdf6VIr7m3CkPh7HwkUf',
#    '5YqROUcia3lfvIrk1nwh9u',
#    '26UxwWl9xCb83OynXELJcL',
#    '4xUmUCcFfX2ynOAQTCdWgs',
#    '7jmTA4qUoE3powcTpw3dvF',
#    '7a9KeRj8ytHFboSE0jUS7V',
#    '595Sl1FDWMXRUktv5LO2gD',
#    '4O7oKy8YADaBrbehcPl0kE',
#    '05KfyCEE6otdlT1pp2VIjP',
#    '3wYOGJYD31sLRmBgCvWxa4',
#    '7Izh7zLJGw1Nscd62Exxj4',
#    '0pqnGHJpmpxLKifKRmU6WP',
#    '0WwrwEmAXGy6keX7noxBYO',
#    '15LOSQ3z91ZB2wMiMhiCjZ',
#    '3IZWCcD1FYpyeY3ki2VUmL',
#    '36fmvm49vZC9VM5X2DQJVe',
#    '2onuiR30fndsiwnY4FR8wi',
#    '1iA7DyrJbukpd4X2EcT9Xd',
#    '2V65y3PX4DkRhy1djlxd9p',
#    '5hVnFTUmD5oa7Pl4ltn6KE',
#    '226FfuxQsS6SZhgSGUPZvs',
#    '0SsGg0Hr7mrH5rxc4wldwU',
#    '4YHUQw0i3O5YTu8sqyl3XB',
#    '0h2ZSu1j6YFsGj85eSyrI4',
#    '5WJdUrZ4ND1TCZ2AsjYK3P',
#    '1NuhAA7NeNwrWcsBh9z8R8',
#    '0AmjoOwf1G8MB8SEG1AOGi',
#    '4kcJsfPTr7RCrLQRvW7cyj',
#    '01c3q4sZFA6zhHwMd03JUW',
#    '1s9DTymg5UQrdorZf43JQm',
#    '1HiJBQgR00UltPnoRWHjiM',
#    '1t0cVl9nW6zkUeow0RCLqA',
#    '7hZoTr4ffMGqm9opMiGmBp',
#    '1xzBco0xcoJEDXktl7Jxrr',
#    '51rXHuKN8Loc4sUlKPODgH',
#    '6Vdyu21iT8qScU1haSjWUU',
#    '0hCHNYL8ApQCGNwJrYN1FY',
#    '1bIEvOOqf2V3QBrFiClE3Y',
#    '4KYS9GK68yeuUJ8vJfPxrq',
#    '3tdNc3VqekiQVPVscWO7YR',
#    '0SH9qOePw4DuYpRwTabyeh',
#    '0Tcw8w9pvPrZoORgxsNASW',
#    '6R0GRYk2vs2XuBVemYK5YZ',
#    '2iUXsYOEPhVqEBwsqP70rE',
#    '55S2PQgSMYAhgoTCcGCDfw',
#    '5tLPWQUcUHvR8kRr8k33cl',
#    '7zBQRGpYImAdIZc97FNj3V',
#    '7cOlTLWr211iacbtV1yMUV',
#    '0ITaSRuI0L1RNL7ZNYTTi7',
#    '0oO1AbL92F6329z13C2qQH',
#    '2mhD6IAZ7oGdRT8bzFI5tF',
#    '2h3i5tGUl6hMu572umjcGo',
#    '69DXEorCMxRNzWf4ozCP1S',
#    '2Wzj9xKdzuaTI6jOj5VPG1',
#    '2nw52IaHkc54CJXcAjcyjy',
#    '06LFFPPS7MylCZXps3cO4m',
#    '6uwjDA0Qi6hk8C6lPJIMc9',
#    '33gwZOGJWEZ7dRWPqPxBEZ',
#    '3iDtphWASBHIjVEB8lWBqs',
#    '6kp0inxIexxSiDJfWqq0ZL',
#    '6asMDae76R5jPI6vQJkwwp',
#    '1NF9EkR5OpMaoVWbsllcm9',
#    '0FA4wrjDJvJTTU8AepZTup',
#    '1mMvahhW2Oz9waG8UTQnI4',
#    '1viUV5EGlKGCiSveBfFeQg',
#    '4Gcv5SsxnQWpmOnUI19EJk',
#    '39pS70eeDvyCAF3t8NAlVV',
#    '4ZkQ2t966y0fmTW6TWNwR2',
#    '3QybPutx0Tjk472bBKjNWn',
#    '6AoHQqGnuwFk9ygWhzLRws',
#    '6wXgnhpmOPEJ7cUweSyy2B',
#    '1U9bGQJ1od9iVZ9RKL58fb',
#    '6rv93pYJSTtReQIuwcCYvm',
#    '72EgPk2yUz4t5eB1CR1r5I',
#    '4TpXLhpLYQPMHM1A8W9J84',
#    '0GDVj31c8AxWXjWFzVFu0d',
#    '0ZXdzaT1k688dkpNeEgQiV',
#    '7A2mYfiUEDz9h2Rs8Ls4pO',
#    '7GW5CekZY8n1ZBG4NK9HKQ',
#    '4f1QbCjIAgQwnf7ms9NXWx',
#    '7ef4DlsgrMEH11cDZd32M6',
#    '6YUTL4dYpB9xZO5qExPf05',
#    '3dlF2OdiChtkFaW77NBAiW',
#    '2a3SHGbb2dPU4TvbfpMWJF',
#    '0v1x6rN6JHRapa03JElljE',
#    '3qkBZ5HegR5YzxGWor650h',
#    '22mek4IiqubGD9ctzxc69s',
#    '02tPSjAkST9flQ1AlevaUF',
#    '478bNaXnrz0uF2AwVl4gyT',
#    '0HSqhMUh1BoMKfLY7Hnhzi',
#    '3yD2LWeCCFu7ybBO3lwbXM',
#    '2tOOcDDYkh0PSjr6GwPEAJ',
#    '4u4NyuceXP7Uzh7XFJKCr1',
#    '1NHlyKgtR4roNylOhidKSv',
#    '6jtNk2zqbiZ9S7l6Gcp78A',
#    '6HicBL9RxtWwNK7sS2AHHU',
#    '15oK0dIiG9xeYU8gk2DB4m',
#    '3P4X0Xg0YkOnmfgMZ3U7HH',
#    '7hxREMLAebTcuadofbuyJj',
#    '76PwajqH3ej4hnk9tgaJpp',
#    '3zM2prB16NRn1zggh1KCY0',
#    '753DZsGGXlasRCp48FmOhH',
#    '5FljCWR0cys07PQ9277GTz',
#    '6s4T0UEJs5kX6EsEjvfXpw',
#    '3tTpvK7QgjjQCKGnHt5xn3',
#    '2xQlFQeMuiyOEP3hNaAyfG',
#    '7cG6SxmQ24hQWnR8UThrk2',
#    '4sWGHlZGM1XA7TyWdtBAbA',
#    '74styyfb7QzIjIvxeyNylh',
#    '3Zcv9IeYgCvEhxFTfsduaQ',
#    '22WV03i2lBbwNVCE1g671p',
#    '6nO3tr47nr2P7f3hXb8JIo',
#    '5NiqIB4BwRpoU1V6U195OU',
#    '0azC730Exh71aQlOt9Zj3y',
#    '66hayvUbTotekKU3H4ta1f',
#    '73yiAXig9qPlUYYAQGTT8F',
#    '0bH5YzmIgaQ4ay1t89eMAh',
#    '7wBJfHzpfI3032CSD7CE2m',
#    '11cCVYamncF0ezwjj1irQ0',
#    '0y3XhtLCvwj7weWmVfgIPs',
#    '5bLGQqcpsz5ISWeihZfJnR',
#    '2N6qMBL0E2G55pKKmkCDce',
#    '1nBlR1MbfZ1nLrecwVoLXE',
#    '3f88AK7TqGIxaTjb3EdxMZ',
#    '4NT8MTxwf9wvZ4Ui36x7O2',
#    '2YzmfPLqUx5CJOaw5ThsBV',
#    '66DHk2u2skPCoKT6N3oe8b',
#    '7gVwgc8b3XnO87TpmXXFA5',
#    '78JeuUoX9ksZhU4tsR1NNA',
#    '3lz2JgAt4cyr04qDlBgTOv',
#    '2rb5MvYT7ZIxbKW5hfcHx8',
#    '3Kh9eZaRwd1teXFVOZ9xPv',
#    '0c7K73roy6RW4ebDkf4yGh',
#    '4VQ46sRJtb6osiD3xfYGHx',
#    '1BZdJrCYel0jMNmKY8KkUD',
#    '20dP2DaMHIAmwWAbp7peSr',
#    '0jQ4mEnWB1AuSVqnFLhxT6',
#    '1X6xn7VChWG7fduFZT56WB',
#    '6AyWdCtEn1DdxjnxPeojR2',
#    '5Jq958VQwRyQFujau4TMKD',
#    '4trrKVzHcXRV5Gv8YAf32P',
#    '1IeCWMwZs4rCmwPOjZYWN7',
#    '23lerLvvPlJqcFB8ZEDkov',
#    '7GX5flRQZVHRAGd6B4TmDO',
#    '2rUwQj4SWaP2anuGDtNpYR',
#    '4afMG2PlvFfX976bZJvHmb',
#    '33zbOXJSwW7uf4VXXWow2O',
#    '0oVxGuRMnawFgA8aduocfc',
#    '7q8cy4uoA2itYATsKeXhcq',
#    '64wdPpi4OeCQF4W2oMZ9Wt',
#    '6KOEK6SeCEZOQkLj5M1PxH',
#    '6bnF93Rx87YqUBLSgjiMU8',
#    '19jsYX7bQKkNmBJPp4uOBj',
#    '4RgoqOBE34Q6zZj8K7RUAx',
#    '6AomCkEOQUODCYzQwH4SWC',
#    '5Xn4IyTtW6FUGIUyWjbUHG',
#    '5WQQIDU3HRaMyPkob8mpFb',
#    '5FTrzXtDMz3adIbLmVShk4',
#    '2gZUPNdnz5Y45eiGxpHGSc',
#    '6BJbOXDlgVAXSaq6wYFYT2',
#    '4L1YNydoXxdghlcty6TCV1',
#    '5jCa1A0ZfkaWcKGsJZQ0kz',
#    '0GO8y8jQk1PkHzS31d699N',
#    '0hGH0S74Eoyv6mXZcOKtdQ',
#    '5YafRUAwbPTPVPK0hbr2bA',
#    '0JvPpTwwD1tu2JCyI2Ojbm',
#    '2brgW2rPRbY5Zn0aU2USgc',
#    '40Zb4FZ6nS1Hj8RVfaLkCV',
#    '4eUsMWZO1Dpc0lQp4JsKXa',
#    '4BWJNzmkfUWu6jF8HAeLEt',
#    '6E1ILfm6wNkA6kautk3mQP',
#    '3k9vMJ09zyVP3N2pi8Yzj0',
#    '77TT8Xvx637TpzV8kKGkUw',
#    '0lHAMNU8RGiIObScrsRgmP',
#    '0PkgYhLpkevv1kh9LKnNxT',
#    '2il9NDpW87Hk2L9AjeDf8r',
#    '3wScL5W8H40zzCKN0atfBk',
#    '0tQmgwFKw9069z1BXniOiA',
#    '39LLxExYz6ewLAcYrzQQyP',
#    '6e2kwYm4qe4hFbOkLm4nbF',
#    '7DwcBgdzqhFJltEaV1XF81',
#    '6UHfW9PmGAUjIVeIkPzPQ2',
#    '5hXqurVR1oeDhMjDDtxPNa',
#    '5lxQ9BW2xOzgRIxQAZzHSK',
#    '1GGxh8QYLRZaQ07d6AHA8E',
#    '7sMu0DXeCVYwTivw9kBl99',
#    '2kimLa9Di1xK5MpZSxJhRy',
#    '3wAbP40X5P9EVWkwmszInb',
#    '2qvc0vB4AAW39DR9j6vXa1',
#    '42tD9J0KCPFSc1d2hFTvAf',
#    '3UyjIh2AKIz5mzjzcwDfP2',
#    '3LEztKH305u3WRpqKdG9Ch',
#    '0tKcYR2II1VCQWT79i5NrW',
#    '4RXpgGM7A4Hg7cFBoH5KyF',
#    '1zB4vmk8tFRmM9UULNzbLB',
#    '0JjM9bKm4wrwohMslcm892',
#    '57IRaiAB4hBZu3gnNVZC0v',
#    '7J6bnDDitOwfelaJNixHhL',
#    '4FtxvQmm0kJPGCIQwaQ5eM',
#    '7H0NHzIEzCoIENLC2o8Obj',
#    '1unFtbwcAnSGgYPmp52vc0',
#    '0hjLM1wMtk27Qd4ZihyHmi',
#    '5w9c2J52mkdntKOmRLeM2m',
#    '6mCqxnyOhr4tHMbRbQL4Yn',
#    '17N5FdRwJuv3UXQ7MHnbhF',
#    '5wMh9hhqKQ4JfqLuvqAC7s',
#    '6bcnokzOVQxpn0quzHj6vc',
#    '0suLmBuEbatdochI4tHduq',
#    '1KzGwlHu27TUfH3gF1RFAa',
#    '2ozuygJ4A6g4Ig0otuuBsG',
#    '4JHfB0tPjE38N5KTSaX39I',
#    '4bPQs0PHn4xbipzdPfn6du',
#    '2tnlNVAhuQGgoFJxALVeXx',
#    '5r1rdd0eq780nePBvcVJHe',
#    '5kTQa2G88tHnKB1Y6vNTyn',
#    '0CBQ0m3mufWH75LTYB3s6h',
#    '6ZNo7Vi0TE9ul1fhKd4S1M',
#    '0pl50PBq8jXKl4Tg4tF7G1',
#    '1yrg59BEI7zSxvAXRcu7YF',
#    '4bhu77kvSM5qMzTXAVzsuI',
#    '6O10oTtZIZ4DkkUqyfCbrR',
#    '5FYvEl2ThSP9THRBuB1qRB',
#    '0urHaAHTNeprwQuj4QzY1Q',
#    '31UEIDEnR72bsUiavstcof',
#    '60wwxj6Dd9NJlirf84wr2c',
#    '4N6Mj4yBpbhmm4K7yZj14N',
#    '1eU3EhUwOa4a3qCM45HogQ',
#    '0TBHAzNgH8aMmJBtpzfMfj',
#    '2r4JRwcbIeuAzWjH4YXlLs',
#    '628Ueb4sRiXApObhcU9iPU',
#    '5iXr01hXAmrXkZxTeXD6iO',
#    '4O1uCappFiU3bisYUdUBWy',
#    '14246VCxRDGZHqlMlqWSz4',
#    '4Na2Xo5yQCr5ucwfg8EGIQ',
#    '6Na5uKk5SsqZimk0hAWo8y',
#    '3Jv1XgMPVjdN5xGfnRJ20s',
#    '558tnJm5He4f3aknOPXFAS',
#    '2m9axSosHP92250FvnnobM',
#    '2cRm43WgDFpOX0oqr6ujbB',
#    '3Dc7EiHP7aDOhTI92OQaKi',
#    '2iFv0UG8PhaNUNQA9RqMZY',
#    '6ic8OlLUNEATToEFU3xmaH',
#    '3EQ9QP2E7wjYQba8OSPBst',
#    '2EaQrkCOe5Esv3NWSnk4sX',
#    '6dnrppGRbt8fie18Lcd9Dd',
#    '5mqzhMuUpvnMfwNz6iepmO',
#    '7bTH8LgGSwyNNE4r1k95Zp',
#    '0xQpIxfvz2m2vmCfZoAeWp',
#    '69a3MMNcoDtV3mmMUcB7Ou',
#    '332glx9nLq3BtqoE8UjB9W',
#    '6YfTl5YupXOQBKiJJLrxcw',
#    '6GSkLS2y4ZnnZsuRAj975K',
#    '0PowxVSTY2uh1CPc8EPKyX',
#    '3syIqcdNRjbFcWkEMRRT1d',
#    '0NdouZ83uCi0bax20fPsN6',
#    '65ES1qwOB577ZnTkizMXJJ',
#    '4rTD34yd4a3ECP7vpkyFf0',
#    '4qxWose1KJgPDYQkMs0Ng5',
#    '39xWBHPM4E9MwzEy5gbM7p',
#    '6tarvNiKnEjYMj1VZhlDqR',
#    '527k23H0A4Q0UJN3vGs0Da',
#    '4YPHrO0jB8nJCrcSckSwie',
#    '2vaMWMPMgsWX4fwJiKmdWm',
#    '0fQlqbTeuXiUZnkmqTurOc',
#    '504JCx3dJov6Fi5083r4Hb',
#    '4tjA1bnIrvCt1O4uaC476a',
#    '6qLM7FY8SPWYIyKKhzzVO0',
#    '6YE2DSWUhMkJBZgWv17fv6',
#    '1ZLc7kRDf3H2myWdBsOAxr',
#    '1XKdnMOLvwsn4lHqj03JCf',
#    '7lEhOiFtcLXY4P7cuTKuQ8',
#    '7BvrETGltiKW75pwf7S1XL',
#    '21Uv9wZMze08ZY0JnA5JUu',
#    '3CDVMejYHnB1SkEEx0T1N4',
#    '3QGppKBPd9gHOgHJzRbVIw',
#    '0GTzZhS8P50p922OEuoNLF',
#    '2CxjDTsUBmVlcMjjy2UETJ',
#    '776eASGwFLhvAUYmWZvwrL',
#    '6NMtzpDQBTOfJwMzgMX0zl',
#    '076jPFqxYEu1me4zsTBWJ0',
#    '5UoyJTgMKccFYaqVArGSRz',
#    '1eLSF6HfrRA0AsNmTkUlKx',
#    '55H02yyv7Vad1LFg3kmnVB',
#    '3nJxqghn6qVTWNzYa5Syc7',
#    '0kDj5JHE7Ba3HaS5APquQV',
#    '0ATmjiSoHDCHeeQ9FcvZOW',
#    '6FXsrAH7Zol1jusSeJIoYA',
#    '6ctmKiHf2CcHQLwT7g4jpc',
#    '7zlcLBqNlVMPhkdBQ7K6IW',
#    '6oosMYrpIekDxg67SV60Va',
#    '6EvJeJu19CNdaNikmFGMgs',
#    '2bBTeoD8VGVCZsaYeGGlBw',
#    '6NX59eoHBHFBkyUcrvcwCr',
#    '02yaX0Reb1fQYIQdri4Ow8',
#    '4lay3Vtg4Y2m1ftaNNC72r',
#    '2b95n76DJVE8RkFtLLtnrS',
#    '4nKcjVLvu3bAf1o7KQsqSR',
#    '37MA6MjmCDzVngu7AzZI7X',
#    '4q6M0ocvDwZp0kbnWtYLaF',
#    '2hcohLIysMxofYziluXCoX',
#    '6epn3r7S14KUqlReYr77hA',
#    '2gahSUGM2ddz48vXK58fHt',
#    '5UsLjwBaTHBX4ektWIr4XX',
#    '75JwFVMnX88ypgshWYBSYL',
#    '6FSHigAWfTd5Zx3jYfehbO',
#    '2yLQbEOLNU5fttfVJKPIsM',
#    '5bS6VIBCYdi9QL9T1upn3G',
#    '4mUIe9gfsdtsVP2zFIl74x',
#    '2Xo3rLHjXfdb4avN68aQyi',
#    '25AEevSO1lu4EKMIP5Sy5p',
#    '0oWL7FTlaA1YtsRRuiF4Xs',
#    '4DyBx5MYoq8RsU33cEAIxT',
#    '5b3igc7LT5skrpVDiljtrn',
#    '6VkomiRtWhCiFs4nzrzNUc',
#    '79MSEdtXuudhGhC5AtG07g',
#    '4Wh3znTCMTIKAZ2stlikRX',
#    '4BtVYDiUSuOuOsupYAJJuk',
#    '5WptmsWwi6FEsTNxN1gUh1',
#    '0l2betcuO1KqLNUb0CxAdd',
#    '1TOHw1SZwZWX08ktFUei9T',
#    '20pxIVsAEvIxbKwh3rjIju',
#    '1OSVnPnIoHdJQmsGIaqRsa',
#    '0i3UeR2oAj9VORgtL0Btrt',
#    '3bFQS0uqG7zJ830fYLkKly',
#    '78ZX04BHxX4NEvDOEoITKJ',
#    '4ENtf8YD34t4Xu5o1IH1JC'],
#   'excited': ['6m60IwLIkZ2Fmz4J9FsQ1o',
#    '67lKDoCZbRCJDa4RT68eme',
#    '3w3y8KPTfNeOKPiqUTakBh',
#    '6gzIcEUuswJQGfJNPYMjjv',
#    '7DR532D64a7D1Fibb9xNU5',
#    '4scpF6J5uMBvoh6sFB7EL1',
#    '5R9k9x85lAYbamdUoKAJvj',
#    '3kfKrrqwD3j4Mx7mZ2hje0',
#    '3W3FVHEDetkiRkkGKDmdir',
#    '0wHFktze2PHC5jDt3B17DC',
#    '2qx64wz99OxqCJYgLPZH3h',
#    '7KlM4piqWaxB69tvnhlrns',
#    '3yP45ZO08QJUyBTo8HGHx2',
#    '1Mb187X5w3OUQNH6P5M28Y',
#    '2s6nFAzZLRAbKS9NKV7Mos',
#    '3RvLAm0ESbUOUZOD7sF4xn',
#    '2GZuzPEKD2C2cklAiEHJ7n',
#    '75FDPwaULRdYDn4StFN2rT',
#    '7knEYd7b0UcbjgChHX7QBq',
#    '3ANd471zdEaxMXaUEevi5o',
#    '0XarUcoGDMFuooo2tk70Yk',
#    '0Y7di9ZCmB6Elad5WISaPc',
#    '05r1GGg1Rhs0RcUg27C82a',
#    '3B1MRmyJCim6yVuVkFpBq3',
#    '4AFgK4wP1iD5i8BYaLr9Vf',
#    '3zxiTHxE4MxwuYf8aLQ9ax',
#    '1k9B8MqhGKbVV3dTpwUxn5',
#    '0rTg7hbhEYFNKNozvtwIDd',
#    '6urLjX35oXXRYtcH1b3dCh',
#    '2i4WKnGYntsN4jEvDjkKBE',
#    '1eEYbTvRWPEozV0ttNO0NC',
#    '3i01Zk9c0FQ5HA1WJjflXI',
#    '2u3EyuCqqV31woqGvO9LBz',
#    '3wdfLVUhmX64lIyWIIEW8s',
#    '60SdxE8apGAxMiRrpbmLY0',
#    '0gUGjvCXLxvLoBLXJVrUSl',
#    '16DHWSDlEa5K0JbMHnuMXM',
#    '7jslhIiELQkgW9IHeYNOWE',
#    '5de7ci7TFqbQ1PFgKAD7MR',
#    '15C4TnrrVdym7UykxQIOTZ',
#    '5S1IUPueD0xE0vj4zU3nSf',
#    '6XTetcNx1W6CKG0lSSnvrq',
#    '2lkWzRxQtNxbuoH9B7P22Y',
#    '0OTBOHjEaoqroFlfut1ZsH',
#    '5wG3HvLhF6Y5KTGlK0IW3J',
#    '0dIoGTQXDh1wVnhIiSyYEa',
#    '5c0Vl3yklw5WX9YI36dPLd',
#    '4xMKjbsbqtw7FgrGEdGtTk',
#    '0oH0OIeKJSAT5bdFkbz20A',
#    '209r8VXhRUVmv7A4VnX4fD',
#    '3fS0GCbLTLK59MYn7HYMNi',
#    '5htB2gxndGHrLb09x1Q3Vp',
#    '7w8SYlPLA9bqj7vRHvYNDz',
#    '6vxU64pcIuQ38O015Zy4qj',
#    '7CEJH5Ed7FBbXF6CqBQPlJ',
#    '0hPLZrnDgtKxrym1BHjDhd',
#    '70jjParnrP2X3mOVkoljGE',
#    '6ah7L6ijOMMlOabQzuJGUB',
#    '0E6PsO3ymCfUh7pJQjBgkj',
#    '4WQj82D2S58Gj0ZoKXWrBE',
#    '343YBumqHu19cGoGARUTsd',
#    '0bEa2tI3Pk6M6TWkcD1uRY',
#    '0JR7iZZ6Ql79sXW3rbiS3F',
#    '4BHzHISX21PYwGXiBEUQ70',
#    '2R7Gn3cjnPaVO0Oj8nsTDP',
#    '0TFVOjSvPTjFHkiZZekK5k',
#    '3wdnX9UwfyXkNq0FJVhQQD',
#    '4pXiV088jJbJzQgU9XcZXQ',
#    '0QBRshHeQLEThdj2TqxM9n',
#    '3jVaP8mvjBZdaACJPkV5PM',
#    '4vpMSPYvyk8ODGuHSyXTXB',
#    '1C8yDcVIhBObN58cSS8oX9',
#    '4ksuI04WMvUnJbHQjgs3L5',
#    '74iw3OCAb3it0SjOVw4Dnq',
#    '3jweuceENR5zzn10LhcjPH',
# ...
#    '6gP1JTKQELhAlPy3a1fPve',
#    '4ojVtI82vjDG9gBEE29YBb',
#    '41ial1TTDNlhaEuzpI5SAk',
#    '0gDMSJ8JtTjnAnROaM4L9w',
#    '04Uu1ZEM2WtDV7yBZA2jYi',
#    '0phEMdWrUlc1nEA7mAfJmq',
#    '3hPRkKFO5mIflYwDjicJ4U',
#    '6pnwfWyaWjQiHCKTiZLItr',
#    '7MQAufzAfMXFea5RbKRhob',
#    '6e3oGWsdfHSKBCFv548RRm',
#    '7rpGOF9MwCP2Oaz9yDO452',
#    '6lDhQE5NehNR4pizUh8B8p',
#    '60xGrKFHgLNpqhuS00HINp',
#    '7zjEyeBsaw9gV0jofJLfOM',
#    '4oNCXU6RZG6qpVDAfZUoEh',
#    '3vROTGlX31Rem9VaTqdBzS',
#    '5VWC7v2dC2K0SIIjT9WTLN',
#    '2dcOprxauIydtyWGbRY7aF',
#    '7yk5D0dL772D2gWePica6W',
#    '5jZHLuaKYFSrtqy3oThpLJ',
#    '6QpZXzHcOgXK41Y3YCx203',
#    '5iFHdi7BB0koNu8t2Ug82n',
#    '2MQhJVwdsmdfG5qK96tEHH',
#    '49K00nm3DD6HZwQg2I4HmP',
#    '1rkxyQH6y3qxysbYKo8yyI',
#    '1vlaBhPNXdqdhdjkwV8VCv',
#    '12avSWqQ2kIAtjLS9C2Vjg',
#    '4iKSrwTBu0vLSqmZUXSGXr',
#    '2sAg6ll1Vd1BxR8YD0lkRg',
#    '5QdEaWJ9fnW1D7lSjQyS8E',
#    '1ajtMxq2KF4B9eRZVUPFhE',
#    '2No1A7ZuMaBGxz45jmA9Gw',
#    '1oCPeGIQ5TpDYKrS4KmSTr',
#    '0oLQRGhq7ltPDF6ThfqQdc',
#    '5bUMUrnrWr29gSRy7UgUOO',
#    '1AL54jGmiH5sEn7OUIbVVP',
#    '4lcT08ARvK8cVjRLJbnKLh',
#    '4iCOzZYiSCljWB7D7t87JT',
#    '31ruOiu2IB2rkFOjkndL2K',
#    '7wfDCDfhVe2tFxIkQEJp35',
#    '6NnKLbuNprZyhHUUbu11HS',
#    '3jq1RpStaB1YGyN3rRZGca',
#    '3KBoMRQ6EbCiTzOCzy4pvF',
#    '6mFkJmJqdDVQ1REhVfGgd1',
#    '2o41jDa4T0QKF9804tqyka',
#    '2kJwzbxV2ppxnQoYw4GLBZ',
#    '5Hi8tZPoSgvt3NkZLbTIk3',
#    '0BYqfF118BfjcxvQRCwaWk',
#    '4OBZT9EnhYIV17t4pGw7ig',
#    '1RMJOxR6GRPsBHL8qeC2ux',
#    '32SebboTVV30b9Atx9OKFU',
#    '3tV3Qb9XnPitAk81Q12tlo',
#    '511dXUrzAfeivY8f0LUMZd',
#    '5TtfSQoBYHfCVPRS0M9DUs',
#    '4XBdcBdB8cIlJIipHbTd7G',
#    '58BB8I0IO8pxDkwuwWyEdw',
#    '4iD4tYNuSVN7Da9g8Epp8t',
#    '3dxpWPVR8qM5VJG0xzflOp',
#    '2vFMVP1Jo4LSO30RJO4Y7i',
#    '2omgCcDetlo5bsOx6Dcdrp',
#    '6GgnlnCWIw7QsIBFewAnuE',
#    '2dqeTHHeyLioSSCn9L3xbc',
#    '7AhQiikvGQzcr2Kpb74fLG',
#    '5zaYPmW3fWxDcPrGQxPsZ2',
#    '07niZTYNkvPcw61OX0YSR6',
#    '4fItBSHKBcgKWixN1Idie5',
#    '2TBEvyObvmpRMzkhxF2fox',
#    '0aZFEiDKLK2B4gzPaGCZVm',
#    '3TR4OoqzX947WgOxG1d5F3',
#    '0fOzbcpxqSgX5KhLwfdGyi',
#    '6Qu2SmU6jgmKNhefkWFW0T',
#    '51c5Wbzs0fPu6mwpDn3bsQ',
#    '1opARDDYaOeE1QUdwXmBGu',
#    '047fCsbO4NdmwCBn8pcUXl',
#    '13QU8HBEBaSTZGq1HzQe9S',
#    '3C23UChONVCL0A3U9uWO5u',
#    '4pOlyNWBQeWZwYoqnQHwEB',
#    '3IOXceWmoCrTyl5TXFDzWu',
#    '3RlwtjeKhemCfiPvwMFozS',
#    '5qtNshZntEZX5szPbTcSio',
#    '6XDJJwtxkhbqYWteeKS20P',
#    '1IeMXbBRCRAeBITfmsLIQw',
#    '50lP2u9FBdxwP2mHdaQ3DR',
#    '6Xgupx0XndCMdA09Nl46wF',
#    '1bsSaYmy0vOUH8tux2hAYV',
#    '02QoKc20zzH9A8mf25NfPq',
#    '4AMeTATGlTyPaPCRzpvN47',
#    '7pdF27mSDuPWhppnHAmWHa',
#    '6xcD8EbsvMep9ULtidHI2j',
#    '0pjOtDz1Sz2flmptUEnjmf',
#    '580SKYBPZ2vQQRcQogBF9N',
#    '4YS6FM8lct3QyV2oGIrCp4',
#    '6cyX6lruOniejnJWvnBmRm',
#    '5shRAbjr263aLdUb7CjpTR',
#    '6rJmWa5DvQ3Nby3tdcX2L0',
#    '794SxkpLERVaBoag5946LG',
#    '7rsRqxM1uneTiTKVjcxfPv',
#    '0jgfH1TWoXIC0Qk5x0Uerw',
#    '52Hq1nvCDDZ17dhgGWLnCI',
#    '2jSPE7R21ImtYnuINW8lcG',
#    '5Zejf0AVF45ZXdcePeghId',
#    '1hWZ0uScuJ6PSeoe2p4sKC',
#    '7pR7yPgbYcipmTUHT5g68p',
#    '3gece8Z6d0DiF8RX1gPjY9',
#    '241rchyLTZnB5A5FAN6wbb',
#    '6NTBj7CHsgxjWcEVZyhOPQ',
#    '3armidhEXA4Ky23Wj97pFQ',
#    '2iE2kMTElChQyFwXS2TEPK',
#    '57gfGCAZMdVkwxcHNQrar4',
#    '6OGSthy4oaSFBg1SNE17dM',
#    '12LkyDfAbUQ2MIJJpFAe93',
#    '7ncqZEutTnKNmxJn50URcf',
#    '77rt7JCOCjZvCLMNEIqoay',
#    '6G32q2ZZIeCraLQweRMa9d',
#    '1E5wZo0royZB8p9rt7TRB8',
#    '1zynLlNxb2xAyFin6GvSGC',
#    '1406pYm01nyJlM8JcCc7Lt',
#    '412vyUC3xYk6NtHvscmgXl',
#    '3vDlW4JNICUAN27xLrYj08',
#    '4ahEI4QjOwmT4z8PuZZYDk',
#    '61hOggobh04KVuPBt9UVUN',
#    '250kKNENGupd95mJdQPXsT',
#    '6rzBDEJ3V3VRuc42OeRe9f',
#    '7tobQQazW32ZWVzc6yTLSY',
#    '6aaDGpzsEJCke8qwMVgao0',
#    '75HUZv6xss2ADArgzuCsYL',
#    '1wcTYAqzjCqssBtpfyc1wZ',
#    '2D9SmqzzP87eOJjSFPIYQJ',
#    '3cPPXnokX4NYz3iTr12aIP',
#    '1i1uXh6JNzYxgmKKZRKgMA',
#    '13V0lxxImhqXZrm8610JnO',
#    '5OqkQteQRQBSZeQXBbY7a6',
#    '5bJwIC3hWM6j8JYAUGZ4AV',
#    '4tfaUHGYBCMliBaOHM5vHX',
#    '0CAXwqDURV3HNIcRBo6q0H',
#    '19AiqwcVZDgbivDpLwZtG3',
#    '3VL14259GNhtTvxA9pAmZx',
#    '64VtmW9P5rbYb0y6btPCNg',
#    '0oXl1pTqskTdXuu46tPCJm',
#    '6sV8mjqZTDnZA5qMz5RtwF',
#    '7KVe6IuWMG1Q5pcmmUOev1',
#    '170ZmbYgGk5kSb0WwFarSS',
#    '2P5hbyBB7LhOaJ2HM7G6Eb',
#    '20twYRka7o68mw3n2Ggz46',
#    '2kRzlPRExNaBBsIANubbHg',
#    '4OStFivEWQbYO59CgEX98f',
#    '6TfvZnvS172wKpSj2S88XV',
#    '4NBIMXqhYshVmoxHHvsmPi',
#    '00oSY6ZhNBI9uDf45e6VMw',
#    '6wfUNH1FO8FcDhvxq6rKuS',
#    '05FuhMHmo0gi65Sotwj01c',
#    '7kfCTnxt6irtsSWWbFib62',
#    '1zvi8dfPE8N05au0znnRhD',
#    '1JSyfYEBN3eYwoaq0mum2w',
#    '1OebpjXwPI4h0tjSHe4YCR',
#    '6BtRHhPR8PcfBBSAsY0ppd',
#    '3vfL95KQ53CMmT5ceVF5rP',
#    '0mEtQh163dmE6NjbaPqf6o',
#    '0YAkSCPXn1yJOL19rBhWFc',
#    '13hD1a2szZHuNLWvatXhNh',
#    '0pAZwblmzeso5UGoEMwXEl',
#    '1PABTmSsFLvGZU6mHno48x',
#    '4n5WEddcRzo2BRGQbvmPwv',
#    '2ThtkgGReOtvMsOuoWZoub',
#    '3qSuHSjEYAltq1AbZS2UGG',
#    '0iSaPL6ibq9y3Kc6gdr6vb',
#    '4eiAkiGZr0w126YOMAtkxz',
#    '4QuwfknVAmTJMTHTWbrGRS',
#    '7dLCC0addn2kO1ALxsjQhS',
#    '4tBYkfHXgFCiMkFLViWNGh',
#    '5ZOEulH7fvK4ZkMLTOyKL0',
#    '0vx7bNNgm1wIAkMK0CjloG',
#    '1kGX01yhwMRuuyOEd1H4OU',
#    '0Lca4X8ywapByHnAc09r1u'],
#   'depressed': ['6eKQpHfI07oX6KEJRGWDtl',
#    '4gxnTpSiGsXZNXlABEQHiL',
#    '6clDsO8HwhHEgJDDp88VdL',
#    '53sTK6KBrvsuqKT9qNpS5d',
#    '2hv3PVAj6KKDOVNhyRfjeG',
#    '4MzxCIHY6TB9amFIvWsO2V',
#    '4cQrSREMqBSvJ8ZzBZjVb8',
#    '7IeHIGriFrJaTeaC4W0a8W',
#    '7F9cT6hIRhnFCYP6GKS0tf',
#    '21yRtB6B8EMounImAfHRCP',
#    '3fSFZevUlT4vL98gPY4RP1',
#    '6LcX2hBbXaJcK4AuefE936',
#    '7iC56CDz8miPDKaH0OEIqS',
#    '0rTGcusBUjObmSibg0gk2F',
#    '1X5F8qFnvUe4sYmIqowEkB',
#    '7jaR6s7ecdDr7S6dsYyM9s',
#    '1AHf5FSofKcUw8tyKkccKF',
#    '1v1IXPXl73Z7zy6f5tUa9n',
#    '5Psnhdkyanjpgc2P8A5TSM',
#    '5o54O3MOnMvcPTmkguYkwg',
#    '1FmdAhS8FqRoEJ4jcSfuKZ',
#    '6sPmJ3MMmFSaPybfU86gf2',
#    '29t9XYOV65fFXiVzFFJgHH',
#    '1JXBNvlDEl2epKSJ9EOgKX',
#    '5b2CRPYt0QNA0jaCJNIIdn',
#    '08bymSahrAUpabFR6YSiy9',
#    '3ZPqsNlUyRHebbc6r5gSDD',
#    '0GMxsSQhO9Yj8aKhN8ljFe',
#    '3wAI7MIQtTgwcRmwchPZBc',
#    '2LvpVkv0z8oFMcc048FfJd',
#    '3j2VxSCmFJcrNZ6QR7e8DR',
#    '3o0nkjyy6eZL5lZcEpvJec',
#    '1njRzdfGNUY2RZU0lVO787',
#    '364spZLB5bhNlnPrzvUB41',
#    '4hCyhlDZteeEkLzllLq9ur',
#    '39JRmdKFka1Oe09FoOCPI4',
#    '31suvgK8vvhfVXyEa2JpH8',
#    '2hIAYj4280fqfNCmGhHWxN',
#    '7AZbFMT8zbbUpDBWMbOg0y',
#    '4ze4eAFojKY9e3QT6xNRNZ',
#    '2kYB66omjIRkqPx8zRPEAH',
#    '29Qo9u0DWEmpnjV3ugcj3v',
#    '49gRLFjmdkS6Cip8V3MrMN',
#    '4CMrdHWqic0usIZfTrKoI3',
#    '5yJRY9n8VlzqGzOHOZHCIA',
#    '6TrjaOqUwdKQ7KNxJr2s9Y',
#    '1Nwnj9ugENubiCoq0Vu1kN',
#    '42kewiCM6QIdTn4I4rjCPv',
#    '1BFFcF83SmsS6cKBLZGjkc',
#    '4lFfMRH0YH4pW5gczTDbNC',
#    '6lAsOTYy9HNXccda1MuDuK',
#    '13ZrmNuuuAP8SNjJUdVnqg',
#    '7KZ5MMVgBVox9ycroB2UrI',
#    '2uEoDYyEG9LiR43vsnaoPm',
#    '41GmT2g8MpZ5F9IKbzVAc8',
#    '0z745VvMjQZnLjnZon4OHu',
#    '4Q40ZOINE8zsLJE3pWIqix',
#    '3my5W7QLojCSj3E33eehcP',
#    '7cfvP13Bqb1EyCZQiYsLum',
#    '5jRSCdszeggflE0vSMXhzd',
#    '5QrmygpdyE3IbrZzJsZ4uj',
#    '668vMRYpYfpLsOvWc73umT',
#    '1D3z6HTiQsNmZxjl7F7eoG',
#    '1bDbXMyjaUIooNwFE9wn0N',
#    '4Bl2bWpteL5TFmqQ22IQXp',
#    '735RSTb2xbtWbDtKD9XDYi',
#    '5YwzeiG4Rp2TdO0kLuZYmF',
#    '0d2iYfpKoM0QCKvcLCkBao',
#    '5BEXgUaHoYhWJDHAUjFwMx',
#    '590bUp2TKTfTS9NfiD4Nmn',
#    '2m1JKNrEQA37VibuKSMJEH',
#    '3TOfcOKNuu6ZPZXJie5msH',
#    '7B09THlbQE2RndpgXeXQYE',
#    '5cGpjfgAvidLy6znwkCxkP',
#    '3LJ9K5bM51xsHCfZMA8ybQ',
#    '1O2wgYfOdpcoWnZbdbrpMh',
#    '5A8EYS9Z4hz4EmtU8W8kI3',
#    '2pBRmrQcEpawTrvWerNB9K',
#    '7AscpVHkhrKFCs9PCLZ6cK',
#    '4Bhdiu8zhwQR3tXy8YMbCj',
#    '6Jc69KjFo9QNailcyDJh2I',
#    '2VYb3Fb5iK5Y8HGZ8oEEkp',
#    '0pxYbh4Uf73JXJ0qqEinBh',
#    '4XvcHTUfIlWfyJTRG0aqlo',
#    '6xWoRNrT0nckMqq6yGtTNH',
#    '14c3REraRhuk9oW6WsLkvm',
#    '5hChuUMe5iHfjkXgzj1D4b',
#    '5PkZ0mhNgfuz7SqiuruKlh',
#    '7vg47qMIEdLfNdTE3WLf0T',
#    '2S02LvvwUmD4I4AIdpWNFR',
#    '1VycJxkDtBSEClyVPrIlWT',
#    '3TVhQk4BP6rQTEovefTpNO',
#    '4mQEVCbtbQuiOYouVR0fcs',
#    '4KXwFI9pgJLpUIAc9oSL8j',
#    '2tJulUYLDKOg9XrtVkMgcJ',
#    '5ORcI4U6qYkU5JGHjkaDzX',
#    '5y1KNlbZ1RAfq7tUIWvH2a',
#    '1Zm9qGPQkTAOBiVpGSnJUq',
#    '5259GVdvIOBkcqo6L2i9qw',
#    '3Z0VsaeB0yYjZwhtiKU0td',
#    '646sbFnyVg1trhqqxqFUJg',
#    '1q8DwZtQen5fvyB7cKbShC',
#    '381cpx26XrMnGOIn4faioN',
#    '37b1KAbfOZeBzeMB0LGO3g',
#    '0AFVQA2Ht64OzMAer4aQ8n',
#    '1fJL0EgvPrLIltnF0d3CbR',
#    '5CXwXCS1EPnsroRTejHCPo',
#    '6LhB5o2iWjJgNHqock5H3b',
#    '38PCpNNE5covoh1X06upVZ',
#    '48wO514aWq9mxrItf3cMXM',
#    '6MWtB6iiXyIwun0YzU6DFP',
#    '4j9G1hsYMHg3n6OBG8AQFS',
#    '0OO9jCqG2YbVgOyZwqEPFi',
#    '7EAI848gzAJpFsEmk6Wi3c',
#    '7nUpnjXtqjg7TIM4Z4QsmT',
#    '56mGsbK1GfCAx1yXjWNcVY',
#    '0m1KYWlT6LhFRBDVq9UNx4',
#    '2C9FM0zZmWp4au1kWwiqZ3',
#    '03VCOcBXFc7gM1l7ofu9xN',
#    '4PbbN26iyzG1ln8X13cMsr',
#    '7DyRfspnGYcUhCAMcCys2g',
#    '3sz2fvkHUhBip8r9i8HqeV',
#    '3nfARfVxSqwFahp3yY53aD',
#    '2hFiYxiRV9pxM4BVATrKeX',
#    '0hBmlHuZzZFcmzUZezNjZQ',
#    '2PlPzw2QFgaGfGNxf6yxf4',
#    '4HTY26kzdGCKJF1EqcRd2J',
#    '3JkGVbWxeqe7gIUm29ikQt',
#    '26NuFmVxFkx2ay9WGm2aHO',
#    '5IUtvfNvOyVYZUa6AJFrnP',
#    '7uX3gufAoBVqKVoD3dBLLD',
#    '7yk8p6zfqIB7fQHPOQ96z8',
#    '63DiImCcNvTjsUjuB7NUFN',
#    '3xXQCt1vfzNEOndrrNWAZR',
#    '1YErts2dE9oJUEL4jEaMsg',
#    '5O5KFUHXR0FvOVALp0xXlc',
#    '0eaVIYo2zeOaGJeqZ5TwYz',
#    '6jEalPiRaDXevCvisy5jlr',
#    '48KXAIruJ07kJVCWOGohMV',
#    '2f4mTu5Y6I3wVApqhy5wbV',
#    '3QqLveYtC7IX8Bj1HKQujA',
#    '6dMVt3eEucCuzaGfZ527p2',
#    '7t1lBIr3WIEtqQEOdZFMUf',
#    '6n3HGiq4v35D6eFOSwqYuo',
#    '6jueLmVCD826bJYuxSIfsm',
#    '3X9OVlc4YaL9nowxAVcJex',
#    '6RIe8KbX9YMO9hFSuowqII',
#    '5jbOCsyeMKNxw2Xk3RSylS',
#    '2bwN9oZIn9XXSd8RlJ4FDM',
#    '4p84O0MyZpSChLOea6HwM0',
#    '0mfCH4nfpshBQR9ueZP5eP',
#    '5YA07lAGP1uYJC9P7VvOUb',
#    '7aJwamBFV2pjHTXUnlDgZb',
#    '2Lrs9j2UlkyXghBPziYNCC',
#    '0203aGEIzVVlmvQ8lX4fmV',
#    '4tRfTVgpf1acjA27UWdcnD',
#    '5URYXSFGks9Q8eYePlgVdL',
#    '1fah1uAs7HeTYDlNftKr3K',
#    '6AGOKlMZWLCaEJGnaROtF9',
#    '4xuRhjrSjOo8n9rBFpwUoZ',
#    '1CAALs08dWg3BxFMaaS8qK',
#    '4I0w0kTFNbIR3rwpH4yQdP',
#    '0BefCZNc7saiEFnEBXzoir',
#    '7hrcHfHWaLhooHzGltlCYB',
#    '7hsulgRNgbyczeAg8tChCB',
#    '22nmtSEfoLluVVHDmAaH98',
#    '2vNY0WQo5xtwQPYnuPlwEB',
#    '2v63nsrBRoEkFZGKaTXA2q',
#    '1B87ZDrD3Pno9hS4stamWO',
#    '0AluA5RNsa4Cx6XRhf2hWZ',
#    '43lYaovU2FoeuBMNusVVVW',
#    '4wC5Mudt8Q6rjjnsgX1gas',
#    '6r0WuK50Lpu9u460x84oBn',
#    '0COXNxwxkWeA4hInT7Zomk',
#    '6XEuhQdge0Fg5NNUDCGNmi',
#    '18yllZD0TdF7ykcREib8Z1',
#    '5InOp6q2vvx0fShv3bzFLZ',
#    '0IX5OFffosy8wk16m1IFCa',
#    '2CInzVilMduj9L8dDXwyUA',
#    '5bJ1DrEM4hNCafcDd1oxHx',
#    '09lmraDvzBT3pUQ2rUtJzK',
#    '6LRl4EPstQ6LyJmsltZoza',
#    '2FbGlEPAjNhWvrVvlentVq',
#    '0RG4tDb9PCACXsbzxBcxUa',
#    '0JAcnlPLPqOjmvjEwHDGYv',
#    '5FvXe5bz4nQQ4eBaitt4EC',
#    '3q9AtvPJS3xHHmENa6Ilb5',
#    '55WLWX71YkHt2tSucNIf1g',
#    '72LlwJM24dWKpFLVB3PWWQ',
#    '6wn4ysn8HVxSzVo82Xk47H',
#    '14drW1kS9XzvsoGAVZn40v',
#    '01NaNxAEmbxcmbfvCFQduv',
#    '37Nqx7iavZpotJSDXZWbJ3',
#    '1C7KSXR2GVxknex6I4ANco',
#    '5bCjoSvRrL8YVB0sntBEKd',
#    '0gf2y5doKjsYaZJJZif4vz',
#    '1bo1Gh1wElmL8g8cmSkV51',
#    '7udsBKuqnJ5csWTAkR0vEI',
#    '57kR5SniQIbsbVoIjjOUDa',
#    '7HnutjN5qNC0ugC0Z7VZ3K',
#    '1VUGWjzlqudhTqvhc17miB',
#    '09avKKLKXaJcbeaGTmLCOs',
#    '0K83VVfg5Y4bPoZ4kmytKH',
#    '5mf5Rbm0mq4K4pp50d74be',
#    '6fIjnWrv46njJHLDAY2JdC',
#    '4f9IfFvBFm7Gsf1IVEudyf',
#    '01JPQ87UHeGysPVwTqMJHK',
#    '2jdw2tc29bqJwToyGvKgJm',
#    '2npQNOq4J3lXv5KBSr8bmQ',
#    '2ca5xMtPpmULDE6aG3VuEn',
#    '3O8NlPh2LByMU9lSRSHedm',
#    '1ql9UO3B5T3qP3NOAg0rr0',
#    '6CTWathupIiDs7U4InHnDA',
#    '32r2k2nglVzoetLtsuyLK7',
#    '0UvBmQOhu4DVXJtdzGc5eV',
#    '2j6xyKqDY5rzjWflwLqEnW',
#    '6yQonganc81UeJuB19N1HE',
#    '2qHk6Nz5glNQrjW8Rhd5kv',
#    '0FxNLtKsBwoFCbTFi3VNN5',
#    '6ydWxkzjDktHsTzvWcaZ1i',
#    '1wZqJM5FGDEl3FjHDxDyQd',
#    '2Ed36So3awlRmQoptqTBJm',
#    '4rMhnUBc5KjVa8oaj2mynQ',
#    '7FEwp8BavoEVE3AnxJDchc',
#    '6XHVuErjQ4XNm6nDPVCxVX',
#    '3Zau3JcrZcBfw8aVjKGkSX',
#    '3oh6SCCeLuXhFpEyepla6G',
#    '5Xw6qRFPFo7F5y3TH6lWBm',
#    '0hy1SOTEn9ifXTzOwnCwEr',
#    '62vpWI1CHwFy7tMIcSStl8',
#    '4tqbLV1qI50CFh5zkvNEPY',
#    '7iRn1W8QLad1RnzKkb4iQk',
#    '3pSWcyiliYf2Z5YUVZSAzG',
#    '2k3DLwaBiFzbieJlWij4pl',
#    '3vWzyGTu6Ovo1GdrcJqH6e',
#    '43PuMrRfbyyuz4QpZ3oAwN',
#    '6xz04ypw5JsqiyityCASG1',
#    '1Te0tlHsR9TKyP1DF7inQD',
#    '1DgX1EfI0JwRigJXb2m8rx',
#    '3VyjsVV24RmBIbWJAeUJNu',
#    '7AzlLxHn24DxjgQX73F9fU',
#    '5SKIBkIzbsAYDo5LOQ9f2u',
#    '0b6UoVjUzFyZNpHI0aAhKt',
#    '5DiuFfnqqyWKat40eY8r8y',
#    '3IzrrsRBpu23x95jJo7d5S',
#    '3BM50QYz0KxWMSv6JMr3H3',
#    '0Gpc3Uch6AowP28kJ19Mzx',
#    '6jglwfqX3drUj0FkeVOXAT',
#    '66Q3fAmSX5eHamgbKa9alP',
#    '63dg6LdBGxa0QA93M2snLA',
#    '5jPAwLGMs0cCKStblX1Jii',
#    '1cYZkAJBeuwgLahrmlHhXp',
#    '4F6YLjakjqWFTgC5qfEwPQ',
#    '1jvX9QdqLLwQUguKzR0Ad6',
#    '32ypPhtgTaETvFn3ZIHXTW',
#    '0At2qAoaVjIwWNAqrscXli',
#    '5lar0mCUejpILVkAz50s2J',
#    '3f0wlG15mXf22WOraAYwJ7',
#    '7JrAZVBsIxO42bLi9HnRYp',
#    '4Wjhj0WjkyECccfHVIgaTq',
#    '3hxIUxnT27p5WcmjGUXNwx',
#    '3pndPhlQWjuSoXhcIIdBjv',
#    '7Ei7kZxjEw9d76cEDxoxua',
#    '0526DaOuV7mRlPKxhMSJKw',
#    '2IDMCaW8K2nrFOoR5UANUo',
#    '1HLL8X0LH20F6Z9SLXLIjr',
#    '3SXEmuNyGN4GfVBFCxoRIo',
#    '4vr7q1NPXQhPysvuRkN91L',
#    '6D53lwtCp4kY6B7aZGkOxB',
#    '1CQ3rIFdw9Lie0uWpfA1mr',
#    '2YeJMTcIUzmDnzpK93SeLW',
#    '5YbrqNUUleF39Ai3b3ruQy',
#    '1wGnp7ejkCuXRsehXx0PNP',
#    '6B1d6DVcimUHrKwlqJj1pZ',
#    '0Odu228D0yGcFySGuxU4rY',
#    '0ixzR1LXNfGuect63Q58dA',
#    '6REbwUNlppTfcnV4d4ZoZi',
#    '6BDD5Ki9l2pWF1juW1RAsl',
#    '2lRe5wBRm4xaSKTbDn2vLD',
#    '4k7dYdLGhJuUjaeEQB5hcA',
#    '40IiSjljbAhrSbdJ3HxSfH',
#    '3WiCqMk8qUREjPsjubiPIK',
#    '2Cj5LxM6O2HWQIr9p9h3TH',
#    '1LV5cAo02H8h5YlZNcjULM',
#    '4ZrKeaqGjiC2GeFBia8q9Z',
#    '77EseIwL4dnUACjF3YmDWz',
#    '4q0o8mbKaAmRpYMDQMRSUA',
#    '4AtZRwSR8BOTTQg5ihSggt',
#    '30ym6VdCMiDkCOQnEWZuE6',
#    '1WTv76ouGCJZ0Rhz15YkIC',
#    '6t2eIONH4Sax3R21QWiKNp',
#    '20O48JTG6O46tPAuZbliRA',
#    '1vEAWYgp0m3HiOVcRmEUUy',
#    '0FlfN5cbUUpIHCRH8X1M44',
#    '439TlnnznSiBbQbgXiBqAd',
#    '7wbClNblLd3hkosmuYAdN9',
#    '0Li1OuXXfi7950ilZUFGkF',
#    '3Qig3auHwFlgO00p5QM6oJ',
#    '5Lgqu1th1KqlG97OF2gWGe',
#    '2kY2ROHIGdp3aA6ahqaUKm',
#    '29M1mAkW4VlxJ4noKN0RxY',
#    '4TnUqDwu2XGgtCnSL4UIaa',
#    '1m8WpLYXEiNVZchsWEcCSy',
#    '5YvYKEQEYJp4orh4z3Dnpk',
#    '4HQmJZyZDBRc8s7IzVrdKq',
#    '0LwwQLNOCvQF9xqD9rJ0Un',
#    '2JagldlkkSI5UnT6fRtYyk',
#    '6S5dMjMifQYmyTu1mX4f8P',
#    '2MyCT1iCuBUhcO8zbjOyRW',
#    '7MjSipTto9QljYzZnloXOn',
#    '0bP9mtOuBLMQ7L0DP2wPwj',
#    '0G5KlXqssFee9PDQYJ8PqL',
#    '4MOy68Xuz84lkfu1NQH6Bg',
#    '78q8pwQ59XTZMrkKoS7BPk',
#    '0ulO93nA8mfpmzcGHE5sWp',
#    '5uVW9FWVaQde0lfF4hYs4C',
#    '4dQRw7ylWmjumuK5LQycqJ',
#    '681ZlxQVB8XBPRZD1Wk4oi',
#    '316R2o0sNz4kCKyR0DOCVj',
#    '2LxudmRpMzYTsb37Oi1RWD',
#    '3zEKbhms2GDJQXaOLZZjAH',
#    '3nTDO6k4R6i3FpKx0QNgJ5',
#    '74atKkOasLOVzvqB6mYgga',
#    '7Gk8jIrqERJ4VJknnKjnuO',
#    '3vF6JeSyCHaCAjDuO2h3zr',
#    '3CTOc6QGsoaxwaPJYFxNsG',
#    '38vnriv5sC7OhkQUlh8qad',
#    '5xjei7JnROsAzLY2a7RdZU',
#    '6fWa5CRgy0z30OeGZyMBvD',
#    '6mj0tbBmZtEiZkmJr25IiX',
#    '2ycWek3FNNVHBhz2TcnOzZ',
#    '1cUJ8uWfmk5RFaaX3LyhHW',
#    '5uZm7EFtP5aoTJvx5gv9Xf',
#    '2KjUZzX9uLFczV1C2lTg0U',
#    '4MXhiYIRDMGAuvZc5IFTwC',
#    '5qHirGR7M9tdm6C17DlzSY',
#    '7k6tAZp4m93oswrPqSfBbc',
#    '5ExHDzOoOhC4xZGPh9zyQZ',
#    '45YuK4uUIJxlrOUjYL9IyJ',
#    '1DxwqrcPH0ixUnyoQcgbQU',
#    '7bpslE0Bb4juoM1LiBml1U',
#    '1a2BXMnQbjArGITwt3bMD9',
#    '0ZLjOTy4kW4ewJBckCDuF7',
#    '3P1MMSKp3FR5tvWlzPyVSX',
#    '764OUqC5YJuYJ9wazz9LtP',
#    '4UyV4tTTJQXJC5Wu56mrMK',
#    '2UKUKl9tHsSozmdLl7lKX9',
#    '3awnZSyvKdi7rBLttHk36K',
#    '6r639TM0j9JWM4jWJB1cVR',
#    '1dH43IEzvkRIFu6HdXWCha',
#    '0chpIFSjgfd1CPrAxM7PWp',
#    '7uqcLJFlSYjVPLUz1vPxkY',
#    '6zUDEI1myhSL5mAHRlKrIo',
#    '3ONIRhoRyimzjiW2W8PjtB',
#    '2K6fE4d7lEmCGcOLetWGFL',
#    '0kwtcexUeuGMmduCFp6x8H',
#    '6TCBeYNx8zRMnkKLSB5ZuJ',
#    '5kNrhABkAowO87oF0EHDPv',
#    '5Gnx5bNAglWcclJkuJnrys',
#    '7itsqu4pC7fp3ytIiiLvrX',
#    '67BtfxlNbhBmCDR2L2l8qd',
#    '0mG6igzxbH55XRyq3ygEh8',
#    '2ZRo7axmMPeSVUvDbGkJah',
#    '6fTt0CH2t0mdeB2N9XFG5r',
#    '5hzuO0DOsv3sJD2oCxk7Uy',
#    '1mXiAclKLhQyyjdUXRscEU',
#    '2EhJijFUs0WUmNClDBpYJq',
#    '74yU4BuONMdJCrBcwdxjiM',
#    '2QmEel9zSLkkeW4qAMTZG1',
#    '6Ggg9H5u8eUDcTzzoInIKH',
#    '5abU03nmreuCt7QG0iCqBn',
#    '7Ey2VcsFaLPCd1QvqHH2KZ',
#    '7Aem1fAapTdGcHwAYyQYU4',
#    '4hEtLH4D9zXiYuefvhaFDg',
#    '2MOMbPmESd5YkmNz8LjKAe',
#    '7LoHryKSypwGyBD2av1EMO',
#    '2AwuCKFWYoJ0sesjHbimTO']}}

# %%
num_songs = 50
model_predicted_labels, model_stats = generateNewSongsList(names, num_songs, model_closest_songs)
# Out:
# num_songs_remaining: 39
# num_songs_remaining: 27
# num_songs_remaining: 19
# num_songs_remaining: 10
# num_songs_remaining: 4
# num_songs_remaining: 1
# num_songs_remaining: 0
# MLP:sad
# 	count of specified moods: 50
# 	count of other moods: 298
# 	count of similar moods: 53
# 	count of labels: {'sad': 50, 'angry': 32, 'energetic': 53, 'excited': 72, 'happy': 22, 'content': 69, 'calm': 29, 'depressed': 21}
# 	counts: dict_values([50, 32, 53, 72, 22, 69, 29, 21])
# 	probability of labels: {'sad': 0.14367816091954022, 'angry': 0.09195402298850575, 'energetic': 0.15229885057471265, 'excited': 0.20689655172413793, 'happy': 0.06321839080459771, 'content': 0.19827586206896552, 'calm': 0.08333333333333333, 'depressed': 0.0603448275862069}
# 	elapsed time: 7.897262096405029
# num_songs_remaining: 30
# num_songs_remaining: 17
# num_songs_remaining: 7
# num_songs_remaining: 0
# MLP:angry
# 	count of specified moods: 50
# 	count of other moods: 211
# 	count of similar moods: 56
# 	count of labels: {'sad': 21, 'angry': 50, 'energetic': 35, 'excited': 35, 'happy': 17, 'content': 41, 'calm': 10, 'depressed': 52}
# 	counts: dict_values([21, 50, 35, 35, 17, 41, 10, 52])
# 	probability of labels: {'sad': 0.08045977011494253, 'angry': 0.19157088122605365, 'energetic': 0.13409961685823754, 'excited': 0.13409961685823754, 'happy': 0.06513409961685823, 'content': 0.15708812260536398, 'calm': 0.038314176245210725, 'depressed': 0.19923371647509577}
# 	elapsed time: 4.0675742626190186
# num_songs_remaining: 41
# num_songs_remaining: 35
# num_songs_remaining: 30
# num_songs_remaining: 24
# num_songs_remaining: 14
# num_songs_remaining: 8
# num_songs_remaining: 1
# num_songs_remaining: 0
# MLP:energetic
# 	count of specified moods: 50
# 	count of other moods: 344
# 	count of similar moods: 148
# 	count of labels: {'sad': 50, 'angry': 65, 'energetic': 50, 'excited': 83, 'happy': 31, 'content': 50, 'calm': 33, 'depressed': 32}
# 	counts: dict_values([50, 65, 50, 83, 31, 50, 33, 32])
# 	probability of labels: {'sad': 0.12690355329949238, 'angry': 0.1649746192893401, 'energetic': 0.12690355329949238, 'excited': 0.21065989847715735, 'happy': 0.07868020304568528, 'content': 0.12690355329949238, 'calm': 0.08375634517766498, 'depressed': 0.08121827411167512}
# 	elapsed time: 8.769786834716797
# num_songs_remaining: 33
# num_songs_remaining: 21
# num_songs_remaining: 6
# num_songs_remaining: 0
# MLP:excited
# 	count of specified moods: 50
# 	count of other moods: 213
# 	count of similar moods: 61
# 	count of labels: {'sad': 34, 'angry': 25, 'energetic': 39, 'excited': 50, 'happy': 22, 'content': 58, 'calm': 13, 'depressed': 22}
# 	counts: dict_values([34, 25, 39, 50, 22, 58, 13, 22])
# 	probability of labels: {'sad': 0.12927756653992395, 'angry': 0.09505703422053231, 'energetic': 0.1482889733840304, 'excited': 0.19011406844106463, 'happy': 0.08365019011406843, 'content': 0.22053231939163498, 'calm': 0.049429657794676805, 'depressed': 0.08365019011406843}
# 	elapsed time: 4.581714868545532
# num_songs_remaining: 40
# num_songs_remaining: 37
# num_songs_remaining: 30
# num_songs_remaining: 16
# num_songs_remaining: 8
# num_songs_remaining: 1
# num_songs_remaining: 0
# MLP:happy
# 	count of specified moods: 50
# 	count of other moods: 319
# 	count of similar moods: 139
# 	count of labels: {'sad': 29, 'angry': 27, 'energetic': 54, 'excited': 50, 'happy': 50, 'content': 89, 'calm': 33, 'depressed': 37}
# 	counts: dict_values([29, 27, 54, 50, 50, 89, 33, 37])
# 	probability of labels: {'sad': 0.07859078590785908, 'angry': 0.07317073170731707, 'energetic': 0.14634146341463414, 'excited': 0.13550135501355012, 'happy': 0.13550135501355012, 'content': 0.24119241192411925, 'calm': 0.08943089430894309, 'depressed': 0.1002710027100271}
# 	elapsed time: 8.459927082061768
# num_songs_remaining: 30
# num_songs_remaining: 6
# num_songs_remaining: 0
# MLP:content
# 	count of specified moods: 50
# 	count of other moods: 155
# 	count of similar moods: 33
# 	count of labels: {'sad': 19, 'angry': 16, 'energetic': 34, 'excited': 22, 'happy': 13, 'content': 50, 'calm': 20, 'depressed': 31}
# 	counts: dict_values([19, 16, 34, 22, 13, 50, 20, 31])
# 	probability of labels: {'sad': 0.09268292682926829, 'angry': 0.07804878048780488, 'energetic': 0.16585365853658537, 'excited': 0.1073170731707317, 'happy': 0.06341463414634146, 'content': 0.24390243902439024, 'calm': 0.0975609756097561, 'depressed': 0.15121951219512195}
# 	elapsed time: 4.820379257202148
# num_songs_remaining: 17
# num_songs_remaining: 0
# MLP:calm
# 	count of specified moods: 50
# 	count of other moods: 103
# 	count of similar moods: 34
# 	count of labels: {'sad': 3, 'angry': 35, 'energetic': 22, 'excited': 8, 'happy': 1, 'content': 23, 'calm': 50, 'depressed': 11}
# 	counts: dict_values([3, 35, 22, 8, 1, 23, 50, 11])
# 	probability of labels: {'sad': 0.0196078431372549, 'angry': 0.22875816993464052, 'energetic': 0.1437908496732026, 'excited': 0.05228758169934641, 'happy': 0.006535947712418301, 'content': 0.1503267973856209, 'calm': 0.32679738562091504, 'depressed': 0.0718954248366013}
# 	elapsed time: 2.776761770248413
# num_songs_remaining: 35
# num_songs_remaining: 28
# num_songs_remaining: 15
# num_songs_remaining: 6
# num_songs_remaining: 1
# num_songs_remaining: 0
# MLP:depressed
# 	count of specified moods: 50
# 	count of other moods: 278
# 	count of similar moods: 64
# 	count of labels: {'sad': 38, 'angry': 42, 'energetic': 37, 'excited': 42, 'happy': 28, 'content': 65, 'calm': 26, 'depressed': 50}
# 	counts: dict_values([38, 42, 37, 42, 28, 65, 26, 50])
# 	probability of labels: {'sad': 0.11585365853658537, 'angry': 0.12804878048780488, 'energetic': 0.11280487804878049, 'excited': 0.12804878048780488, 'happy': 0.08536585365853659, 'content': 0.19817073170731708, 'calm': 0.07926829268292683, 'depressed': 0.1524390243902439}
# 	elapsed time: 8.033476829528809

# %%
model_predicted_labels
# Out:
# {'MLP': {'sad': {'0LnS7aOdOdI1dNKZqdOLz4': 2,
#    '1QPreu0BNOrUfEb8HTd2qG': 7,
#    '4BBNAjTIzRHnrsrbjtRSYE': 2,
#    '0EgDkAi1hzNK3D3DjWs4bL': 6,
#    '5QK2qYLoYyE0v45cbtBWEe': 5,
#    '4qov4NauMMEyqZGLzK4ezu': 4,
#    '7uX3gufAoBVqKVoD3dBLLD': 7,
#    '4MTmAFWHpvB9kPMSRgLFRp': 5,
#    '193Dm5SqYy3hTSbuzxbwKc': 6,
#    '3U4isOIWM3VvDubwSI3y7a': 6,
#    '3pdwePS9Cbn6cfiheoc6Rq': 0,
#    '4XvcHTUfIlWfyJTRG0aqlo': 6,
#    '59n53QoJQa9RcvSuz739oX': 2,
#    '7xZlxQGgb0rBOPLJkviPCq': 1,
#    '1UGD3lW3tDmgZfAVDh6w7r': 7,
#    '5c3luoCub1Z1Gg74NdNtuq': 5,
#    '7oD9IulgMcp2IeqbtBiF5k': 0,
#    '73w7wNBVyoOc8DR7dBY6bB': 0,
#    '2NaEvg0vN4FmGigLTtbCFc': 2,
#    '1qA7crrPzO702kDZgRAhyk': 3,
#    '1e1JKLEDKP7hEQzJfNAgPl': 3,
#    '6n3HGiq4v35D6eFOSwqYuo': 7,
#    '3AJwUDP919kvQ9QcozQPxg': 0,
#    '4hjbxjZpJ8H6qRCzDOGI0M': 6,
#    '2E4INiVkDRBXXkFL4kB1Vk': 1,
#    '3zpRtPxRA4aAKdQWaIkzqA': 5,
#    '4hlH7MHdhEDTHgNdOO0AyC': 5,
#    '706ZrLifsm0nwlucKr4kQg': 4,
#    '6cA0wDujtrbg5W2rgNTJR9': 6,
#    '5yV2jwp1AZnulVkiWEorq7': 3,
#    '45WkcBtgPS8xulUwEg63X1': 7,
#    '6EbVuwU7EnKeF2hdpViXCH': 5,
#    '4ByaTrfoYbXrmlbsTG8MTD': 3,
#    '7pNAvsuTCFaXzSSUmfBPxz': 5,
#    '2naJy8SKJ27gj6ZhRPDKaz': 5,
#    '64IcRXZ9TzOOqyse3EPA3Y': 5,
#    '5qkZ6PPFjweR2yOKUGUDX3': 5,
#    '6ZA3Q8Dj5BrnmOsT300DCh': 3,
#    '2eArdfMxOmUz4JtBOVzKnC': 0,
#    '4CbANooTL2aTHzJZqQ0Uvk': 2,
#    '0O6u0VJ46W86TxN9wgyqDj': 4,
#    '0Jwqf8WzYlEtywz7opb9Uk': 1,
#    '6mY56gQjKYzpwyK2PNRJst': 3,
#    '3LgtCt7CVhMvNSMGoQD9i1': 3,
#    '1J9fx1TY0zlIxERMFHFrEf': 1,
#    '1ThmUihH9dF8EV08ku5AXN': 1,
#    '1YGqFtTZrScf2fHeVC3WiC': 0,
#    '5FkoSXiJPKTNyYgALRJFhD': 1,
#    '0bCPJsVGDxPYwQMDZMi4NW': 2,
#    '2q4F6OpQgx9umNB9uGFPYo': 1,
#    '0YvzawIC5nFFYj5YAvv5HP': 5,
#    '75ahQd2xHTpisbw2qgVOoN': 1,
#    '5B0ibk0qk9ees6wvlzMsZe': 5,
#    '1xzBco0xcoJEDXktl7Jxrr': 2,
#    '2njX8sZmCK4t7EKx2cS2Vb': 0,
#    '5aqI3CBgaQZlu9mvo6wKDh': 0,
#    '4yVEpUXxYgBwfSOKGTFxv5': 7,
#    '71lyUtIPCMAYjTwwwxy2jW': 7,
#    '20pJKlNIU3J1CrvhBr1kQ8': 0,
#    '6Od2OWvoT4embWAgIGeFRd': 5,
#    '21WvAGxPUNJARcZoSqswd7': 7,
#    '5MqbniRB0Q3qPVckYS5mge': 7,
#    '39d9CQbAB6AMLCxcJtSc0U': 1,
#    '7AJ56PvOGNavqK0HouT2al': 3,
#    '7IMwEtpAiJanqF6vQteZN2': 3,
#    '54NBD72JXFXzrodbQBSzWh': 4,
#    '5nayhWICkQGMTkisxVMbRw': 3,
#    '3OzwuqlBU5IInWGKhIDhTq': 3,
#    '4y0zVAo6QyExz997JXNEuG': 3,
#    '2tKOIBLJ2j384tnunmmKi7': 0,
#    '5bzf1xrbqr1ttjAJuRz2xY': 5,
#    '6gILStIFAhrreilolbRFex': 1,
#    '4K1syYUkHH9jI6LiJRKxtP': 2,
#    '2kJqNHHGOzLNahukdvlDWN': 0,
#    '2SSSPmOHhe2HRzLU3nTAv1': 3,
#    '1zcERMZrxux4h9mQY5NR7c': 5,
#    '4k7x3QKrc3h3U0Viqk0uop': 6,
#    '2B1DszJ5T6DkC05vnS75oD': 1,
#    '0xUvi7wldroBzaZCengPa5': 4,
#    '3CDVMejYHnB1SkEEx0T1N4': 2,
#    '3Tgv4rvWBVwnbmUTlJwzk0': 6,
#    '5K5mnE8uQnf9zIEX7ojdoq': 3,
#    '285pBltuF7vW8TeWk8hdRR': 7,
#    '7xEVy3xCkmRSbYavgefnsI': 1,
#    '5VJWIU24bvYZtFzhbG2bg0': 3,
#    '40uMIn2zJLAQhNXghRjBed': 2,
#    '6liNJDyWJjyHAgDnAX95bw': 2,
#    '4Pzg3KLuXxPJ2eFsPiN134': 6,
#    '278kSqsZIiYp8p3QjYAqa8': 5,
#    '5LHHKZOwV8XW4LJP2C64mw': 3,
#    '0zotwiNo16aaUg76C4Fgl5': 2,
#    '7lpmIGFw7Kc9qIdq4cGs34': 5,
#    '0J6UvGEMuJvzPKvlDbBvLz': 1,
#    '0hDJWGbW4mfl3widl6cfYg': 3,
#    '1qMMYpVatbRITKCfq1gasi': 3,
#    '28qA8y1sz0FTuSapsCxNOG': 2,
#    '0nbXyq5TXYPCO7pr3N8S4I': 4,
#    '1Y5Jvi3eLi4Chwqch9GMem': 3,
#    '47yB12k2uZtaLSwHVdszhH': 5,
#    '2h9ymIolsmYaqwtxn69fXj': 4,
#    '74lnM5V6ecvoTPV0fvptx9': 1,
#    '5EaHXf4tvFDKr3W2dDTlaO': 6,
#    '74loibzxXRL875X20kenvk': 2,
#    '3CAX47TnPqTujLIQTw8nwI': 6,
#    '5uEYRdEIh9Bo4fpjDd4Na9': 4,
#    '0jYLYhbDoceMWHWwwvYpVv': 0,
#    '6xagjcywpcyNFghafZPQJv': 4,
#    '5BOJkxCXjmDaBDZxFLJ57e': 0,
#    '4G92yYrUs0cvY7G41YRI0z': 6,
#    '1HYnjKqSSHh1tdl2Hi57zH': 6,
#    '564oa00vY05d1uYnTEAAmE': 0,
#    '1x8huXwyN6cqXVBcUt5fQR': 6,
#    '6F54OjXJHGYuIgrGtSr4TV': 3,
#    '2dSKFFNoNXKo3hPnlwUdPe': 1,
#    '2Ggr9IfS70wYQacW8nZKPG': 5,
#    '2Wt0JrVGExLvYIxoQNaY12': 5,
#    '2lLG56qpLP3UbcLuzMvkWX': 3,
#    '5HFzAeZkaTDBhlaqwcRmeL': 6,
#    '2yUAogxEgxEHBGG3zw57x9': 3,
#    '3ctLZTz6ogxp7BgvzP4FWJ': 1,
#    '2IePEfMAtqWS6rLXXFZIgI': 2,
#    '7fxSLnklnayJNBIKntXedZ': 1,
#    '6PQK1Y3Dl6dym9pj0y9Chy': 4,
#    '02rdXe0KhMe8p6ZHzYtuw0': 7,
#    '7zLYKWcXnYeHHWidalz7rj': 5,
#    '2sR8ZcBWTUVxLVbbqMPmLD': 5,
#    '6VS7wKwtvL2FvTupYSWZ9e': 3,
#    '5Jac5r26r1HkpH9Xv5zt7A': 6,
#    '1au2UduxcvHfa0fZS3Szci': 4,
#    '4SBZis6PQh5N40Zv9ro3Ti': 7,
#    '0ifLplTQxXkFZKMQpWCHii': 3,
#    '4wlR30YY9mb1CsQkf9eoTP': 5,
#    '3oLlBlxV32V0ZuJ7NUJTLb': 2,
#    '3NbwRR74N1FykCWETcEk3j': 0,
#    '1JyJl8Owr9tN7MbIaMlbmq': 0,
#    '6wWaVoUOzLQJHd3bWAUpdZ': 3,
#    '01vHGJRvJ6EZW9KO8NtZpi': 0,
#    '6uJONCdr2rC65BNmCnTBWK': 3,
#    '06s3QtMJVXw1AJX3UfvZG1': 0,
#    '4W4fNrZYkobj539TOWsLO2': 0,
#    '2f8y4CuG57UJEmkG3ujd0D': 5,
#    '5in02YJDTkdfKDQjfsvxYp': 4,
#    '2beS6dD5rovBxSA1zYoSHR': 3,
#    '3RKLJPyyMZfwebsePAzqjL': 4,
#    '3SsJ17EnPIu1B4GZshqjIS': 1,
#    '0Wgh1XUbVf2Hd5DdIeRgff': 0,
#    '3dYD57lRAUcMHufyqn9GcI': 0,
#    '3B54sVLJ402zGa6Xm4YGNe': 2,
#    '30QR0ndUdiiMQMA9g1PGCm': 3,
#    '0mk6o3Ukx0FQfxIeA5LnVj': 5,
#    '6Hfu9sc7jvv6coyy2LlzBF': 0,
#    '66pK7thQ0yw1xlqw8AQSlw': 3,
#    '0vjeOZ3Ft5jvAi9SBFJm1j': 2,
#    '6ZthdsKjWtiCxnxbhs74vF': 5,
#    '03YZnK3XQWKpvo9TyNZzXf': 5,
#    '26UxwWl9xCb83OynXELJcL': 2,
#    '2K9bqtVjSkDN7K552R75d6': 5,
#    '7vUinHnJHVLNxQpM8fCDDN': 0,
#    '0fX4oNGBWO3dSGUZcVdVV2': 3,
#    '7KA4W4McWYRpgf0fWsJZWB': 5,
#    '0eeeK1ar71WxdsTKydG9yz': 3,
#    '7vnF6fz4ckQOVAjxwYv2TB': 3,
#    '2ZxPeA5bF7iAA5VvLQ6zkq': 6,
#    '6Tj4oHdbQdnicaVZD2d2tQ': 5,
#    '5qHirGR7M9tdm6C17DlzSY': 7,
#    '1h6kgem1ai8vUgO1rZOwfB': 2,
#    '6OfOzTitafSnsaunQLuNFw': 5,
#    '2sA4woGW5KgEgGXXxOKPAZ': 0,
#    '0s9xZDmDtrZKvgXVNJl5VS': 3,
#    '366DLDHAnvMnHP5ECYt4N7': 1,
#    '3RMdpItoSE6HDsezfpqIuJ': 5,
#    '44sYqNBttbXNxya33FJ3Dj': 1,
#    '5uKHTLXNcftXtYfU7j9cQ6': 5,
#    '3QFInJAm9eyaho5vBzxInN': 3,
#    '0HrWshW3SuFJ6nKS9ba9Mh': 3,
#    '7rwX0O3RlxqqIjQM8evm5E': 3,
#    '679SFFZqnBAJ40r9rXChTh': 2,
#    '0iyJTZnNXL4FLgEKPGG3R4': 0,
#    '3sNVsP50132BTNlImLx70i': 0,
#    '3TlFe57RW3iLtdmKitrXIW': 4,
#    '7KXjTSCq5nL1LoYtL7XAwS': 3,
#    '7cpCU3Denug5NGZsSpQl8v': 0,
#    '1yHVHoz6Ny29gbbWJYVnFt': 4,
#    '65th8C78LWsQV4uzfsIEDa': 1,
#    '3l3iCfpZsxbxWJhYoiQNkD': 7,
#    '3d2JSZa5RGiGYHzl1CjzeN': 6,
#    '3lRhAvgOzmzHOXqzbNJduS': 4,
#    '7KWGfnsUU4Ri46TIvjpAPx': 0,
#    '33gwZOGJWEZ7dRWPqPxBEZ': 2,
#    '5Ze85vOLSjJMABOk1hHTlG': 0,
#    '1SCXzqKZdif5b33POmzwI4': 5,
#    '6gBFPUFcJLzWGx4lenP6h2': 2,
#    '221qmpQeBNV87sUjQeUTVH': 2,
#    '4xEHlCgoKd4RdrS79OPn9y': 6,
#    '1GNBUGLY90p5vP6z1eEA7k': 5,
#    '3JAYZdCYMH7yoQTupGP6qz': 6,
#    '4MQIDIQjNWkUvpXe5Je7TO': 7,
#    '3S1tTwSKIZgf4QGltFyCxM': 5,
#    '4euN0XE8wuVc5UHyhMU8uN': 3,
#    '6n4g9rQE65ZgPQo32mWixM': 4,
#    '2nfFFhkquAgEUJ4mK789DN': 5,
#    '2zDpwmvl0Y3nl3tOx02Lt7': 5,
#    '5uYZnkDGu0yQtnE7Oy424p': 6,
#    '5hTpBe8h35rJ67eAWHQsJx': 5,
#    '4qZLvqy5Wg4sgQ9gKusb1B': 7,
#    '2RJAKIw6nIkgZVsAIKhmqz': 0,
#    '3y3U0Ek183gHVBFxO6fFos': 3,
#    '2ZlABhxMMa43COmZ97kKsJ': 1,
#    '6bpBsotzL05UzS1rHsIqk8': 5,
#    '5qEDMy4lkVZ93et8y1VP99': 2,
#    '58bFfMjShaACL6sAIR1Eyj': 5,
#    '7fEoXCZTZFosUFvFQg1BmW': 3,
#    '5FflbihMpPQYMtYMhuxR77': 0,
#    '2g6tReTlM2Akp41g0HaeXN': 5,
#    '5hVghJ4KaYES3BFUATCYn0': 5,
#    '1EmVyH2yt5PEMm4hVftZ6d': 2,
#    '1OPVFxzEgHEdfvCTiB7nh2': 0,
#    '6MF4tRr5lU8qok8IKaFOBE': 3,
#    '3RYVXC2rPXzF06ggwUwn3L': 3,
#    '2RVrdr062uLFxXwIxwdXPH': 2,
#    '31UJ8vd4JQc1JEa7TgcDSz': 2,
#    '2dHHgzDwk4BJdRwy9uXhTO': 0,
#    '3GCdLUSnKSMJhs4Tj6CV3s': 4,
#    '4rmVZajAF7PkrCagGPHbqa': 5,
#    '6PGoSes0D9eUDeeAafB2As': 4,
#    '2JKUucHX6iKiY8phj8U5zg': 6,
#    '40dgXhA8m9vZUvwjzzrI3P': 3,
#    '2BJWxD8xKrDv8vneTvTIm9': 1,
#    '5NORWMFC27ywGSZxi8uquP': 5,
#    '5WoaF1B5XIEnWfmb5NZikf': 5,
#    '1TqafPEsBS77cOefzHXs3s': 7,
#    '4XGlpZw4XyOAisQrpodzPn': 0,
#    '3J3LxwxJfgjjAZ5jsKK3Kq': 6,
#    '3gE4eQH3K83Sght0ZLvuBK': 3,
#    '0QQIhT6PtJ5glyn4HKNKQ6': 0,
#    '0oO1AbL92F6329z13C2qQH': 2,
#    '02A2Mi0vR68au8FHSX3xmc': 0,
#    '1djzKW3eYLyzjjHXazEWWh': 0,
#    '4xqIYGwwZTEem9U8A42SPF': 4,
#    '0w6webWdhjRKdqJ3DeGgM1': 3,
#    '4UEuIEv9Wc3wtiWUplGJ7q': 3,
#    '2fBs3IClRp1Gs0EzvlQNYs': 0,
#    '3fvb9N0z7RK4Bjznxidly4': 2,
#    '44yqXBoQ7KV3jZdvGUiAex': 5,
#    '7qGlmtbPmILIzNIrzwabQw': 3,
#    '4yn0ftNHQSwsWE81h33y4K': 3,
#    '2vCOmGPDOdFbiWrXCQOCSZ': 2,
#    '2AoKiaQylcQaUwsJNKdJOo': 0,
#    '4ReJBi5fD6RiAQvknuRkqs': 2,
#    '0PvFJmanyNQMseIFrU708S': 3,
#    '1xa6NUKXLGrUqJMSAfJVNg': 6,
#    '1sbEeUY8KsdvgiQi26JBFz': 3,
#    '6JjPBQfI2Y8nIjnm65X6Pw': 3,
#    '0uPBYnoltG0oiZ2bOTy7iI': 3,
#    '4vOWNHRx4FGlQhs0pyxgJl': 2,
#    '6Qwuw0eOeszVlewLpu24gR': 5,
#    '5kQQ3eAIsg5DGbikSHQ8qG': 6,
#    '1ITpqT1kDATCtMBwOK7sYn': 3,
#    '50a8bKqlwDEqeiEknrzkTO': 3,
#    '15IHacLPzqbzfUQPOt9r3v': 3,
#    '12Us8e6NFesdkXKf4StU1I': 3,
#    '7wBJfHzpfI3032CSD7CE2m': 2,
#    '73jCuIwQZavaxgy7iCIIR3': 2,
#    '4MgMO1pKoLxeZpadfZBDR3': 3,
#    '18kOgPYJgcMCpurna8P23T': 1,
#    '4RGKft6YTTWHjpQeRIInuS': 2,
#    '23ZAaG8o6uPxnYwPZlWrDp': 0,
#    '16DHWSDlEa5K0JbMHnuMXM': 3,
#    '45oGS3iHeT2cvkihSP7KzK': 0,
#    '0ZfByLXCeKchuj7zi1CJ0S': 5,
#    '1fewSx2d5KIZ04wsooEBOz': 5,
#    '40mjsnRjCpycdUw3xhS20g': 1,
#    '2Si7shrUKzMBFEDRTb4LlW': 5,
#    '3Xf0AJa4KUyQOOqW4mlRbe': 6,
#    '310BgC3S2W0Cl8w0OmyS3n': 5,
#    '3t9yWxeI5MnMtZ5rvKw315': 1,
#    '2VAKKZDVOBksPNFZ82u7dD': 5,
#    '1F1QmI8TMHir9SUFrooq5F': 0,
#    '5btojoDU9TNQli9bZBliVp': 2,
#    '4s8rPpoY20f6iZBz0yw7JT': 2,
#    '7ycWLEP1GsNjVvcjawXz3z': 5,
#    '6Qyc6fS4DsZjB2mRW9DsQs': 5,
#    '3Du1gVreaJ61I0dGwZ8rcx': 7,
#    '4QbVWCAkh9Z1G041cQAiZ9': 0,
#    '5vDNippoMr52KpXBO9b9KQ': 1,
#    '30KctD1WsHKTIYczXjip5a': 5,
#    '6r9xnueU24r4eoG3HXC87E': 1,
#    '1oitaFhc0kVM5ppZWGWJIQ': 1,
#    '5iUQMwxUPdJBFeGkePtM66': 3,
#    '5KqbsqDW0xgOpZDVxKQPZk': 6,
#    '7lEhOiFtcLXY4P7cuTKuQ8': 2,
#    '2fau32jRbkSUQgH6R7VX9Y': 2,
#    '4DtQvWlFTgIlE6XuloFQ06': 5,
#    '1LiN0Z98FkR1t0m8KmLcAH': 0,
#    '3gruCKVuhCsRjs3a3dG8CA': 6,
#    '6piAUJJQFD8oHDUr0b7l7q': 2,
#    '3krzcyMKlRXjVkJFZqMN4t': 3,
#    '4zQJf65ZNkPgEl3i622bbA': 0,
#    '4LGg2NY9eHp0jF3L1WbCNl': 5,
#    '1WIZiOuNO3woKfdlSK2gNn': 2,
#    '6ZyQM3ATa22psCotZxJFhZ': 5,
#    '5J64qSSq0VZuh0CiI9o9Nq': 0,
#    '6LWstZ3aCECKV5HRO2oYFq': 7,
#    '6ydWxkzjDktHsTzvWcaZ1i': 7,
#    '4IO2X2YoXoUMv0M2rwomLC': 2,
#    '5KpUzmHFirESqWjCrXnmWS': 1,
#    '6AQbmUe0Qwf5PZnt4HmTXv': 4,
#    '36jMu03qVcjYAccvQLmAMR': 0,
#    '5W8jRrZ6tWrTrqnKRtIQBf': 3,
#    '42bbDWZ8WmXTH7PkYAlGLu': 5,
#    '74B7lkp2IMiPKrcOa8cD72': 2,
#    '5FpanIzR7msLbt3XMdFBfv': 5,
#    '4F6yN5FsFW10Ucx7cLCzBh': 3,
#    '0NKoPGc72yUKTIneVhFfg1': 3,
#    '23mxI8WrJJx5SF1M5HirFX': 2,
#    '3JEJwjqLkg2Jbau5922CAb': 5,
#    '6NfC2FKfsfzuLIF4lThw0A': 2,
#    '5ximSyk6bKXk7ngjmu6txJ': 5,
#    '3umS4y3uQDkqekNjVpiRUs': 0,
#    '1WbYFNSUNn9fP1x0Z5DU95': 5,
#    '5DBD1TTl06dvp3WqPEY5Pj': 3,
#    '5Sqya98MFN0RHN2oglnTTX': 2,
#    '7yq4Qj7cqayVTp3FF9CWbm': 5,
#    '4VA2prpKDv7ywbnPFfPrWS': 1,
#    '0RLLvYBopDwooCyvnTwgYu': 5,
#    '2Grb4G6t9VIqo6moKUloom': 3,
#    '6T3l1Ov2VpZdmqN7PLcMxP': 5,
#    '71SbmXsy5H0bqxJAVBcfsG': 2,
#    '17vQTNbvhpvi92qOnDOFHB': 0,
#    '6Kkt27YmFyIFrcX3QXFi2o': 6,
#    '4T2dHb8XBYHlVj7Dyo1cW9': 2,
#    '27a1mYSG5tYg7dmEjWBcmL': 2,
#    '2vzMWO0T008m86yDnXwkII': 4,
#    '6Nzq7iIxg5w9ipnCd15sQt': 5,
#    '4qV3FpOX5NQbghsnmx3wKX': 3,
#    '4nGOqcmjNz0XGMh1S6Noxu': 2,
#    '0d05HF3WXs6ryypJ0aQPKC': 3,
#    '3QHGfxhjexLaMKGHXagfRs': 2,
#    '37F0uwRSrdzkBiuj0D5UHI': 3,
#    '0euxhIjYMWtrsM4XJBe3OQ': 5,
#    '4vIBtcC2KzJY4Va98bvI8P': 3,
#    '5BJMeoCXXgbRAWfp6fTulr': 3,
#    '1RvL7eHoeUolnQbWm2Hnba': 2,
#    '2UQ2oUbHiB8wWYCE42JX0k': 1,
#    '4C4Pduzp8LfAtQXHAGQWM5': 7,
#    '65OVbaJR5O1RmwOQx0875b': 3,
#    '4jTiyLlOJVJj3mCr7yfPQD': 3,
#    '7BSRsN1Aw98BboPe5K4c5V': 0},
#   'angry': {'1lAJUXyP5S2dUYHer1xBas': 5,
#    '7ivm2yIOd1XdjZBLxklVcO': 7,
#    '0CL5CGhcKaJLakMZNSRLu9': 2,
#    '2mgwWADmEQrWzENfhuCrll': 0,
#    '6PdIJOOMKQGFxqnDZuT0Vo': 4,
#    '12QosYNq9wO1VGy6txpHGN': 7,
#    '7eUvg5UEG8AVyWKGWm7Lj1': 7,
#    '7azNymxOe7UbOzym2MJTaR': 2,
#    '2vA1SuXE4HLaixxLSSZT83': 2,
#    '6rHnBRfWizxM1Se2TBhDHb': 1,
#    '5UwXs770kJdLYJF5tbCCyD': 5,
#    '5cDlGGYVy8sq9iOfOTAzHS': 7,
#    '0uM9CyhRRCoe10HlOTYoHF': 5,
#    '0k4Xxpf3Ml9e0UFYacCIDO': 3,
#    '7dDYobgpyZzWdOFdzoOkNp': 0,
#    '2Pj4QgfmnQ37Kn5eMhxBy1': 7,
#    '1wIQtB3UQ1TfjNMZZqO6eh': 5,
#    '1l4667RlKg7diD6P1Dz9aL': 0,
#    '77HYInT9f6KfjaLlrRz7Eu': 5,
#    '1CUPpcV1Qfks2FGgjp0npe': 2,
#    '1hp7uTRi0jYcN6wgFP077U': 0,
#    '6efkcs2aUBMFKxl0cl2JWQ': 6,
#    '1S3KbOLtL2oPSwzh0jwBCS': 5,
#    '2XcpSEpLjOLtnMXPCSB9dv': 1,
#    '4OsZvXMvbvSm0QLu5QqjvO': 7,
#    '3jGGBXlK2H5wDCJliiDdIW': 7,
#    '63tCTmZxknDTZKEEEu9JOS': 1,
#    '1mahBv60Rh4aLm7kLzBBRu': 7,
#    '2CiML0n33Oz3x7Dgocsplo': 1,
#    '6tBUQ25NUG7zUVTL0KRY6f': 2,
#    '2fpTRcMLt4aKlqULOwuXUP': 3,
#    '1uCGmUS3xDgc3e2pSSJX9f': 2,
#    '50sSNm5rq7O6wqvkIn42Zf': 0,
#    '3Uqv1FU5OwU6hVOdj81VQa': 1,
#    '78etUET3eSVF2Wfca7yEOD': 3,
#    '34k9Q9AF9bqDSJxyL5IPkQ': 4,
#    '7o2IbwyONZhbwYmjYXtTF4': 6,
#    '74loibzxXRL875X20kenvk': 2,
#    '2XHouWEiXbXB7m50ybUG8h': 0,
#    '0yUA5Ci61OTYCYnE4RPU2C': 1,
#    '1de4nQ3igImuTvu3y7FoHS': 7,
#    '3dVOmfKCIbJ6iZlmRgJqoV': 3,
#    '0l4WWnQHGJeeY2UCJw9t5M': 5,
#    '6bGwKHXHNLmTy6yt147FPh': 2,
#    '4Q2ZgILbVW5bViFhaRwmnT': 1,
#    '1wGaQwgfjollTdTSktbuOV': 2,
#    '6lcjOb56xe0poKmhe5mxLa': 7,
#    '2J6gxlzzS5KMBxTGZlU00v': 4,
#    '3pqwmeQy4xQS0626fG3idJ': 3,
#    '1Q2Q6Qz9YNf6KZPpHOKFbD': 6,
#    '0jvl8JNF7NOUnmYcRD9RSm': 5,
#    '6z16uj7iUAas3yP25Tf0ia': 7,
#    '2fzvibAxqwManQKIJLrMgs': 0,
#    '1VqkFbnmFCzLB2t6BfqGXT': 1,
#    '0enBqQTzbtrEh0V9bcoRBE': 7,
#    '3au0pvHqcTtszysswan6AO': 1,
#    '2iOCEiSIxjF02O1zFvcCCA': 0,
#    '1A60dNMbkartuzixGZt2Rc': 1,
#    '28JEFSyc3hjkHN4LpolsXt': 1,
#    '40bpQa8RWIvo2XA4QK1G79': 2,
#    '6djjUOSyqWDFm6LsejN7kg': 5,
#    '7hLBjW9tLXS1hE4w10u10h': 7,
#    '5V16lV6skOpS5RK6Mz7RC2': 3,
#    '4riI8HuqMYwKHfTlYMp6W8': 3,
#    '7GPxQHkuern9JDUfEKeFDl': 1,
#    '7u48RjanhFy30zE8N5dOiw': 1,
#    '5qlTwtYe8RqXqF7npTawjD': 7,
#    '2Gn3xsO0hacXJy1Z2EHrgm': 1,
#    '2AEWlaVGx9IopuYlK9hbzF': 3,
#    '0s40OWn8ThsmdKHoP7PsYG': 1,
#    '2VCYZkgpmOEWAUXdRSIRIx': 7,
#    '5vDNippoMr52KpXBO9b9KQ': 1,
#    '0Dk9lP1YnOqssHH0oCeq9u': 3,
#    '2NlegEcb8J6Db5uvP7nUpl': 2,
#    '61dXty0FR61qyVczdM49F4': 4,
#    '3VI1Raz5Z7HivJBuGeJMrq': 3,
#    '5Hp9VxugzfhnN8A2X5U5gb': 1,
#    '6vEqBc6xXRz9Wd0QbHUgwt': 5,
#    '0uhJG7qeBA6obJRTGotNhX': 2,
#    '6FUwkDkUbkrZQdS1s4uNnM': 3,
#    '065YsNvP5qD4YDJt5JtPv8': 0,
#    '6orlcXc4pdUJ9JwpC2gpDR': 5,
#    '36DdoiM044LERG9dTQv9wH': 1,
#    '49BcHCAaL082dWLyq7mEAS': 6,
#    '6VDz4m1vEGHDDqQojf1mpc': 3,
#    '1Ajoi45AjYqloARp5ufaVK': 7,
#    '2TxNgbkLVLpurNpnyvwaLF': 7,
#    '0Ca6iv6d8LuPVsL0vPmesy': 2,
#    '0QLuexVmR2wgNsekPKbv6c': 0,
#    '1cPijzuZu3GAR66jjCybvB': 5,
#    '5DBD1TTl06dvp3WqPEY5Pj': 3,
#    '4IO2X2YoXoUMv0M2rwomLC': 2,
#    '6l7mnrTeO2UQ8cqZjaJne8': 7,
#    '6MF4tRr5lU8qok8IKaFOBE': 3,
#    '3ph0msZhsDh0GS6IuVjdmp': 1,
#    '6JTmyL6UeTVLHuoco3FlBJ': 5,
#    '50a8bKqlwDEqeiEknrzkTO': 3,
#    '7Ik8lEKexWPoGutgJ90C4S': 0,
#    '1g7wluTLjwfTYddHcFn5r6': 6,
#    '2AhAhd9BiyydtKq2hMdb7Q': 1,
#    '7IkBGxyGxDOK4WEoCCylap': 4,
#    '1oomHsI4UhLMlb2Y128f6z': 4,
#    '4SH08d2cXxxmnRv6S2goZi': 7,
#    '6ioJIbTdQEpbvkTdPuwhF5': 3,
#    '0ZQlr6DULcQWLJJcgOlAMT': 5,
#    '7eyo0GFemhsOcmVxHBLG2x': 7,
#    '2kiQV8jlNY5h4Fb6n5Qzra': 3,
#    '15NQ3x1f2GUhqs8oBXhTqp': 5,
#    '1fewSx2d5KIZ04wsooEBOz': 6,
#    '3CRzYkSElJbrYBa4Z4O6Ad': 2,
#    '65g5edzIuWzXfqkphbc2ur': 7,
#    '6T5i0o62ZyfHRRHHihYJ1n': 1,
#    '7ibRB2S2WOfPKSvYkhcYtj': 7,
#    '1IFIZTpvfeQ3CRrH37ydOR': 0,
#    '2UZumcfvEzAjWM46OqIi37': 5,
#    '1FTRi5Y7DIe73Z7XS05Njv': 7,
#    '6paWpAybFiKxhPfI8E743w': 1,
#    '2IlkoEZkqKV6DnRPKXmuow': 1,
#    '4tTFl6L8eNA7BK4dRJivK1': 5,
#    '0ra6JCpzmmby6wzy51AzU6': 7,
#    '6HApb3dx0i95Qj8SEgXCAt': 4,
#    '1P6ZWbU95Y5issu4KXTpwz': 4,
#    '0X9tyUxH6fPN0C2BgESONf': 2,
#    '4Zv818EZuPZ2Q1FG51eXDI': 5,
#    '7fEoXCZTZFosUFvFQg1BmW': 3,
#    '5tw5H51GeMaSBcD0CHKsBq': 4,
#    '4VMTK4vNbo14HP8xFK6ShF': 7,
#    '5M5FbqhEDQuhFeKumZVTjj': 7,
#    '4KTP7qTGHtUCHEASskaaa7': 2,
#    '5FkoSXiJPKTNyYgALRJFhD': 1,
#    '3rd9naU172zv7PD7x733n4': 0,
#    '2lLG56qpLP3UbcLuzMvkWX': 3,
#    '3KmnHmphncVbWeXVDCfmbQ': 5,
#    '1ZvBVbsaNqHEP6ymXaPGlj': 3,
#    '0TKIzyJYqeSXg321a0wCLM': 1,
#    '4hOuJIB1norFj3j84oY2Cq': 7,
#    '4PyOOibJkmGOvhblR5I5Uq': 4,
#    '0GqnOkgpP4cnn1UT6LVrcX': 5,
#    '4b9ruyWFMtREf1oatvwa5N': 5,
#    '1HF5R3U6Ha8nzJgmABbrBt': 5,
#    '4xl69qYIDxUIACXSeRkXOY': 3,
#    '5Qtk3aOajgvG1GMkdvTIEZ': 1,
#    '7effRlJnt6AnihucMsHriS': 0,
#    '0M9lXQmCUsBFWyrmWEcbwt': 3,
#    '3Vr27jCg0tJ46FRdYaQNoG': 4,
#    '3EcFEq1cxpIG7y4Gy0Gm6a': 1,
#    '0Z1CgKoZXoQYRiqyXhq9LV': 6,
#    '71lyUtIPCMAYjTwwwxy2jW': 7,
#    '1tF0XTcddXV9t1dSJV4mT6': 7,
#    '22F23R3CYWiaqzX53GlTlG': 5,
#    '4vvztNc8XVIPWcVIvuyFCu': 3,
#    '2Lmpxi7j95HOvsR6zj1Fl3': 1,
#    '1qMMYpVatbRITKCfq1gasi': 3,
#    '6CIM3aXBFg7iU8SBft5jXV': 5,
#    '78CqQhZGmcabQEbuI4HTLU': 2,
#    '3iGicWZjOWrXXgRE4UcYJL': 6,
#    '0eaVIYo2zeOaGJeqZ5TwYz': 7,
#    '4zLYu1WP0e6AVEIgfQtM6Z': 1,
#    '4J7IUiMAbCEBN15c2ekiDh': 3,
#    '38tpgg5HNLAEhSvH68Gg7r': 1,
#    '0ZTnxnWqzIyClPgZdsC2vk': 3,
#    '1W4qc7UnAuRmT93W8Ad1t1': 2,
#    '5J6Dfjl3mVvzPBbdhAOa9n': 7,
#    '2SAP0EqRkRNOP34atfudZa': 2,
#    '57ZUX6TNyKLBydAdVVd02x': 1,
#    '2TSfStvlAMLw89u3tali79': 7,
#    '7AoV1eI8VBfn80Johpwwk1': 1,
#    '4yW6cszR2DQEYX3tA1wKbD': 7,
#    '4RIdKsqdglJ5JqTG8kTvw7': 3,
#    '7jmTA4qUoE3powcTpw3dvF': 2,
#    '7t7PRXIimTNJ90MUqPNIPz': 7,
#    '4HBhQyTEAqc4f3Jn9XOiQe': 3,
#    '6D8Kw7L4EX2SfQrUlI8ff8': 5,
#    '3k2h1u0z6Wx6XFYHmalPlJ': 5,
#    '4bHOdZJfMdDS1XYEU6L3GZ': 5,
#    '0qVyEXpCwfVds7WUTxtpjM': 7,
#    '3sjtQ07ptlPzw2N4YmGW3S': 3,
#    '6rmiFKRnGUHt7zpWxC3Jf1': 7,
#    '3P7xjKJTg7tG7xWlyCpfih': 1,
#    '1b0gC6s5XQNVcsmPCpBznZ': 7,
#    '0j1oCSyf33qqdmQ49Iro7r': 2,
#    '27eb4YUlqGJdnleIlg8cA3': 7,
#    '7osqbFRT43itJzwduP3sST': 0,
#    '1hegHGW3yUFJxRWOVl5ga9': 7,
#    '1nd6YkzmI0JuEMlfPtNDeB': 5,
#    '7FUx1SDHG4Im52aKu3iCXC': 1,
#    '3RZb6chXBLfzub0LfGSbeC': 5,
#    '7H3rXY5LE4XkzZ5TP4jQ3p': 2,
#    '1MIkFEuWvGeQGHsmwASnh0': 7,
#    '0wASQ9xMN5CR5K7TdYCDbd': 5,
#    '5hpkK8f1iVrF3OrAMcphJY': 2,
#    '2PYiAtlcFNVbP4MdQBa6zk': 7,
#    '6wYlH8EBwJmd70i4HLRlIu': 0,
#    '7m1cNdKABpKy0aAtsKAIGx': 1,
#    '5KhWSvBNRGxY5I3t0X6f4w': 0,
#    '5cemxRCYTnp6nZVnMdorkI': 3,
#    '3vEOALYBUNQUMXpqhWx3hG': 0,
#    '6LBpGdlukUARutol7VgWIS': 5,
#    '3y4YUioQQVCZriM2RjZIik': 0,
#    '7ghOZsTDRMKX8c3g7CgiRt': 5,
#    '49Axmi0mWUSJeQvXKlRHOp': 7,
#    '2wfiYnzYZgnp887tnedGgW': 5,
#    '1Kzma94Px6xjhjX74SXuMQ': 7,
#    '677ai1ZuIvkr13W5vSR9wn': 1,
#    '0TVLKv5F9iSXhONXDtSnVa': 7,
#    '3lOfgduXmNt5rEQxswtgbI': 2,
#    '7CZhfP2PiPC79NIAUTdkVp': 1,
#    '0YLl4nxpYX2SBH9gIAtnL1': 7,
#    '5xembA6CsmFfo0U7EmtDWH': 5,
#    '2OwdUZPORY0EAdRBF9hSZD': 1,
#    '5qF7knZoOT4pPq6A7xlOSw': 1,
#    '5lEccWVO25jlYFSiPp5ikX': 1,
#    '3IPGG5Niex4hGlXFOYWzp9': 3,
#    '42l1MxxIbbey0MNJZouAt5': 6,
#    '5HyMn0GaqpUnyAaD4AhjjH': 1,
#    '2QG6sy6xFILDbmLXYTUJGW': 1,
#    '29TQLMbYYWOEfytEwLthQ0': 2,
#    '5BXwOgBn1XXg23YsNgxZKt': 5,
#    '4aMxs74PXoQg2SLgjypcvb': 1,
#    '6m2mgNOGl4yUkZP4Kj2lZX': 4,
#    '3YFnfm9z8RmPFIZ7C16u4e': 2,
#    '3nDjCWmn3FHTI9q8y2twLS': 6,
#    '70B3eWw0ivRKxEvbbHQcjs': 7,
#    '2RgFaAUAlBZZdvgl96R8eH': 5,
#    '5ugbd9ssHSQYxB32XWXNPu': 1,
#    '47Obor5zpUwTRLEQIX9woV': 2,
#    '7lybccwE368E3JGeVKP1su': 3,
#    '5YZpdsmpazPtBHFbGN8mon': 5,
#    '20ruS04qMUXD4Fwvcd36fj': 7,
#    '72iC3kAnSjbdWE2Rbax5xj': 7,
#    '0D5luZzw9jxPxom7yYFKkS': 4,
#    '7rx8az1QFM5TmReow8beys': 2,
#    '5lLNBIyjp72btcnrjBG751': 3,
#    '7pHXRkvxrNnXDfJFKCdJi2': 2,
#    '2EOQfSrwpcQS8jLdqnyaXB': 4,
#    '4MnaV7yPUmglATd5NHo2HH': 7,
#    '3YJP7MFR6D4R1zFDXmv35p': 3,
#    '3wDtk8q2I5iyxiKJguVnfM': 2,
#    '6EpGSeInzJgZVDVgfpMn7h': 1,
#    '21F1jnehTDOit0mzPjcWfZ': 4,
#    '58zV1fJcsitH2BZVotMd2A': 7,
#    '2hKmsv270gdqt6r5dJjOsE': 0,
#    '4aTWP6Zd55wK7m0x51hlrP': 1,
#    '0ZBchpb4CLk5Qqu3895Etp': 0,
#    '1yHmbFm61m6aGqemhyOv5T': 1,
#    '5t0Dc0e2GyaOcsruJDwljN': 2,
#    '6vOedMRRZuckfMknIswvLv': 2,
#    '0y6zN729H9Vti6RgnOeWyJ': 3,
#    '5WMRWKUT8gtPRLTqKc7HrW': 4,
#    '2h07VxASyzG42ZW9Q0eIWb': 7,
#    '7MI23VU7ULV1PaGZoHtiHn': 5,
#    '0MZGwYb5mTATbmoi671wEg': 7,
#    '2yFvdTG0dA8VLOcjugXUPS': 1,
#    '6G6AcK7Y7p3h8hi8egfovB': 5,
#    '2HJbI3twKhkQGCj4R4XSWm': 5,
#    '5Ryu0SlsYjKh78RkJUONFr': 2,
#    '1BBwECyBZklj6svVFlIi3m': 1,
#    '1vFdFfjiYjLtwNM2xAnY4Z': 4,
#    '3jRpsDJGzwU0cLDnazDgyf': 2,
#    '4biJZe036GsCFNp2D2SR2j': 5,
#    '3CS9KbKRetHgdl2t1aXIey': 1},
#   'energetic': {'4KX8vXbouybtUptEyYxtIk': 0,
#    '71zSXauBrA6hHrkJLuxO6Y': 0,
#    '6r3Aomddyv7Be2eUTFDt8a': 1,
#    '2wBRsrnoCnCCG1Il8hwgcN': 5,
#    '6Vw2g9GliMpjMz3vU8coch': 7,
#    '6ApwybiM6oVMM6IpaxtTyZ': 2,
#    '6LVNkUMkEkDxtnCDpHMeN6': 3,
#    '3HGkyQrTyNoLqSmfjKhzvA': 4,
#    '2G0cfoGmCoCIZNGOozLM9z': 6,
#    '53tOwFuBoBEM50N8ele5vr': 6,
#    '16qPkGAjjtZ9dKuSUwpFB5': 7,
#    '2BgEsaKNfHUdlh97KmvFyo': 2,
#    '6gBFPUFcJLzWGx4lenP6h2': 2,
#    '6zq8ZuYvdWiKnsthgNv0k8': 1,
#    '6rGINM9sUnmeEkCWYJ0JDg': 5,
#    '24OwOkMACgku2eAg9pN584': 7,
#    '5skqgm0wCj3bKdKHF7rNvU': 1,
#    '2f6Q20cRfDfPqQenbMTXJO': 7,
#    '39StnYtTSbBQE608FwuupH': 2,
#    '5jJYJthaXUdkHKmiS6TuXe': 1,
#    '7si3FzQV7xcFvmdDQ57ZVt': 3,
#    '3jjujdWJ72nww5eGnfs2E7': 4,
#    '2cEmWBBlCfR9wWrY9JmTyt': 0,
#    '3uVPLtkmDu8pDkYEAVqbgS': 0,
#    '7IQwT5VzrCo7UcMRljkkmR': 0,
#    '4Wui4miiL1JR3QqWcbcKwD': 0,
#    '2n5CkEtbZmhurTRZu0jxrj': 6,
#    '6f7BE3VcZScJx6n3wsf5Z3': 0,
#    '4rfSSc5RuNQ9WlrjSg4dQF': 0,
#    '4okFdEte6SmTcGYuemlqAS': 3,
#    '1OS9fNE87zO4Z696lBXriv': 2,
#    '0PvFJmanyNQMseIFrU708S': 3,
#    '2hloaUoRonYssMuqLCBLTX': 3,
#    '4KgNtIiPXn8O98PV5kow5S': 7,
#    '62WgdE1RiSIw2zBBKIXT7h': 3,
#    '6QlijpGhZPZH8XXpyjUe9w': 2,
#    '0eMfxMrNdLpF8swyBbRkpo': 3,
#    '73boKLgPCW8QuSnNMg62zh': 7,
#    '1RrsCmyR9yUOcFM60IBbky': 0,
#    '0KKkJNfGyhkQ5aFogxQAPU': 3,
#    '0KbPGoZfbrbsqncQcW9IQy': 3,
#    '4XvcHTUfIlWfyJTRG0aqlo': 7,
#    '3DarAbFujv6eYNliUTyqtz': 4,
#    '34MqDD3411uJQvXsqpZv3D': 4,
#    '2hgzdQdnfWwtdpZbhZlV72': 3,
#    '2qT1uLXPVPzGgFOx4jtEuo': 4,
#    '5OAr06c94n3ORwJytObpL4': 1,
#    '02pGUPMnZlHx2VHznAjluD': 1,
#    '0dj5O3Nc6ONKWNd8mErvND': 3,
#    '0XZOPOZo52c5wxb94njsEg': 6,
#    '2X622rIkNwh85wKUPKB1XS': 2,
#    '2WsuSYJNXGKXVYkHPnq2yp': 3,
#    '4tD0JTo3aijmfnl6KipqpY': 3,
#    '6vmPUsrVk873GWkJwygHKD': 6,
#    '07sZYHns2X3oOClU6tHvuc': 7,
#    '6iaSML1PIYq936g62BDtBq': 0,
#    '5A1fw3ySxSNZJAfdSMlnlo': 6,
#    '7CjetOgFvmLba6hCgGnczU': 6,
#    '1Y5Jvi3eLi4Chwqch9GMem': 3,
#    '1RcD04agTYEjAtvYEOJR3g': 2,
#    '7uLFOXgLrS90tEYPO1DGXy': 3,
#    '50I26hs0QlKos1s4c2kYi5': 5,
#    '1hNsP4IStLu68qktbzhDSO': 1,
#    '0DC7Zs2qvAbNK1owWQ4mlL': 0,
#    '50a8bKqlwDEqeiEknrzkTO': 3,
#    '6nbt3gDOYlJRG8yz6hPSSV': 1,
#    '5sWbwccBcyHsg5LEKWGZo9': 5,
#    '1mAKnHmu4XuStwSXho1p9B': 5,
#    '76FZM38RC8XaAjJ77CVTNe': 4,
#    '230wNo1dnexltKYQbsW7oD': 5,
#    '6QicTxeiSaRkPnkGDUvYOs': 2,
#    '0RYFdSlwtwZWi2mHeFPBf7': 1,
#    '2E332aF5PwLmxrLOhuh3FF': 3,
#    '30QR0ndUdiiMQMA9g1PGCm': 3,
#    '6V7g6qM8wheMivMWrzbPTM': 2,
#    '4wVOKKEHUJxHCFFNUWDn0B': 7,
#    '0u2P5u6lvoDfwTYjAADbn4': 6,
#    '2fSW54bA6x2iWePU7rpCiP': 0,
#    '2Bs4jQEGMycglOfWPBqrVG': 4,
#    '0XoBYcbnCoNOZrgiMDJ4hn': 5,
#    '7BKLCZ1jbUBVqRi2FVlTVw': 0,
#    '3rd9naU172zv7PD7x733n4': 0,
#    '1VRltPKyUoyrU2XRWxhNev': 7,
#    '03vMyCyCK7pVWjC1i1zur0': 3,
#    '3GCdLUSnKSMJhs4Tj6CV3s': 4,
#    '40Duf6hCElUKCpstTT7RNg': 3,
#    '2KRt6yYMdyKzm6nBbKL6Ze': 3,
#    '26kPTDeIh5pTcyMuD6IonN': 5,
#    '36DdoiM044LERG9dTQv9wH': 1,
#    '285pBltuF7vW8TeWk8hdRR': 5,
#    '66g2nHRRT6188buMNd4Nxg': 6,
#    '7zCI5JTYKczpYSdKVk0KrM': 3,
#    '0WQcnrsEqrY2e5nexGe3HX': 3,
#    '6DHKC6Nga35RKO15D2xewc': 5,
#    '7epJrOnIefLprxxLXs53zG': 5,
#    '6OYJJ9WyZkikWLquKc78Bd': 0,
#    '43CIWpJaJHRcI4mUSjqgc2': 1,
#    '7jzcoWGOQXGufcXbs7TFVN': 1,
#    '0QLuexVmR2wgNsekPKbv6c': 0,
#    '2a4EjsC0cpRXPQ9moclzbi': 7,
#    '2VfBzanlxhOaBgZ5sb2R6f': 1,
#    '0KQKIASP1fLtjVZA5dspfs': 3,
#    '4ekLf5JvgzXIMMbqaQaNVg': 2,
#    '7JmIjOsRish3vYBSLTytEC': 0,
#    '0HYaC4uGgpx7EIBekhxWfi': 2,
#    '0uqEh3frTOySJMtfIMysPB': 6,
#    '7dt6x5M1jzdTEt8oCbisTK': 0,
#    '4a9tbd947vo9K8Vti9JwcI': 4,
#    '0b0WJSdPsu531iLWZ0FDqR': 3,
#    '1fewSx2d5KIZ04wsooEBOz': 0,
#    '7lgYpkex6NfcjujPa8TOw1': 3,
#    '4UlPUu3Cnx1536SD8c7681': 5,
#    '1R6VwZ8TuHRzxZUxe88n4I': 0,
#    '3ZFxZVoTeM9pY9glme0Ppn': 5,
#    '2CuK8ra980dX567wHylnoC': 2,
#    '5jQI2r1RdgtuT8S3iG8zFC': 5,
#    '2cJiFt99z1JktGLRFHjROK': 5,
#    '7lRsXfGnY0PBSxVMIxuHME': 5,
#    '3UVVDIkcEJSqpUcTIpC8b4': 6,
#    '5jA3XlSxDfv4IZFltS6Mgj': 7,
#    '7uxlLOOwa0at9Yh2uW2uRW': 3,
#    '26gXWzhL8DZJSU5sODhVTs': 0,
#    '5ZtCRfSBH6L6ekP6zDLrhQ': 5,
#    '5R2rsbwCDXORX2tLfprRmM': 3,
#    '3oGbHF3Kdwf3AsRCbBjUxu': 5,
#    '1oSevjov1EOdo8TYcrb5nQ': 6,
#    '5uHymKaQyyZgQb0HbgIQG9': 3,
#    '6yVjDlSjQIZ9aEMaFkObHc': 3,
#    '7pDspg2l98EwYQRcBpmQWK': 6,
#    '7sphBFGNw59cojKtbYZxkc': 7,
#    '6CzdfjiTA6BpNTzdqb9F0N': 1,
#    '39pMuJ3ShxDqb7bBIAXSYG': 7,
#    '4H77Jpd9ICYIGVuKJnXhvE': 1,
#    '5N3Wui8QxBDbsZ0CdewPgf': 1,
#    '0P0mnftxCJtjlKQXHtLLv6': 1,
#    '2FMnEALnICdghl3ikMSXue': 6,
#    '2U5WueTLIK5WJLD7mvDODv': 3,
#    '6gSWp8LVOLYUB5FjvAu0SA': 7,
#    '2PGWwZuMMhkhetYpX2TVnw': 1,
#    '27wbh09rX6NY7wGf8OdhYN': 3,
#    '2oQ4ph6UMFYF5ssmh7A1m8': 3,
#    '0Z1CgKoZXoQYRiqyXhq9LV': 7,
#    '1T6ExogT7pI6wmoRG7Wcqv': 3,
#    '6ZtiywT2Qm50a1uR0jlY35': 0,
#    '4dNzyBSJD1VWC7esROaNvT': 1,
#    '0XJPWKIXZGSOnzR2Nw81i9': 1,
#    '3szFx3SyWFpRbehaPxpyqq': 0,
#    '49Axmi0mWUSJeQvXKlRHOp': 7,
#    '5Iz7YGMtwWvsQpHONmKp4R': 6,
#    '65OVbaJR5O1RmwOQx0875b': 3,
#    '09IStsImFySgyp0pIQdqAc': 4,
#    '2E9Ox6JbcKtRhDJ5cC2QeV': 2,
#    '3ukklzkdKjDzqkroiXTvf4': 6,
#    '2zolLMZwfHvcAmkiPBvswS': 6,
#    '1zvpuqPXqUnblaeocI2u2m': 3,
#    '1OieOuP48UgIfNdekO4fdg': 6,
#    '4jaDsX9mdGp4Kj7D56asrR': 3,
#    '5gw10iNKa8k0UjZnLDxgDf': 1,
#    '74lnM5V6ecvoTPV0fvptx9': 1,
#    '24yNd7yDeS6q2T4xolYx7h': 7,
#    '1GGmo2JXTOJ5Hy2JRgvNki': 2,
#    '1wlZNAKGWSKbXfdf8nByM4': 0,
#    '5nzhL67GpF9szXWg5y509A': 3,
#    '624Qb8O6EKwQaq8nDPzHwW': 2,
#    '0NTMtAO2BV4tnGvw9EgBVq': 4,
#    '5sChpY5nwIJGvHb1uq7Da2': 3,
#    '4uhWhs8VOYRcUi9G0M0OD9': 6,
#    '1YcQdL5llP3lFYNv3drp0P': 2,
#    '55UU2ePEv4noOYpipH74Qy': 3,
#    '2RJAKIw6nIkgZVsAIKhmqz': 0,
#    '2y4lAQpi5VTNLu2ldeTdUH': 0,
#    '5KI6bApOqVwEhctoFbRRDy': 3,
#    '5tErNrwK58SgLMjZXJ5fdY': 1,
#    '4WfjYOo0JxommRm1PyObJl': 5,
#    '02ffsB9p104aiZWgibNUZP': 2,
#    '3JrBzs82BJMj4L1BBkVF2X': 1,
#    '1Myf95gPvCx4gq0dUcBwnT': 1,
#    '25WtjzwiujOhF1i6Rkuoxz': 1,
#    '6mQLN3zRtAp6ovjusyYKrV': 4,
#    '6R6BpGki7hsjDGJEcH86ze': 3,
#    '5bJ1DrEM4hNCafcDd1oxHx': 7,
#    '7qGoMOzR9pJ1bPl4bFmTN7': 0,
#    '3U0xbYGTtYZAUv3lEwPebJ': 5,
#    '4yyX2Iu4xJjW9xMvBZKSBi': 0,
#    '5dOxHHMOFAbG3VH23t0xNm': 3,
#    '3pfB04c93tUlIdf74bWpFN': 1,
#    '2oTonsZvFCMwKbuKW2UqZZ': 5,
#    '2eBa9toOtsc8vaAQDnTZlg': 1,
#    '1dhO5lyN2Otv4qR0xWQXH7': 1,
#    '6OeLDaGaFIFkcijTmiJHUL': 1,
#    '0zbcIc9ky9R1E1OkXlZgeT': 2,
#    '2dckqnpRjV0hrsMywWiYuA': 3,
#    '4PPLJAEYBSOcnzr9TZoqf9': 4,
#    '2iFXAsuAAM7V52ZpaYeL6M': 4,
#    '3Qu5YNbnUb06Jx1XLS86uV': 5,
#    '0GHu9LKinW6AFFLWAd6pTI': 1,
#    '6xSPc6Y1QBFiGctvvaSBYN': 3,
#    '2xGgdpk8jGngVguCfsQG8T': 6,
#    '3NIMU0kcDa8NH21FgmlfHT': 5,
#    '213yvmgTvWQxcOTvnm9rzg': 3,
#    '4xUNPWegC0WRYRblBXuSQG': 3,
#    '5cF0dROlMOK5uNZtivgu50': 3,
#    '6yxYbivIKLQfjdp2Bt4om9': 3,
#    '00iwQgjIgoGO94BRBDyClo': 6,
#    '7wTZfTMYxtRoM83s8pElbs': 5,
#    '0WZFN4E8HrmGUU0EMyKQ8c': 2,
#    '47IySiC5o08gz0z5VDiH93': 2,
#    '22kXvw7mAvMvyZxPnhYzaa': 1,
#    '1W07GDEh8QIVhcs8v6Lsle': 7,
#    '1IruBrVHO0XS9SfXGoYBXn': 0,
#    '1NCUe90ZCiWTnWn3umrwqw': 2,
#    '2SqQokigZwa6XXjClP0Fva': 1,
#    '64JdgBvnvT6etwlLY9UonV': 3,
#    '5UU5b6betKUtcmCO5NqHcw': 5,
#    '72TFWvU3wUYdUuxejTTIzt': 4,
#    '7lAK3oHbfEnvUQWosrMMpR': 5,
#    '4UoDSs5VAw6xHdzbkjocTM': 0,
#    '4W4fNrZYkobj539TOWsLO2': 0,
#    '1tcx5cpqdcwjy5Oo8rshs5': 1,
#    '5syaaFva8b6Kgc1wiHkOFp': 1,
#    '6RvNddeMnAHVSLZiaIhYuP': 1,
#    '1VCwy127XKSprn5WasGtgT': 5,
#    '2i6gFLSVPcv3VG2HLJkOGZ': 5,
#    '0PeWHVfXWa2rgosd8sURLn': 1,
#    '1afIofM4nFYJDUwX3KsXeb': 1,
#    '1JR8vCb6wOe6agZbUzP7Jd': 6,
#    '1VaRnQ7k9btJoJni4uGewf': 1,
#    '0INehbMZOFPnaPBAjK97i3': 0,
#    '6sFh5LihlIcOh6ahYn6UyJ': 3,
#    '0Vd2DLAHPAJWQuehQe3ANH': 3,
#    '40iJIUlhi6renaREYGeIDS': 3,
#    '720zu8RUP9Cdm2L8fCyA6a': 7,
#    '3GpCQviIw7cVeJEgq1IGFa': 1,
#    '4tQYqEg52x22ltin71xGLr': 3,
#    '2gliz6Ye1WECF9O4Mo9hGO': 5,
#    '4sqQci4nqA37mA5tcHJnfo': 2,
#    '43wzy7JxMEfvCh8ZFeZKYk': 2,
#    '6bhBAfmiMdvfFFtY0Rp8dA': 1,
#    '0kN8xEmgMW9mh7UmDYHlJP': 0,
#    '6XO8RlYuJCiI0v3IA48FeJ': 1,
#    '0ZLuW8uOXdFNWcI40C0OC2': 3,
#    '4SWWe2OYC4mqf40Gc2RSdl': 3,
#    '7IBSffWIu7P2MC7kMwy2FM': 0,
#    '7ju97lgwC2rKQ6wwsf9no9': 2,
#    '06wOTgtdzPNKGCago6m0di': 5,
#    '2x0WlnmfG39ZuDmstl9xfX': 0,
#    '33KJ2xFYONOlIYDBg6wPx8': 3,
#    '60R2V0krwXfWyHgD1SmR1X': 3,
#    '3BVt1MH9KaZjQw4W58SUTV': 3,
#    '0ug5NqcwcFR2xrfTkc7k8e': 4,
#    '5aMqxvFFrNQXgTEXooiOF6': 7,
#    '2UhGH49HJPZd5PzkOi1hL1': 1,
#    '6kLjkvjzixcM51ktR7vihe': 7,
#    '2AuWgceaQyfMoI3EGavwGb': 2,
#    '2rB3bbEiGVPkL2mxlzsLSc': 1,
#    '33gwZOGJWEZ7dRWPqPxBEZ': 2,
#    '3rFF7kSm5qBOOPs6ljFgPp': 3,
#    '10GJQkjRJcZhGTLagFOC62': 4,
#    '4Fz2SLzZes7eN1Z4D239TC': 5,
#    '4FWMs0QomD7B2yLiwoTfep': 6,
#    '1H6Q8cBkDB8oGAefUFz9cM': 7,
#    '7cLdpDzMuTJtZuEscZd8t7': 1,
#    '4FEuh8zuTv3IIO8BaCsQPc': 1,
#    '1ndcbIr7B41XWVjJXZaEtV': 1,
#    '3fI1DEUK7gml9W6iFntNel': 6,
#    '5W8jRrZ6tWrTrqnKRtIQBf': 3,
#    '3w1WjD2zJqjBjDz5fwqQPJ': 4,
#    '7EQpvVujgytLVY8vKiDHAg': 3,
#    '2gwkD6igEhQbDQegRCcdoB': 1,
#    '5gxsl39CCgEAr85mz0eU3L': 1,
#    '1qbS5wftrONsF7PO44gZp6': 1,
#    '6VsPKfhj0KXpspPWSS8M4z': 2,
#    '1rpKWA97PYmYI5TLHRuDnV': 6,
#    '0bYVPJvXr8ACmw313cVvhB': 4,
#    '2JvzF1RMd7lE3KmFlsyZD8': 3,
#    '2xB46Bj9HZ4cr058yN4Pla': 1,
#    '7DhLMc82gpUof9X1RC6nW7': 5,
#    '5j6l2MK4cYAkysnBIyhA9G': 6,
#    '7vhD3xirsnmyYTGtNMc1Ph': 5,
#    '4aTyb0MBTzJXE75aHxeGW5': 1,
#    '5qeAyLr3QcoE2h3lUZj1E4': 1,
#    '3xBHLZwRfi0fjO9euaj5zf': 3,
#    '0nbXyq5TXYPCO7pr3N8S4I': 4,
#    '3FsAm9w6AxqwZ0H7nEQ367': 3,
#    '6mmbdTrhT3nd2M6Izn7r4V': 3,
#    '40uMIn2zJLAQhNXghRjBed': 2,
#    '6gpSGgMZoazkhSl1wTjxGK': 7,
#    '317dDsMf2x1lsneSL5xg20': 0,
#    '6zFMeegAMYQo0mt8rXtrli': 3,
#    '74loibzxXRL875X20kenvk': 2,
#    '6gzIcEUuswJQGfJNPYMjjv': 3,
#    '3swc6WTsr7rl9DqQKQA55C': 0,
#    '690XaXR5b2GUwWBVW3ejU5': 2,
#    '6WafpdzdAeSocOxG1YMVRN': 5,
#    '6Tc8jPCCNdoFvL97fIQNgK': 3,
#    '1iSqfoUFnQwV0QW1EfUit8': 7,
#    '0M8LxCq0U5hnu2A9Pn1OeB': 2,
#    '7ytR5pFWmSjzHJIeQkgog4': 4,
#    '1uN0f4NqMDcReSwXO6PLuG': 2,
#    '4XpynhTVh1OX106v8KHST6': 5,
#    '3eekarcy7kvN4yt5ZFzltW': 7,
#    '42NCKlV5TFvgIGAGM4IbU5': 7,
#    '6PWv11SoxcweLVpUetusTO': 2,
#    '6Oq1KQ02DTKtbP6KTdL1ZR': 5,
#    '6ZuahEctZD6w75peme58hm': 2,
#    '3iVq1zq46q0auo3VwixXFe': 3,
#    '3rWDp9tBPQR9z6U5YyRSK4': 0,
#    '5MH5j4AWjgimrWLvp89WK5': 1,
#    '609mekAwxC90JkQ4BDo9IK': 5,
#    '3XRQT7EoS4U87rUuJwg5P3': 1,
#    '3j6Vua6G9chRUJ9dTiOh7k': 1,
#    '2j8MsmmNqmc6UBEA54KOlY': 4,
#    '0tHrv651YF6MT15ht6Kadb': 1,
#    '6BjtaWm1T4kDWAqHrf8vEi': 2,
#    '3AnUQdCODwx2LzDw86WUFk': 2,
#    '617AVCLoRWC5zubb5m2qNx': 3,
#    '4JM00ZVJNlHeNN9LuC5QxP': 1,
#    '5AaQ4Dd9tqlKsjcSQbACtJ': 2,
#    '5IOnrqVaLAQ0gS8gjNNdDU': 5,
#    '3Ahh4FUw5EfmjMzOBjjnwY': 3,
#    '60ynsPSSKe6O3sfwRnIBRf': 5,
#    '6tg9IlbJeHzesV5OWuhDup': 0,
#    '6wi3qtoKT7v3dnXyxrEBDg': 5,
#    '0gV5B7zmJkS1aaH9APokrH': 3,
#    '0t3ZvGKlmYmVsDzBJAXK8C': 0,
#    '2bjUEg4jBtKBlPdNrTAppI': 0,
#    '3RauEVgRgj1IuWdJ9fDs70': 4,
#    '2a0ypNpK5qy4nuVo1eTAeZ': 6,
#    '1Zuja8E6YVErvZidrEG3uU': 1,
#    '2g8quSGCzXy4CeontFI8mN': 5,
#    '5Gu0PDLN4YJeW75PpBSg9p': 4,
#    '0sci7ppTZFm4mjcH3nu8yO': 3,
#    '2IhNiST8ZiY4KPcPSBzMcB': 6,
#    '1B6WqEhaZMCs0cVISXYkkL': 5,
#    '1YM6c2sxbf2Jacl9IFgn4I': 7,
#    '0Ryd8975WihbObpp5cPW1t': 1,
#    '08bNPGLD8AhKpnnERrAc6G': 2,
#    '1umiK6lmi2hK2Fgnc7KgrH': 3,
#    '18Zq1ovdgC9gdQluiOvuaD': 3,
#    '1u8c2t2Cy7UBoG4ArRcF5g': 4,
#    '652n1TA5kwWdBD0So77sXA': 3,
#    '0C3gyphZJY83XplEHz30m0': 2,
#    '7oZaC1tTSw4eqbhIBZENrN': 0,
#    '65gRtgh77JMeOlD3oPoOdD': 6,
#    '733hyyG8U8kxxebds98nc6': 6,
#    '4LAp0EFUdBeVCkusdw8i77': 0,
#    '7CywMqHIeMDkWllJOF7iGn': 2,
#    '7nD9nN3jord9wWcfW3Gkcm': 4,
#    '0MC6LfBcq3EgLMThwvpZHj': 6,
#    '2NnhfuMn76URsQKtlJU4Up': 7,
#    '7LpMG3AEaIJgs62HQhAa91': 4,
#    '40Hmac124CZAlpY5t2ZAXL': 5,
#    '5lIqsVuMQd8YK5rTkdJolx': 2,
#    '2zGezykP4tK3yMcflbCO3i': 2,
#    '37jO7BdASJFew1KtLRXYpI': 3,
#    '6u2RZ32GpvOgUwf0NjNiXP': 1,
#    '7xQAfvXzm3AkraOtGPWIZg': 3,
#    '1cOyWWUr3oXJIxY0AjJEx9': 4,
#    '772YiGM4jlRseASqqG1XR5': 1,
#    '2DtUUBwYwEzKMTMDrc5EiO': 0,
#    '1hHe7cirScEJWgAS0JFqTL': 3,
#    '4vtohpLhudwQh5q1ESJZ45': 0,
#    '1PVza5KmhSJhz12OewWciE': 2,
#    '29VdNzgJIxzlIDkIYjFQqS': 5,
#    '2Ismv7tpgmdyQnKuX4U5jo': 5,
#    '2Y0qqNWmF69eldaec173QU': 6,
#    '02ceqXVaj9etv71M1yncQw': 1,
#    '4PMqSO5qyjpvzhlLI5GnID': 5,
#    '5oXzLfpl6RYu8ZOmOnmBoC': 4,
#    '0cslulzapJw0zPoaOuR72O': 2,
#    '7cgu4JBW3hq1GwTM1ilkKQ': 2,
#    '6mDBmG64QSg09onp4DsGX8': 5,
#    '5jfkhjOOHwuZeNQ9hpIEYE': 5,
#    '7pbg3ABlAZv2NiIdKbBBFm': 5,
#    '749LoYyGJ48SbUxb36GgTQ': 1,
#    '2LNMhZ3YijTO7USmqjgJfG': 0,
#    '2TRFIQpTqq12xGpFJEr0Ft': 2,
#    '4Jhg2SDKvJ7SSlmEjhzpZV': 7,
#    '40EzsYqmJjQ5PonhsxYIO3': 0,
#    '0yFtaHw58tl6o85ngZbfLW': 1,
#    '5x7V2AtVJ140NSgBuf2lt4': 0,
#    '0kIAP74p31aDbkw43QKXa0': 3,
#    '4Hm0XYgaJr62dre2PTzN5M': 6,
#    '0ekPOYOJPlwgTRS1ktn2aW': 3,
#    '17Cs25j5Ui6X6W4Hk1kAyC': 3,
#    '2dRMUKbrPHaSm8BIk6OFSf': 2,
#    '7MhNCT34oaLIxwAsZlZd67': 0,
#    '7E8edqa0m0ASLXkLfmWY03': 2,
#    '3xB1DEIwXnnVvCyLCChBBn': 5,
#    '1C8ux1YWLMHCenYJFiIV4Z': 2,
#    '1mXVgsBdtIVeCLJnSnmtdV': 0,
#    '4MnaV7yPUmglATd5NHo2HH': 7,
#    '3zkWCteF82vJwv0hRLba76': 4,
#    '6jRq8gaZhMUyy5RclRPcAf': 4},
#   'excited': {'5iRNlitNM1y6otuY7EIauj': 2,
#    '2FBpJGt00G0h1q0RHuqaGO': 0,
#    '5GXAXm5YOmYT0kL5jHvYBt': 0,
#    '3IhnjbmCMolLE6ozY9PkD0': 2,
#    '2xJCMIJfcNYDc5iR0sAm2O': 4,
#    '0Qei4siljQFgkzyVnnMfYs': 2,
#    '6SqqsrQBdYGNuLJzo6oRQY': 2,
#    '78R4blSKh3hMdvuETzsYSL': 3,
#    '5MQLnJ9dahA1v3NGInWcne': 5,
#    '5TMHd1VRhAIHjnefZl56WJ': 5,
#    '1gPVp4acBJk7vdTTwDs6rV': 5,
#    '3Mvx7WvQxXys1x5Vj4KpTB': 7,
#    '0OI7AFifLSoGzpb8bdBLLV': 2,
#    '5O6aG176PhWlInVb6HvVuO': 5,
#    '6xY1ldUHrzsV6egbnzMuAs': 2,
#    '2N3LQk27fglVbVqQ8zA6lQ': 2,
#    '1FqGIiTQT5Ij2mdQyngUUu': 3,
#    '2WsuSYJNXGKXVYkHPnq2yp': 3,
#    '1RsKgszIpSiLONHeaG3G3C': 4,
#    '5BojMTUzwug3YQ21nThLhv': 1,
#    '3fPdf6VIr7m3CkPh7HwkUf': 2,
#    '0pAPFaE1Iwfvex9EVJuQlG': 5,
#    '1IbM4DZeNdG8LdmVsicM8A': 1,
#    '0n4YRp7oXTcsWTpyUmOKij': 5,
#    '1L2L1Tu1ngxvJ1k6R7nad6': 0,
#    '3gruCKVuhCsRjs3a3dG8CA': 6,
#    '3fEpuoSr8ufvyRR7s2jB3U': 3,
#    '5RfhBzc2RxL6n5mXxFZkHd': 1,
#    '3Bbx1UN5T0KH9uasjSSZ2q': 3,
#    '3IsVBIr0rZk2leqPqFezRV': 3,
#    '4BhGTc3Cgay2U1QcTS7vQe': 5,
#    '5N0fCfFgNKqoxIUPWvAMcV': 0,
#    '7pXKHhayzs2JVDP5VKxUo6': 3,
#    '6sBB5CBuzKJhDooro1IraE': 1,
#    '785dxwmxBRiqo9byQmvcdx': 7,
#    '0mtmrbRFsectINNpHdDkUQ': 2,
#    '6sjPU5PnFW6yW0BWMUbChy': 1,
#    '4UBKe75v9DYcehHirq4ot4': 2,
#    '0B0tYbVp7pDQAqKDhgMeaL': 0,
#    '4rkUEE5iTzG0szS8k8QzqR': 5,
#    '3qP5RxLNzmLa6bLb9FFGFx': 6,
#    '6AtpT1NzEgXmimb8x5kt3p': 3,
#    '0sSRLXxknVTQDStgU1NqpY': 5,
#    '6V7g6qM8wheMivMWrzbPTM': 2,
#    '2Foc5Q5nqNiosCNqttzHof': 4,
#    '4odWmR05uVl3Adkas6Ap9e': 7,
#    '5Jd4va2HRPEwVw5N3xeGPL': 3,
#    '51rXHuKN8Loc4sUlKPODgH': 2,
#    '6Vh03bkEfXqekWp7Y1UBRb': 2,
#    '4YS0JF9kSLe15ggwOQqQit': 3,
#    '6QFzUXTIZXOLesQcgmGOsR': 1,
#    '0qn82f69SmdiiL8LSgEoSu': 5,
#    '2wtJbMAEeCICHkszAggSw4': 5,
#    '7IBSffWIu7P2MC7kMwy2FM': 6,
#    '3XVBdLihbNbxUwZosxcGuJ': 6,
#    '2VdT56BGpdqNHUgOe1j5vc': 0,
#    '3q5vVM2ogQWXxRjnMjhCrF': 5,
#    '40oKW22ZNNkEdZLJTScaQI': 3,
#    '18Ro4a1rAWkjTGcp8OkUV6': 5,
#    '0HGGx9fQ55LFw5QFIB5MKp': 5,
#    '6MF4tRr5lU8qok8IKaFOBE': 5,
#    '5oady7OSE7dH7LHiqmb3Cr': 5,
#    '1AYNmdKudx7JArl2uDy1nv': 0,
#    '1Zgg9isn6GuQSzufRjdmOG': 7,
#    '6n3HGiq4v35D6eFOSwqYuo': 6,
#    '4JIPyaaceaEZtOJAWmzBzF': 2,
#    '7aftSOGSOpSoIlVAQVBb71': 2,
#    '6eT7xZZlB2mwyzJ2sUKG6w': 5,
#    '12DtP4CnaV39FjcFP8SoG0': 5,
#    '67juGXaqmo3uldt3rknTS1': 5,
#    '1ALQx8OykapEaMlDxIZPEw': 7,
#    '24f3lQnwL9vL2GUu8sdoBP': 5,
#    '7g4eFCMPlbJlPzXM90txva': 7,
#    '07hEEp1PRNkQBZEcF5mJo8': 1,
#    '6qxJxf2azj13JA7I3N6AVE': 0,
#    '0mfpBXjYkiYt4Qrr2aFQ6U': 0,
#    '1h4nOgOv7cMZtjpyJm083Y': 4,
#    '5kxfejZRUEQMaH2pFUi7sM': 0,
#    '7oxy6gcerLrJ83E1dynA7W': 4,
#    '4ii5S0UcGpdAANl098llgB': 6,
#    '3Sx8k6SH4gqMMjS7nqLcJR': 3,
#    '5CSID3PvGYFa3zNgid3ClE': 1,
#    '48cHZXUlzIVCRYW5XR1tuT': 1,
#    '4ujX9kC3UUp26MG0tPhUCz': 7,
#    '5SGYanjZguKYg5PgVzFsvR': 3,
#    '2Za1AlJNvksouPPWbXpR2X': 5,
#    '1TkKRN0nuTlRWUmrvzKRkd': 7,
#    '465mhRDuwxjrJ61UrvRvrZ': 1,
#    '7eYAHC0RbBF9eaqWzT34Aq': 0,
#    '7rC5fxyrbNDRymrH7OwSxE': 5,
#    '7FtZFla3ZH6PqsAJ9MvVCM': 1,
#    '5HVdyKabHJcjSbJcMKUVCp': 0,
#    '6iaXP51tRc5gBWmESaI85u': 3,
#    '1WlU4jsJ8AoTB96dgd8LJA': 2,
#    '48td6xvpokdYwvbl3JIiXP': 3,
#    '5QHiWzDN9z3qkLyvM1w7JK': 3,
#    '0Z5ok0QLLttAKsujOZYOXf': 6,
#    '7DgQ7F8TgV6ZYkovedf8bJ': 1,
#    '0VhgEqMTNZwYL1ARDLLNCX': 5,
#    '1QV6tiMFM6fSOKOGLMHYYg': 3,
#    '1G4cdOtF36ZCs6i2dZoC87': 0,
#    '6tiKwZppNjrls8RsPQwK6r': 0,
#    '5yuShbu70mtHXY0yLzCQLQ': 5,
#    '1MouEw3cQid0rTdlAeidGx': 5,
#    '55xNjVrGJxgqcEFqCyejTM': 5,
#    '5cF0dROlMOK5uNZtivgu50': 0,
#    '0GuhX81IqyufFB3VdVzUbj': 3,
#    '3qa9CI4W8SQf85VZzi7GIQ': 5,
#    '2cOUlop2ZakjOKe4WinesN': 4,
#    '2kqAtjOtQPAR0OiYUJR43k': 2,
#    '3AALcuKu2uN5VChEChnD7v': 7,
#    '34h7O0d0ToOB60zYSFkGKH': 4,
#    '4UoDSs5VAw6xHdzbkjocTM': 0,
#    '0nrRP2bk19rLc0orkWPQk2': 5,
#    '7dt6x5M1jzdTEt8oCbisTK': 0,
#    '4VFE6ZNqa8jHAmbYICoAFg': 5,
#    '6UelLqGlWMcVH1E5c4H7lY': 4,
#    '0U1sNkzPniZBCFWebiaRnc': 1,
#    '4vy0kVo1ygAIKTZU3F5OoT': 3,
#    '6BjtaWm1T4kDWAqHrf8vEi': 2,
#    '1I3ZAmPmbFV78oNKnibOiW': 1,
#    '0mJBiaODgK0XjOLCN5fItq': 5,
#    '1Vowce2imLRD2QjZl1tULo': 1,
#    '6YXxeDNipkeI0kV6v7QD91': 1,
#    '4cluDES4hQEUhmXj6TXkSo': 2,
#    '4SCnCPOUOUXUmCX2uHb3r7': 7,
#    '3wJJPeMhR7A8t2AkCoP9Ma': 7,
#    '5uu28fUesZMl89lf9CLrgN': 2,
#    '04FG3jfxbSViVX9GYItO4n': 4,
#    '0xr7t6jQWzFsZ9XwfcxAu7': 7,
#    '4e4fqjx0Izh4svvTef1z7e': 4,
#    '1WClVHO9OFHAqMzbwLmtO6': 3,
#    '00h12tbjC9Aa5uEuq9HrgO': 1,
#    '6MO2bfLHKykUgCChFdw91H': 5,
#    '1HXy5I3HTWq8OvxCn0z7G7': 0,
#    '4IDXbulI13UDcEu1EHvMR2': 3,
#    '3WRIaWsws011vHMd9uzPjG': 3,
#    '76hfruVvmfQbw0eYn1nmeC': 3,
#    '3b2SHFP4bIkcNFSvHDKG9E': 5,
#    '5VBueqGOsxaREV9SLDqz5w': 5,
#    '20MuVazoNMv6xjKPnRFOxG': 0,
#    '4gL8fyRJwOsRIwWi7TXR0n': 6,
#    '0pJbK7BzmaG3nr9nxy6o3u': 3,
#    '68prFxyfOaL335N8KnrPX7': 5,
#    '7Hg27Pwfh9iTgHUdGS5rTx': 5,
#    '2HEsewd9dzzLg4751JIS4p': 0,
#    '1Dtvx1a5KaoCuCIrG032pN': 5,
#    '4pY7nKcWT0Kjey8ycuW6wM': 6,
#    '7rErmb9ztCh29H8nWmavQz': 5,
#    '2t9kiToH8pMisasP7Fq5jO': 1,
#    '5R2pz8i4k4bvRAqiIFXzKz': 2,
#    '5JycxhApZmzbA4xSwvqh6k': 5,
#    '2Y0HyCSVZ67Ri16Fi0peh1': 2,
#    '0FJIu5hx2gl0etJfz24al8': 3,
#    '2kYB66omjIRkqPx8zRPEAH': 7,
#    '0MrRAUcB8AZiB9ue2VOBYe': 2,
#    '4R4ZPCBWp2aGcS2rzUP5qd': 5,
#    '5x5JM1BSB6vollcIzDocqT': 0,
#    '3xBHLZwRfi0fjO9euaj5zf': 3,
#    '2s1imOhCAAdApnMs5zZUYG': 5,
#    '1XjXU5QseFCdZfda2u63hB': 7,
#    '4SWWe2OYC4mqf40Gc2RSdl': 5,
#    '3q0U6eqmHObU2cy0O6VHGS': 3,
#    '0JeLwrv6BWt6vO2M7XYSfx': 1,
#    '3WcC6NH9J77xPEvj1SOL7z': 0,
#    '28a0aMV1OKoyNiCJuNsWrY': 0,
#    '2BgEsaKNfHUdlh97KmvFyo': 3,
#    '6tl840rz5kY1ybVjv1jre2': 2,
#    '7hCNBVRhHzcsRAv0TQnOzq': 2,
#    '4lH5L59hPQGr05aJyb2Q2E': 4,
#    '5SWnsxjhdcEDc7LJjq9UHk': 2,
#    '3NWrHCwvyII4fTx05PN3IO': 5,
#    '0F7FlaQBiyNkV8iakTocsW': 3,
#    '2fQxE0jVrjNMT9oJAXtSJR': 4,
#    '4SIB2yxKoFOrbkjA4zfQbB': 7,
#    '29ZZAShKhwRUuKULSNtxX6': 2,
#    '55HA7BDCwHhWbtlywFifL9': 1,
#    '7BqBn9nzAq8spo5e7cZ0dJ': 4,
#    '1rlIrbWboTRGeKfHhgbJRZ': 1,
#    '3IaZZj2USNXAvWQIH4z79y': 4,
#    '1tyjWMMINb9S0YBynTvJ7s': 3,
#    '0kN8xEmgMW9mh7UmDYHlJP': 0,
#    '4HlFJV71xXKIGcU3kRyttv': 4,
#    '3LAELphM5luYQjVsqQYt77': 0,
#    '5M38MWA6seLDUqZrW4n5q3': 4,
#    '6QqF0MqjQVotftZIuQUbvf': 7,
#    '0XOMoQbYxYPVLxwK4VDmNA': 2,
#    '2y4lAQpi5VTNLu2ldeTdUH': 5,
#    '6k9nsVCSf6QO1WnFsCsmVf': 4,
#    '1VjNQAm7bG3MLIC5Cwb508': 4,
#    '5sxq1iFhvcqSbS86Cws8aj': 3,
#    '5yAvJs2chb8yIZDuJ0eB0i': 5,
#    '0ug5NqcwcFR2xrfTkc7k8e': 4,
#    '0oufSLnKQDoBFX5mgkDCgR': 7,
#    '2kE82JhBcoS7mimFO1SqqX': 5,
#    '11tyDw8LD59AJIOAW3Ga3n': 3,
#    '1dzQoRqT5ucxXVaAhTcT0J': 3,
#    '4MnHvx4W6eMx4d2vZP5ONK': 0,
#    '0YEsfwQpG7ofdIiHWA0dHi': 4,
#    '4rMNgxEwGWoPHIUcvB5BrB': 5,
#    '2QgfDF0fQ4sskDthP8MG5w': 3,
#    '0At2qAoaVjIwWNAqrscXli': 7,
#    '6uFn47ACjqYkc0jADwEdj1': 1,
#    '5G2c6FsfTzgYUzageCmfXY': 2,
#    '01sjbEk3X7KNXFvXXXN5MY': 3,
#    '5R2rsbwCDXORX2tLfprRmM': 7,
#    '1vhNdj120DThwevpJnr4q6': 5,
#    '6HR1z11h0ROUlWP4Kx8Z7G': 6,
#    '7yWQRTDYazfVjFvmjtYfGQ': 0,
#    '1suqXPrYygZ7BYiSfaVZE4': 2,
#    '2LdSGJ13cYo60zroZe81Nm': 5,
#    '5l5TCOCroxvDmeoYRmvKMM': 5,
#    '3KbFtYPyVP6C7BQVgH2cCf': 0,
#    '4pM4yFNLj3pTiNXOZsWYxf': 5,
#    '1likxiGuFOCkY2WtGbHj3F': 5,
#    '0laYHRpNTS6i8FXdupHkJ4': 3,
#    '6lV2MSQmRIkycDScNtrBXO': 2,
#    '2t69g7j808uReNkYlEgZEu': 6,
#    '428JUvntvW20r9hOOpFAao': 7,
#    '6b8Be6ljOzmkOmFslEb23P': 2,
#    '5fyvUqw0Vu6qTM4DSkDUs2': 2,
#    '0FCoFdzveaZbjMjcySPnne': 3,
#    '2t8yVaLvJ0RenpXUIAC52d': 3,
#    '5wJL4o7k8m02m6ZM9KT0ir': 3,
#    '2wWboDFZJPWXVNlHUbdSVQ': 3,
#    '7qiZfU4dY1lWllzX7mPBI3': 0,
#    '10GJQkjRJcZhGTLagFOC62': 4,
#    '30nRBCh0wGhKiTLNWN3k3L': 5,
#    '6jBCJZNeb7wfl8TkUYd0E3': 3,
#    '1Ob3As06bnPkJqXLIj2tA1': 7,
#    '2rFqkDRJlumT7QjljlldlR': 5,
#    '1UgcHFkETFCydO4u8JXQMj': 2,
#    '6hHMhS2HcjOmlQ0BSDyfI9': 5,
#    '4Fblf1aEOkkjpoGM8E1ppV': 1,
#    '5PvVkf1Yuq3XyMqqjPiKPd': 5,
#    '3fpVWegR6YOS1Yk5HSMYIq': 3,
#    '3LfHBTYZBTqmz43tvVXJBd': 7,
#    '20GMMjB8izelaRWY8qQs7Y': 0,
#    '0US9Kpq72rwYU1AFt0Ni1N': 1,
#    '5LKDSAdfK1DdQBeizkbd1t': 2,
#    '0OoNzMdPSgbkM5MkcuEZfm': 5,
#    '04T47lGsiQU6x1cV9GhgDN': 3,
#    '22WFzQGH1J8FrUIc2o3eKz': 3,
#    '0tgVpDi06FyKpA1z0VMD4v': 0,
#    '6s6LTQl0hrFd9Hx2kF42bx': 1,
#    '0hPLZrnDgtKxrym1BHjDhd': 3,
#    '0SbOpoBzBBCqWIcvo94JeD': 6,
#    '0xcFH3973DZauDkGnNjMgm': 2,
#    '3wLtYwtqvKK2ewelSVPeDK': 3,
#    '0pxq04wmOwW0uMxnqoG21F': 0,
#    '6QxJ9Oe0dehbGk51THaxoq': 4,
#    '3Vo4wInECJQuz9BIBMOu8i': 3,
#    '1PgBYvG7wziTSmZdDLYIvn': 3,
#    '4BYMzeiusYBat7qjpjuv26': 2,
#    '4Q34FP1AT7GEl9oLgNtiWj': 0,
#    '7zLYKWcXnYeHHWidalz7rj': 5,
#    '5kkaSMcf4BFlhRRICCKZb6': 6,
#    '4wVOKKEHUJxHCFFNUWDn0B': 5,
#    '5KhWSvBNRGxY5I3t0X6f4w': 0,
#    '0afhq8XCExXpqazXczTSve': 2,
#    '2ZLSnT49tvHVEhrhsrw483': 3,
#    '1I6pKIyaBp4OebTGLJpCCC': 2,
#    '45o9opPxXwQfK3fHvEHnvB': 3},
#   'happy': {'5IEqZd6NOoVSWk4ehFdbgG': 1,
#    '5X4L95J8q2AdJRQedrWINM': 1,
#    '4LHJUZCjDrjI7mQEbM48r3': 4,
#    '7dxWG9qRCq2NyUsNES2inQ': 5,
#    '7D5Sn4Js8AkducmrO8nOhC': 1,
#    '68HVqTvtboLvUpCHN3685j': 5,
#    '4giv4l0m4zRzKzvdISpDzZ': 7,
#    '206CWNlXy1wLw3nchSDWJA': 3,
#    '7mN6Y61Xo7k7aoxkuqzXlz': 4,
#    '60ikLb85vSEVkZKnNyuFic': 4,
#    '7ycWLEP1GsNjVvcjawXz3z': 6,
#    '6XBkVK0XMeSkXyG6lN2QDk': 5,
#    '7z4SjTEQ90TvqXcqvaXKD7': 7,
#    '0ZTnxnWqzIyClPgZdsC2vk': 3,
#    '5JRMqkR82k2fdDEAim9SCN': 5,
#    '2F0MOLTF1sfgt4ZGW8wF5V': 2,
#    '1SDMJYKkUd99L1xqo4DMOZ': 2,
#    '4CPJQmuCA7iyMEdefWhfl6': 0,
#    '6efkcs2aUBMFKxl0cl2JWQ': 5,
#    '2DAKrNS5I635XFMRHRntSJ': 1,
#    '5367lywm1ux2wROgM16U4l': 1,
#    '4M3989riJy9ycXY3KtkSaC': 6,
#    '6wR3zbFumY6hfNgN6xtrBI': 2,
#    '0Dfmwxl6g35vW10qcU5UN1': 0,
#    '5naYe7rLMZcLfO1DKg48MK': 2,
#    '0zFComc9VzjCKWm4PSbIJk': 1,
#    '45WkcBtgPS8xulUwEg63X1': 7,
#    '0A2uZyGMFhSgyzslK7LGof': 5,
#    '5jxoCMBtObBUFFsGIeqQuM': 5,
#    '0u3dPRxI7Brk5z1x7VNqB2': 2,
#    '036b63gNyc8VTNosQWa0bs': 0,
#    '39cyYJtB3TMyCSedqoIjRz': 5,
#    '6flhrkPIIqB0zU8j2T2yyc': 4,
#    '10TOeMHUDPkswPClP45U7z': 5,
#    '7gPHxxAq4YjK7GoLT3Vch3': 3,
#    '6uJONCdr2rC65BNmCnTBWK': 3,
#    '5ODnTtYMnow1nV6WIdS87j': 6,
#    '3Bx3EVl8dVyrbSlXksAxxK': 6,
#    '366DLDHAnvMnHP5ECYt4N7': 1,
#    '4J1s9DYFmN0WW97WRzAGRM': 3,
#    '7GG1QIQ547taCwl1uLaTf5': 3,
#    '0XkeL2XqUAZIY3LCqdkvEq': 4,
#    '0q75NwOoFiARAVp4EXU4Bs': 3,
#    '4kZhSFSY9NUYMYD1gOzeZA': 6,
#    '4yYqTEjw9BRbmOeG9p30uI': 6,
#    '2ltlseRQEMyEjDkzqhk34s': 5,
#    '6T3l1Ov2VpZdmqN7PLcMxP': 5,
#    '4ukZ5RUJMbIyS2tOhooPNY': 5,
#    '3ckOqEMTFIHtVGn2XCgO8K': 1,
#    '2PB428pRLBrW2IONANRbB1': 4,
#    '5ZHdSdhLl9d79wasqTn3Ax': 7,
#    '40mjsnRjCpycdUw3xhS20g': 1,
#    '4Ami4MTReWxztxGW1ZmOk8': 1,
#    '6MgjpAJ8gwzpACBS0SoV6T': 6,
#    '086xJzFlEYeCrQmFIVizMb': 3,
#    '3SXEmuNyGN4GfVBFCxoRIo': 7,
#    '5lLNBIyjp72btcnrjBG751': 3,
#    '2BPdf6ZdGD8WXm70dPSZGM': 0,
#    '3q0U6eqmHObU2cy0O6VHGS': 3,
#    '5CRkUL8PwtIbYCUjXUkZCh': 5,
#    '3KKGBhKtAyspFBw8FtNQrL': 4,
#    '6YBxEjM8ZkO8vMRy7vjiuf': 2,
#    '7yWQRTDYazfVjFvmjtYfGQ': 2,
#    '0j6Zd4442OGpZHsjQDH1rA': 7,
#    '4MZVVsxYzCPL7kabGmczOC': 0,
#    '0eNgIp2VlMKIaezHzDs42U': 4,
#    '4Aocy7YAyOYf5YHj18Vfj3': 5,
#    '1zFqYEYQrz5mkTxFM1yxXy': 3,
#    '7BS27vWbRTmCkSEpeFZRRy': 2,
#    '688QpQAwqsLdBR6lr13wK1': 5,
#    '7vdv0eDg178o0uUtGvRfm8': 3,
#    '2o9IBHA5j1wB1p9Md2QZqi': 6,
#    '7lgYpkex6NfcjujPa8TOw1': 1,
#    '7pMRTKzR2k4JNTzPDJrHjm': 3,
#    '4SCnCPOUOUXUmCX2uHb3r7': 7,
#    '6j7u7Q5deIiRlkrFShofyz': 7,
#    '7BUjnisMmZJQP30tLA25DD': 5,
#    '2wtJbMAEeCICHkszAggSw4': 5,
#    '6OieTz3MN0a5jXsnkI6biW': 5,
#    '72dDwYXwF7wOQU7rOz8sE9': 3,
#    '3oykaKHbFdUvjS69m5lK3n': 5,
#    '2aOufD9FiarF4jDaxo8B8c': 7,
#    '4hqOmrCCJKyiuwDexd8c2t': 5,
#    '2mT7vV5A5SEUwPo0Q3wEVf': 6,
#    '5LizNsBvl1DvlA3UpvgJdQ': 0,
#    '7p4tetW3qNwSCz92PLGJg5': 2,
#    '1PhwQEsshs0AqhxbPMRVU4': 4,
#    '1cOlfNiT9Nc9kgE5SoeS2N': 0,
#    '5jwakA3WYHMeucmgu0tjbD': 5,
#    '1qUdAB72nSWPZwDqH9KMYD': 3,
#    '2nSKol7UyxwffI6jLYTuUd': 0,
#    '5lAziil6mBTE447oPBcOIA': 3,
#    '1BtdzYewRepGafV8ohDo6d': 0,
#    '1xzBco0xcoJEDXktl7Jxrr': 2,
#    '42o2Dbu5R27rhWaa4g4xdK': 3,
#    '7EwCsCBbGoVNb4vktqCbJ7': 5,
#    '0FBWSrWmslTXl0bQq7IOgh': 2,
#    '0nbXyq5TXYPCO7pr3N8S4I': 4,
#    '3AV73x3dttUZfwGVpMkobg': 5,
#    '7rbOo9HePzCK98ujQx9ReY': 5,
#    '2IMxBnxu3m0DByGJrBAzUT': 5,
#    '75jnDgECzi6uY7bCtsJknr': 1,
#    '1DZjCQCUymOXw4svpC0WyY': 2,
#    '0fFWxRZGKR7HDW2xBMOZgW': 2,
#    '3R9j8urSPiBbapNbyuSYkE': 1,
#    '40iJIUlhi6renaREYGeIDS': 7,
#    '566MMmfMJwlR7oQgRyW2w8': 5,
#    '3tI9EAz2qLao3SWjznbMLn': 3,
#    '49m4jOwcyrSektySzKyUcg': 2,
#    '2MYlc1fGFG4DQvbeSMVoUK': 2,
#    '7f0clCgqcoDTTNxyu5cO8a': 7,
#    '3iVq1zq46q0auo3VwixXFe': 6,
#    '4Ghlp3UUtrYBmkzRB1m032': 7,
#    '6ZelF5APDN5r6XnFqcnvWR': 3,
#    '7s1cqDP1Bgc29merDKM4ds': 5,
#    '7p17D91YMHqR6LuhnDcR2D': 1,
#    '1mFdyuUq9c1uTUqlyyr2Wq': 4,
#    '19q8gOEVAyK3yVEonguoOc': 5,
#    '6tCHedziuLVAceViNWK5id': 0,
#    '2HKlkeWtk7JkikHmXOEcPk': 2,
#    '3nIlBeSIVnDbWFO3mExxV2': 7,
#    '5T74psry87CqdhKzhTxqpp': 5,
#    '1STkjkaPuvmfJPFU8V1pNm': 2,
#    '5IckhJATD1gMHqzpcU0a53': 5,
#    '1o8n563oEpZzCj4qTIJ0NM': 3,
#    '4ABM7D05ULpP8CGyuDJ1Yg': 3,
#    '3b8ovywNFzaiVpifmivkmU': 4,
#    '48S4mJNtmuC16ptPecFGIh': 6,
#    '1sbEeUY8KsdvgiQi26JBFz': 3,
#    '6Yhd7StWtv1dzEXiURMbZb': 5,
#    '5TCLguzJxNZFLcV86PyvbU': 2,
#    '3UHyARzPoREpfAz7m3NkYN': 6,
#    '7sdqtgsO9zxvKdrrVDpaNu': 0,
#    '4oVPwYfvilX6sBMnDylHyc': 7,
#    '0A7xgfdP4RKVJD95kF0dx6': 5,
#    '31T0Tuupsv6N0e1sfKuSSo': 5,
#    '0fUSBO3OpWtQHIXqwzvZAp': 5,
#    '7foypmc7KZyU716Yv63BPe': 2,
#    '1CGQTaQVVfA0CNae8IwPyC': 2,
#    '3lSDIJ2abCrOdDJ6pshUap': 0,
#    '26oFhG0dVaooDg326Ohof9': 5,
#    '7mwGxVzcNze72t7F2Om5dh': 5,
#    '4M1mOA5zAUjURc79Zkaq2D': 4,
#    '2V4l1eFzP7imN2HrWmDHxy': 5,
#    '1FS6vFCosOyOGcR28cW7jK': 2,
#    '1YP1siGyGIvrxYNSqxgjLd': 0,
#    '0CfmNX2TXk7yoJqHJiixnp': 3,
#    '2XWjPtKdi5sucFYtVav07d': 4,
#    '0A5gdlrpAuQqZ2iFgnqBFW': 2,
#    '2kzEf3Bg7S43YuSFPI3462': 7,
#    '0xoC4iuSQz7qxtB6UI92IJ': 7,
#    '7Ib4HxrkMe8iHweXxMsev5': 2,
#    '2hKmsv270gdqt6r5dJjOsE': 5,
#    '6WOC0K8SGct3PSB2F8iQJP': 5,
#    '2q4F6OpQgx9umNB9uGFPYo': 1,
#    '0T9AvdMYNPi6eszsj0M30c': 5,
#    '1MgL0ArBZIqXONY0ilfIEf': 2,
#    '5E7D6pwvNV7oOYEoVQaL38': 0,
#    '749W3kDaSYtSn12pCF6gd6': 5,
#    '2hwOoMtWPtTSSn6WHV7Vp5': 5,
#    '7onHzHeOVE3M9p0tNKQbXc': 7,
#    '0AuPeu60S9nXW61rneYxD1': 1,
#    '76pUKeKLQuxjFFfbXJ5dif': 5,
#    '3ZfuCvTAxfvxBVlQfKtadK': 0,
#    '315erlcEdp5JqHqQQLQTiD': 2,
#    '54yCP5dfn4uvU5h37aE8f4': 2,
#    '3lVoXGfuXkf6OrokztiTqx': 0,
#    '14wSJRbvcAjtpmWq8FflSf': 0,
#    '68KVmSqAOYem04YsC37U7B': 2,
#    '0NEMefYAVKeRUNyosJVRi6': 7,
#    '78Tqi4M6TYBwqRvLDhOMOF': 1,
#    '10kkgS1Ua4pgXORO8dUtDL': 6,
#    '1nX9KhK3Fff27SnrIor2Yb': 5,
#    '1AYNmdKudx7JArl2uDy1nv': 0,
#    '3WRIaWsws011vHMd9uzPjG': 3,
#    '6GjgrT8fvfEehxDBZMZTRZ': 4,
#    '2J4T0IOIZjQhLzosKPR2PN': 0,
#    '6EW1fwOk4JHmTZKINZsyjB': 5,
#    '5Q6DJEgNTiN9xcOQzKmw9F': 0,
#    '4lhfQGsmEHSluuFqyGU8JE': 6,
#    '0SDrD96V1uEJLptciyML9s': 5,
#    '3s4mrPrEFFPF0LmAfutW0n': 5,
#    '1j6kDJttn6wbVyMaM42Nxm': 1,
#    '2eSnW4d3A4SyEVhVPmBffa': 3,
#    '3iOK7EbYFLtQyz9jwKIw88': 6,
#    '2Vgo0mLTvZj6jWFv4Nqgo7': 0,
#    '6bfrVpzzSGhYlZZcRGt0e1': 7,
#    '2sszPmrr2g25pKWiGudvlp': 0,
#    '47fLJgV5DWZXLl6FEvPD28': 5,
#    '3PtkyEjqwMz4fpSjo9ADNf': 0,
#    '29qRIyGVrmRiCdZpHAVNa7': 2,
#    '45CiDBvF0HNtAHXQFfnSzD': 4,
#    '6eZNvqvoJUArNvVSKMg1Sa': 4,
#    '43LHR1MCuqPluDS89VeZf0': 4,
#    '1BjF6aXMb0RUckbp6mbX4m': 2,
#    '2zRmDaYLsDw208NFV7CpFj': 4,
#    '2otqZVvW83kij45qpJaipl': 4,
#    '4zrwPfq5ENLzjq41Txs2HR': 3,
#    '79JqbyvbJ7Shub94aKID7P': 5,
#    '0tlM57cmnhLbHwxU8hGox4': 1,
#    '4cS7Sd0miXi8xRF1XTZHyN': 5,
#    '0cge96qsW6ifXppeiiRIGd': 3,
#    '5u6vkDnOyaf8LsteDAj2ub': 5,
#    '1UoIxOgN7skrYeTdJhKhxS': 7,
#    '5sUce9YhLCEltoYFjdHL7c': 5,
#    '6ImxYXeLDQPIv4qo7bMhSk': 5,
#    '6YapMTu34xuchs2ggp0k3Q': 2,
#    '21HeQbniFVvdtVZVyl8ORw': 3,
#    '3lRhAvgOzmzHOXqzbNJduS': 4,
#    '7HHQv5b9hjcRbaNoF9hNEX': 3,
#    '3avPiwnrXifS0lFihYpzDk': 5,
#    '7166FiVEnGCG27MITo4kXC': 1,
#    '7IBSffWIu7P2MC7kMwy2FM': 6,
#    '2fwkl5Z8ujDtAh6qxEA5x0': 3,
#    '1udwFobQ1JoOdWPQrp2b6u': 5,
#    '2Z47f6DeKm1xIDmPPn2sGS': 3,
#    '34dEWnWlThEqkHiASAy0ks': 6,
#    '1QZZHF6IqLK4e2hnMq1m9z': 3,
#    '5Jn3W2PPpKDj4SBQTdC8op': 3,
#    '4yvll0fmZ0TQ2dXLsFnH1t': 5,
#    '7JjZgY5fNkIu7aVeAIKBx3': 2,
#    '0JIcWmxwEpv740agHLbVB5': 2,
#    '73XCBmAq8ExhpAaK7OTbA4': 5,
#    '6oOJL3xj8zRz6URS0SwlXC': 5,
#    '5QeUZ1Z4xSCegBXutW3IIt': 7,
#    '0UtnmtF2Tj880Xs1sRP3gb': 2,
#    '6opt7VYMPXbQf6FGfabp3j': 5,
#    '1Fwppfa2qKDAETKveNFsHR': 0,
#    '0UJUZy6F5M4RxVEZCJrS6t': 4,
#    '0z36JaXXoFXuPuQucKEsdx': 1,
#    '4JILKVT5WHJ5b66QO41rcV': 3,
#    '2jAGOBsUwolwe5S62hnsLG': 5,
# ...
#    '6jXaJ37W4yKIBOEMpjGlli': 2,
#    '5VKd0sCErSIhQwTuMnYSja': 5,
#    '4mHgYpuGHu99Mw69E83CP2': 5,
#    '6P044Uja1fjxwqXOTT2QO4': 2,
#    '6Oi5FTOvWeHiauCJ7uxZJN': 0,
#    '4WuOWVnAqvEQxgSRrspBgt': 2,
#    '2WC4sK0ryyysQhtDok9Ytr': 5,
#    '5ouEKFLJwLAZBZONV5YSJQ': 2,
#    '19eoyvfxVTQUClbo6ikwTK': 6,
#    '5f4Hy5mw5SRaUgXX9c6P5S': 3,
#    '32vE1nuG8T9c8bhmZdRY6d': 2,
#    '5MPPttjfGap2C6j6eKcO6J': 3,
#    '1GHx1nHNeTMSUdyiwhFe1z': 5,
#    '6tiKwZppNjrls8RsPQwK6r': 0,
#    '1z64Qkx4ff9QUuOqG85eue': 7,
#    '590ISHy0XC3FRcDC21mmty': 3,
#    '74fQgHleHZ4V7Gm1XYcGkj': 0,
#    '6kksmL4t09IgxhajuVDDxR': 5},
#   'calm': {'30nT3prZFX5dITIbZGSbVA': 2,
#    '4FXaug5kHOhLCkQ2oSY06r': 6,
#    '2EAscrSU2XbrX415MvgRKL': 4,
#    '79f1BWnoz0SzwpQVXjmtxX': 5,
#    '2mGIPYhZ1iC3GUBiXmYgA8': 2,
#    '16UwPw97aFFsprUZrjoU3I': 6,
#    '5p2AWt8lG1aND8atwvpScV': 1,
#    '5EaqAJx6JpnQkJ7HM9X3hC': 6,
#    '2o41jDa4T0QKF9804tqyka': 6,
#    '02uumlgqcsmJb4n8xus7yd': 7,
#    '1rH0fl85kkL8ySygNMWvRM': 1,
#    '7JinB2F0516WbcPMtFepu6': 6,
#    '4mk2YCEPtrgVgHUutmQcSr': 1,
#    '1R2oFnqFpBpZj7pJd24nDZ': 5,
#    '5vAUwAzCryz0XuR6QdGwbk': 6,
#    '1dGC8B4AVlFvTE7hW1ZNK3': 1,
#    '2g7oWQYXIurU5x2YtMAC7H': 5,
#    '759KqKQyDmTWJape4odo21': 3,
#    '27An0sDvzMb7GM6pRE9ycF': 6,
#    '6Wgkn09AhQjIzFK1qx4xvY': 7,
#    '7nIG9RI8QkvsrepRb1t6ZQ': 5,
#    '0ptKkh5g9jnbLnNQjbpBTs': 6,
#    '0dz8sqGtPQIQI9fdIoMUVv': 6,
#    '6cr9XbO2yAJgTNa6XNRINF': 5,
#    '3noiPAHonb3coH4jSVM09i': 2,
#    '0DaAyMobjHsWVZAjZbqQ4J': 6,
#    '0hKF43wSjZNpnSwmNfHCct': 6,
#    '79Yw7tly4ekHIo0jQhXcIm': 2,
#    '4kyLrBSL84qHXJfYvnOoQw': 6,
#    '5FfInegP9g9CPjmfzZ7TuV': 1,
#    '6EtJU8JmcF7v8sLBEIO9tK': 6,
#    '7vxLj7MREliG5i5vSnqSVr': 2,
#    '3WBYqPLJjBxGYMDHjpGS6C': 1,
#    '1ehlPAd9LL7wTbA2mRNkzq': 1,
#    '4dc6eq2N9fGfdBGtIGZu3N': 6,
#    '5YGrJ7Vy0cOQl2F4uzl6lT': 1,
#    '28cdzzyEkkcimdkW8Sux4l': 5,
#    '2lMF3cGQbTOzELfwj4Ex3F': 6,
#    '4SBAy5e3cQWwH7le2CxJDm': 1,
#    '7oVzg7PHNE9fepPdHJVq6f': 6,
#    '4oz9h9dQ3w6q4l8vBBwGwf': 3,
#    '2sZmxXCO6mZCPTHd6DRcBH': 3,
#    '2PxmcrwxxXzuxDKyJaNV6W': 2,
#    '62tRvfOJMzsxhPkMJIChxq': 1,
#    '4smqcp7wpCfclJHaWJGYP3': 1,
#    '5iXYIu04vkN1pT11qqKBM9': 6,
#    '4F3obAUvUPgEmPWiFIaMvi': 1,
#    '0cn9QNXxWic1mrTdEJWSqz': 1,
#    '1pBHwNFcKgE4OcQOHQppSC': 1,
#    '27PNPVQqaqQ0m2p7uoxnFo': 2,
#    '67Cs1ZAGIzy0m2iiF7UuQF': 2,
#    '3BnXclvUwcS7iKV0iSR1zv': 1,
#    '6jQcQ1Ysb299iqeotY3Iy2': 5,
#    '0YFMpvuxexjjj8lZKYRCrD': 6,
#    '7j9ldwhKk3wx0KFWN7qADj': 2,
#    '5lx01JAoQWZf0bXrBamIba': 1,
#    '4lVmCosrwdhCJPhXyqs0do': 6,
#    '0b53tPTqZR1kOv7RoG04kh': 5,
#    '5vz0Vls8TbtlI58CHQrIpb': 6,
#    '1F6M5OxEBzMTpcTX64ie9m': 6,
#    '3LUvWNx3ceBjsOeuDOMEsl': 2,
#    '6hufgffERIawyOInt9DQTk': 1,
#    '1uAsrVZwWejTkJ87otnX7l': 1,
#    '7ElaJfZcJhriDGZ0EXUwQH': 3,
#    '4HTbx3Gny40i6LcQSWNgAZ': 2,
#    '3RMRrmCruSltU9pnzURb5F': 6,
#    '7n6PyIyXg66h87tCDkgPYQ': 6,
#    '5r9fTbn6YZVxHKaU4Rze3t': 6,
#    '0qgrapBbyeoDtHhsuWEC0N': 5,
#    '3XW2ewe1iNoBlHTYPUi39V': 5,
#    '01DgyWLmCNuUBJJGuokRiq': 6,
#    '10k2QcLj7kBa9HV1JQPsiD': 2,
#    '2SxQiQXujf3D29LxFeWm9Z': 6,
#    '7bk5U14iArhfEeazvoP3L5': 7,
#    '4C4B9L1O7JCiDSniF64rbJ': 6,
#    '3JPbOyccVz2HJDNaXfehiX': 5,
#    '6obsAYZi05zj2412g9UsGJ': 5,
#    '34rM6lzAxc1uZ1E0a05dQC': 5,
#    '28D9EaiySXKtyg37WFQqpT': 1,
#    '4MeXAGHd3SYAgfx8YsTveT': 1,
#    '2UBmzkQ80QnurJ3fioTMoI': 1,
#    '54CL4nBgy7PCEh32swRX6Z': 3,
#    '27tnbPBfFjof7acoR2aqcQ': 1,
#    '0XgpqzcmMFapQ0kebq1EuD': 1,
#    '0ob3wzPe3R3NpJtUEz0wUQ': 6,
#    '7Dxb8siYBoC5rZRPTmhob4': 0,
#    '4xugZez7zpHFNTgkf0DLV1': 6,
#    '1bsSaYmy0vOUH8tux2hAYV': 6,
#    '6ObteiklP2l4whcMITjr9Q': 2,
#    '5aeoTqvX4FHygRkHiaQ6co': 2,
#    '7qa14fkhxgOwWgJ2cbDTyc': 5,
#    '7c2CN4p20ptpqkERAJPdI1': 6,
#    '2yR2KTxdGPqpk8krap1Bbl': 6,
#    '0x8xbM5MEduFnFKlRqEmX0': 1,
#    '5LdVyywNiR4gqPPM3yqVSR': 5,
#    '2WOugRtzn1QKmCarSqavnM': 1,
#    '6CTYTP3Kb3TKDLurnsPcOP': 6,
#    '5AciiCKJKTLKRrAPSrKQy5': 5,
#    '60xGrKFHgLNpqhuS00HINp': 6,
#    '3u8dUoeCAtxfHQa8Q8J0tB': 2,
#    '6FiFFLgiC4yfPfTCXWIKtT': 6,
#    '51K71t2Sk90AVbjVsBcorb': 6,
#    '2VYSYwmSV52FNMlDu3J29w': 1,
#    '7Ln0DgKSrDG0ALbtNwGeml': 5,
#    '7LIo9pXnB5aaLVeP2CwArz': 2,
#    '6QIipu4U5W2kRHnZLURPhM': 5,
#    '4Lxh3lRm24bFhsmQyQsRMe': 7,
#    '2s6OXlo50HyknTTiR9k2Lu': 1,
#    '6zm09IPppaJSeHvLXxIMeG': 6,
#    '1hPEjphQtd9xBOLL4v1VYn': 5,
#    '4Rr8wJMtWyrOZTjEFwW06Y': 5,
#    '4mPSvPaenWjDjjsOhRZG7t': 3,
#    '1PFhEAtkZzUUl562PkbLey': 1,
#    '4xDlA5m82NK3cPFBED5ttv': 6,
#    '2iWlzsg7MoN9nKIwxlJWPc': 6,
#    '7pgD39CGSkncKQWi2jjVce': 1,
#    '3fO6tsLefZB1QaEsjp2CYC': 5,
#    '6OXrNh8asCu28gqFyTSw3Z': 6,
#    '5sdRMVfel2Bc5pTpkhjsbv': 1,
#    '3D6MKvMF7jmPJktJWPy4er': 6,
#    '5FGMMbjDUWrfwyP1w2ac0K': 5,
#    '4I27l8kJx6KdG1RtypMm3O': 1,
#    '6xgwBKdOoRET28Krqio0AM': 7,
#    '1zigCM8hdI0nC3Mt0NtFvA': 1,
#    '1hsC8r1VfGSuGCwLWbzmEh': 6,
#    '1B5B554dl0Z36trXMkpizv': 0,
#    '7JrVZDnXeCVMDQE59I320S': 0,
#    '6TCW0OXyzUHN5QCCIj7Hr8': 1,
#    '7geHCfvKGWHQ9d24S2a2aa': 6,
#    '5kvoICzDSDX0Aa76iyudea': 7,
#    '57I1k1T8MsrIRvYSp1UDZP': 7,
#    '6DjuB3ja8UvTVIrbLP7pSr': 6,
#    '4tfaUHGYBCMliBaOHM5vHX': 7,
#    '1jdY3EkXOaCZQVZNohFodF': 3,
#    '3nfhbwdfbK19V3vwRTAcoo': 6,
#    '2MOMbPmESd5YkmNz8LjKAe': 2,
#    '4BLroGG5pTJwGui3vurqql': 7,
#    '2okugVOve4zNsK1a3ZkvWj': 2,
#    '37MS15pVLTyY7TgqiKsDSs': 3,
#    '6UMSnFNKH8Wb3PTZV5rQIE': 6,
#    '11nkLTEsCUzxXLWpyuz65G': 6,
#    '4bXgmTz6rUXzetS0ugUGgy': 6,
#    '6Y7GT4UuGkUFhYHxVLQ4bF': 6,
#    '0SECfQ39aAxnp1tMCIDrCg': 7,
#    '74yp8DY2h6OJFKohTYfavv': 2,
#    '5ncldgDWSVHunEXD3nv7Ct': 1,
#    '25XP7GVJyjIN3S1gnD39Pi': 2,
#    '7FbRZoqaVPOEoJCQXiJSlo': 5,
#    '6o072JVrUHju3ReQDwnQvX': 1,
#    '4ymjIpe2Xh1aSMWnPcBjXf': 2,
#    '3v8L0vVNHzOTPK4GlOLzMX': 2,
#    '22wxDyfqvHg9IGx5sS2KCn': 7,
#    '0nk3vSKIYGQV6CK6pShUDQ': 6},
#   'depressed': {'05bnEv2dpFzmGVLGdjD9UP': 6,
#    '7eExIeAIMkxmrlxkzsNBzx': 1,
#    '0z2baDSyZghkfn5Bn6uHP3': 0,
#    '7vA8CkWhm0cdl6bOTUBPyu': 4,
#    '7IhouSjZ0H5W3fYd5zpPvn': 7,
#    '4jvjzW7Hm0yK4LvvE0Paz9': 4,
#    '55HA7BDCwHhWbtlywFifL9': 1,
#    '7zy7iE31dGO70ShMXghsfj': 5,
#    '6cqCWT5nFpMuQcl8KBl8Ix': 2,
#    '4lLR14DyqhM5LBj6iHI0Al': 6,
#    '5TWNjoKCqKySlJlfD9Dsg7': 1,
#    '439EmunDAlipjDuejCQDjQ': 5,
#    '7AUXScBeRD7EXEFOsglJag': 1,
#    '759KqKQyDmTWJape4odo21': 5,
#    '44p5ZWDBSppOoABrxoH5jU': 0,
#    '1PZ6hKLmGYOtCSnqAM4ckB': 0,
#    '3J17Wt7w0qXzWOeb96FBjs': 7,
#    '2k4JprD2WzbThquUdLPzCT': 3,
#    '0Id4hY9V8gnNWKjTngo0c0': 1,
#    '2yZax79pOrYuyIFVW2cZY2': 7,
#    '10jW0nxhLrPI8QQ0Wa1Tdm': 7,
#    '3QIA6NjmK8ecTQYEM5Lr0b': 1,
#    '4p4paSLA24MCEHmpXzOYPB': 5,
#    '38EhHqsV5NX9JrC2D2qXNI': 7,
#    '70hDklZStSazrExPjHJPfR': 5,
#    '4zdyFo2y7qbQrfpLaRL4Zu': 7,
#    '03ERnTvSV5fy8WAyvA4uNP': 0,
#    '5sa5t9EMaMa4G1nv90uR2t': 1,
#    '7t56yq30WJ4ok9DQlGFohq': 7,
#    '76epGKVhxWA7gEYcjAs3em': 0,
#    '2z2jZzZabHWHP0e7ulELQS': 5,
#    '2edkogvqZcdQcGSSxOvQs2': 6,
#    '6eZTf0CCINNXzgFcYLSJPI': 7,
#    '4oebzB09U8UoYtNnS6vTjt': 5,
#    '6lhL1ohGs3jzzrFWAkxDvY': 3,
#    '4GSyA0YDBON0qD8fvqmPan': 3,
#    '5Ctp29E4N078VPralCQJBb': 6,
#    '0EthCoR2pdeYgqgQ6KE4ig': 1,
#    '1t9WgS8FN0534tLBRwbaxO': 4,
#    '1R6VwZ8TuHRzxZUxe88n4I': 0,
#    '0B6gI2Eupg8MigELBFHVA8': 5,
#    '4h6Bde1AFeLDT5jFbxjXll': 3,
#    '0uOQncxaxvAYGGQ5WlOH6g': 1,
#    '3hu0J1n9WVCtehnfgXorZV': 5,
#    '3tRmZdCNGn51o5QtkB8ROw': 2,
#    '2LjW25DtSDZHU7FvyqspVt': 0,
#    '6t2dHDQMpBlHH0vrHIifaz': 1,
#    '5xbrhx2tMMcN68IT3cJbhS': 7,
#    '7pqNDK7jFGMuQjRWjg8rVe': 4,
#    '5ZbtYedjpo7Sw2mqjNCUdx': 0,
#    '3uGjSpIV3g5WRoe6EelLgp': 2,
#    '5mrOB2YKsdKO76lqF2eQSE': 5,
#    '3AMxuq6id3YGB57eWeheZQ': 3,
#    '1QPreu0BNOrUfEb8HTd2qG': 7,
#    '5jEckE3mjKysnzmE5hTEBM': 5,
#    '1W1kOLMIYoX1GaVdoCj5Nt': 7,
#    '2IePEfMAtqWS6rLXXFZIgI': 2,
#    '1gfxFC5OxtlfJsphauqSpB': 7,
#    '4eSZUNz2flCKs7zESV50kW': 1,
#    '4eTpR71VWfTee42OKPaQcz': 7,
#    '7qDb2aYT1RIxhKT83HzDQ7': 0,
#    '3arQDLbkZnujJVfhoyEDlM': 0,
#    '6BOv5seykOCtEXOZ88RR1l': 4,
#    '6ts4kE7a3xDeYF3IWViRXg': 6,
#    '2HTXyMzSa6yxMgkEDV14Fb': 3,
#    '6BjtaWm1T4kDWAqHrf8vEi': 2,
#    '1q8DwZtQen5fvyB7cKbShC': 7,
#    '7CpXFEjLntpr4GdOhTtFEv': 2,
#    '3vEOALYBUNQUMXpqhWx3hG': 0,
#    '6lH7efXawM6TwyhepEmMQ4': 1,
#    '7lftB3f1vir7xBnYzEnaUr': 4,
#    '3BJcTgZiU1l2msoyi803I8': 1,
#    '5467KZaTToEB680WvOd9w5': 5,
#    '5vAEnWrHxLv78uwZrAJcX6': 2,
#    '0Xakrw6UhbfgHAvWic9ZoJ': 2,
#    '5hpkK8f1iVrF3OrAMcphJY': 2,
#    '7zpVxc1rK9EZSwnjB4x8ep': 0,
#    '27aGlicHJKf5QY20looYlR': 3,
#    '5sqqtnhc4alpMEjG6447u2': 1,
#    '2rqz2W2Fw34FXQLmpcrpSE': 2,
#    '3sYqw7GRD7ioOO3Xq2FqZ2': 5,
#    '7HpTckXU5esuMHYzpI2JD7': 6,
#    '2EznBGrlmx9wBeYgyDojsA': 5,
#    '2vl0D1b0M6UHlD1Fjh5j1m': 3,
#    '3e7LQvyW617yxNW6mm0XdA': 5,
#    '5yYV7pSaVaMdCOtx8fksc1': 1,
#    '4pQbnbI736qzbR6lUNlaSW': 3,
#    '7DFH1yLJ5kWqUEw1N3h8Gv': 7,
#    '3rcWGZhZcFy27M25xxzsuc': 3,
#    '2gKgIBiXAcnCp7kuX9YJkb': 5,
#    '2puiJu8UrS9UmXlafslEbM': 7,
#    '1T7LVMJY0QWosapku2By6K': 0,
#    '4D3hcHpsFsiQFBNIKYgjui': 6,
#    '6rTInqW3YECMkQsBEHw4sd': 3,
#    '4Th3WxcSkq0Vbp7FyTw0Zu': 5,
#    '2fXw6dpGwuw2JxxWvbnyoJ': 4,
#    '1b0ZeVYPZCDaAk4pT42pxy': 0,
#    '1Ajoi45AjYqloARp5ufaVK': 7,
#    '0J2etwoRJ4SLhNfDYWo3mo': 6,
#    '2P8wItbUXEYabqM2y5hqe9': 5,
#    '06X9eSG5QBL77VmdLIA9v9': 5,
#    '2xcSJYwY0Z6M3mnwXa3CqU': 2,
#    '3aQem4jVGdhtg116TmJnHz': 3,
#    '6zBDvPm5pD1kfyLoN70y9i': 0,
#    '4LfnSeYhgLEuhvbj0k9HEB': 0,
#    '5VlkejIdL1SnfseKr6Abzc': 0,
#    '3Kwdm0iLyEiRB8InsZoo6n': 6,
#    '3oZXabexCtFngTbNLgY7wR': 5,
#    '4LZjjqNHKbrdUD62mZSkjL': 1,
#    '1wiAqJt4noNYp0eSVrX3jE': 6,
#    '6fYr27d1dxrs2tiYW3nOdN': 5,
#    '6QOsKxJafmMzYGdjxwnELF': 7,
#    '156QgQpZ4z9tKSeucOLIPy': 0,
#    '4jQiLyv1wtOtgKVEiA7yuq': 3,
#    '2kYB66omjIRkqPx8zRPEAH': 7,
#    '6Jc69KjFo9QNailcyDJh2I': 3,
#    '13m5HQh3NzNyukUsA0GyYq': 4,
#    '3vkYJeL6p7hOC0uNqFWNU6': 0,
#    '2Yr2BzqNDpIh0YQcnFqM09': 4,
#    '3Gnmh7SrP3dB1dcMphR1Dd': 5,
#    '1VMhHTmsu0mpT5bPTN60rA': 1,
#    '0iizrCBnUUJuAwCPJaWWY0': 5,
#    '6h2U8JPQ4ytRiUybQK7Aae': 7,
#    '2rbSlNYTYboHHWelF0xSAQ': 2,
#    '50J3n2Xi624snV5VmAGfLL': 3,
#    '5mguaSBj1tjUnpPxqGyAMb': 7,
#    '4UYQHTgOlSdaQWfUTAjpop': 2,
#    '6755DFiZ7CWe2WMdTGW5C1': 3,
#    '3ZeQyvZicIaMgUmAIUg2CN': 3,
#    '2Z2KI7dFmWpxdLMYWYPhHE': 1,
#    '3T34THR0MHEQCZhk0E99Ew': 2,
#    '7jtmFB5v6jXFsX6zVccf1U': 5,
#    '2NvCCQf6AegakliNO3Ujat': 4,
#    '616rALOBxvc3bbp38iiud5': 2,
#    '0chFtR5ZB1Z46Te39UVghc': 1,
#    '1VLtjHwRWOVJiE5Py7JxoQ': 5,
#    '7LndLbr0FT2w6bzgfS1rM3': 5,
#    '4HlSeYvTvl6kuPdhJlm8Sg': 5,
#    '7sd72KZS8D59g5NmhxyHpJ': 3,
#    '7Cq27Qc3WRyQ3ddwVslpVZ': 2,
#    '5eBH6kvJDJEEuS45SfdU2T': 5,
#    '2ZLXySbOZbdg1uLpC48zzJ': 3,
#    '079mtESlfnN0BTYsaiEXuY': 0,
#    '3Vi4bL9tyKxIcFnWRWKYpu': 2,
#    '43lThlOgXQnP8F1ui2Ml1i': 4,
#    '0FF3X4K698Nplr1Mj1n7Id': 5,
#    '2Lmpxi7j95HOvsR6zj1Fl3': 1,
#    '3jpZwYrDbX2lQMhHwXjyUD': 6,
#    '6QoAbC7Goquys7vP8yqQoa': 7,
#    '5MrtQggewKtfSzs4akoaD2': 1,
#    '3a5AVFUzkPgXdi4wrQel0t': 0,
#    '7A0YT182CeR5tNrESpPbJj': 6,
#    '15cYjzRUBRrDHn76GdxWiv': 4,
#    '4hGHcdD5IwjAkftalZm5an': 3,
#    '6OquGsVTLqZHyxqG0PLwFz': 5,
#    '2g6tReTlM2Akp41g0HaeXN': 5,
#    '5cfIibuUGxlrdXcNaWmAnQ': 0,
#    '2CxinLuB16KJjMPoIMLVTL': 1,
#    '5pNuQiQVP0DX7BlYZItdzW': 2,
#    '64IWxKeqZnEH9pewHZk2yX': 4,
#    '1biGLgU3ws2Z9S4iCMLoDx': 6,
#    '55mmAY09sc3CccPpAdUqo4': 4,
#    '2E4INiVkDRBXXkFL4kB1Vk': 1,
#    '66IEiLsDOrGwdqkMc9KJBR': 7,
#    '20VRHxIghP08HJcqVItB7c': 1,
#    '0a8hsn7oo5KxrN4S9zzy8a': 3,
#    '3zECq69UpWbxwIzF1jJl7G': 5,
#    '5tw5H51GeMaSBcD0CHKsBq': 3,
#    '6IM2okqXPGT9LJuOW1RV9V': 5,
#    '1uk3kkh2Nan6FjROqliwbu': 5,
#    '3fOYC3nXiWIJRWZYkLxO5C': 4,
#    '32d7qjJQ35ojU0vI5EZDCJ': 3,
#    '0Sylalanw3faH04jn3xd02': 2,
#    '0ExV4N2BxqbeCa17VNYC4I': 2,
#    '695L0B06tMVsy8RiwC7dHc': 1,
#    '09OLqn4uDbI49OGfioUntH': 2,
#    '06YAQv6odmXWnR9pzMaJOm': 3,
#    '7MfgrjZCYAneVip3CBSE02': 5,
#    '1GwvBbLdKyfcvyLCyjgSlF': 1,
#    '3zX85oquwvMRDnGlbOOnBm': 6,
#    '6mqXhNpg539WTUFewKQz62': 6,
#    '4iozFVWt8fzhDffkxoxcsS': 7,
#    '22hdnPB5hmyzOJLQQrcDSS': 4,
#    '0CCvfFVSpOHGuxsrzfwbYL': 0,
#    '0xeK2ZJmnLfHAw1ELUinE9': 5,
#    '02TPansZwYWRrDEZn8QbOh': 0,
#    '4E2clyqifN77zbPZjYvzMP': 2,
#    '3q0U6eqmHObU2cy0O6VHGS': 3,
#    '66mbI5v6PcCH3VKGJqdFfr': 3,
#    '2H81mhmuFhgMfQ2cZHgRdJ': 4,
#    '67RGFObGLxBAJDLrukSusE': 3,
#    '6fahWEQQyU3y1aGwqpI2oj': 6,
#    '1ObJwPnro8VjpEDt1slsgR': 5,
#    '4uOTXRwsnJIQt6R4EwuHCw': 5,
#    '5zqJAcrIbemMIqlN5sMX91': 7,
#    '3KcIgymEfwvxJxQTkhUlC5': 3,
#    '59s9wlR26j5Q9ecqiFFha2': 0,
#    '0GCIytWuI9C1jFgX5ChgB4': 0,
#    '0MW5zwGXciXyVdFwQbvBq8': 4,
#    '6VGGUt2yqHqrEnEeKrIkJM': 5,
#    '0RrevZ4nkQAP3krXXjq9Cf': 6,
#    '2dSKFFNoNXKo3hPnlwUdPe': 1,
#    '2bQxqezLVNiJVeLO0RWPON': 1,
#    '1Nn2soqezg6z2FaWUmgnNK': 5,
#    '4zqSYxKE9K6B4eghImq7pz': 1,
#    '43JEp8oQ3fmXXHZPgzEIoC': 7,
#    '4G2EZxuVFICrq0hurtxYaD': 2,
#    '70wd1fE44Rb9mnZMaApmkc': 1,
#    '2nGgWIQpeVTKwrxTDcYflU': 5,
#    '7cGzEpKCeLvODoxLFy7ntV': 0,
#    '40OcWS4cakpvJ4ZYfwHWSP': 1,
#    '4nyMOz0tZOqPoZMYvIg6xN': 0,
#    '4PDLvSojW752SsO9yxavlv': 3,
#    '73tPKPTIqlfW3xjvLtaUJh': 7,
#    '44dvAfibxim6nEbQljy98l': 7,
#    '6U9RfWptbPDHzXSktc3GV8': 7,
#    '3q5zy0yDMLa4cOGlR0i3o3': 5,
#    '479acVfQ74icOy772hE1ba': 0,
#    '3AO2MYgrCiTorCUura1szR': 0,
#    '1xMvdOFQaql3EBkHmuh2TK': 3,
#    '5ocuRCDSWiUMZcWI4Utd9g': 4,
#    '2kxZnZBMfHbinyLaSDvP4Z': 6,
#    '7srEG9v7czAVq8kUzoHVGG': 1,
#    '0Yptvdo4iVZ42hz0m8rGng': 0,
#    '20UF7YHurJ0DRgEaBLdBEB': 7,
#    '2jrS0Navn5ztmRTuvN1eMS': 0,
#    '25XyKEbwKuOAfNFR4gut7i': 4,
#    '4pqYf5eVYFpesyKlrFGNTE': 0,
#    '3z2wxeaDVi9iIxtsHxmC39': 7,
#    '5ZYtMEd0eqzLcQdXImuizq': 3,
#    '5k3xP19vac82Kweo4mOvlw': 7,
#    '4a2rDgkDZVSN660vkhE4mE': 3,
#    '77GoToROOVIQZidN1naoOF': 7,
#    '7EZTzAIa4S8593vh2KgGPS': 3,
#    '2shEeQzAAL3nnOXfB5pJXx': 0,
#    '4xt1R2G2ee60xmS2KRQAAv': 3,
#    '5m1X8EJrSvcCe2fiZgtFiW': 7,
#    '6LsMmm02qu6SOmp9JeaIyC': 7,
#    '6Q0KBExmZVG7KVoFA8CRag': 6,
#    '5lXaNGil0yGfrcgcyjlXU5': 5,
#    '59nJ265OcQ7Rrms09xk8LO': 4,
#    '4nO9Cmh5GCffY1gd56zfNg': 6,
#    '7EuyxoNvPPi4dGYwRD7qFk': 7,
#    '2tsOYiP106WH5jqTQlIs34': 3,
#    '49mHp1iZxr3kkMDJH9WJYI': 7,
#    '5Y0Iuh3hlpbYczRl09g2Ot': 0,
#    '25YKz9PgDO2kBREfWc4lH9': 5,
#    '5zx1WrC5AuCaKjpKZDzNy5': 5,
#    '3cUREgJIhqP6S5afhHRPqg': 2,
#    '7hZoTr4ffMGqm9opMiGmBp': 2,
#    '2bYKa1pkKKkZg0O7f32wQC': 1,
#    '0bc3I3fYeyHj6dyEaaV2ga': 5,
#    '7nF0TnQV9RIzn1mIlr5qxC': 7,
#    '1zJFJHs9CY7QgiawsMI5tj': 5,
#    '6fsypiJHyWmeINsOLC1cos': 1,
#    '65OVbaJR5O1RmwOQx0875b': 3,
#    '0ijkEO0FxiNofOkQc6aNUo': 2,
#    '1dSQTFRuAAQSGbFlLukmD5': 2,
#    '2OoB6AHLHuLxhkNHrUH7lD': 2,
#    '0QVXKWDVlIMG5lezc5syoR': 2,
#    '2JbNx2R6LaF2dZ2CYA1kDV': 7,
#    '1SaxT2eggG2xalUM21tUSw': 1,
#    '01zfCyaC7dqYGfTWNUP7G9': 7,
#    '3YpZvmfw2sFD4jb4rCqC0c': 4,
#    '61OE5AniQ5OYYTFg2ifkS0': 7,
#    '4lb7sikLCQRhFNdHCgThFa': 6,
#    '1cxiWayyqLr51M5gdkeEgi': 4,
#    '1ePRRO0RaVPy2diUURqb3I': 4,
#    '6oOJL3xj8zRz6URS0SwlXC': 5,
#    '4QPtyUkP2ysNjZDF5AuZMC': 3,
#    '5hVnFTUmD5oa7Pl4ltn6KE': 2,
#    '1vOYxV3UqnHv66gHvjhgO7': 1,
#    '2UqBRTMIA8LylOo9B8VKjk': 7,
#    '2oe6dDthgthqUkfL3czpEd': 6,
#    '6xk72vDvgejb0PlrNVyqDv': 7,
#    '1miTBoyS953uPXfGjEA3lG': 5,
#    '6tFWMs2FJMi4loy4XlR8bz': 5,
#    '1Wh5LO3TWAvaeDrwp4FZgo': 6,
#    '17sIAP86GewFcJyKyrq0gb': 5,
#    '0ve3W5MKGMHQeydchnAJHw': 6,
#    '02fYKPm8iW1seajDuuVfRe': 2,
#    '2ocqfNwZgURFqRvFHxTN7g': 4,
#    '5Dn6cgiKkQhO3HmHfvN4aG': 1,
#    '2RC3TbzlpR5lpzODqOUQfL': 5,
#    '25RqaN8gzxP4xzd8QBKi3o': 5,
#    '4nXn1iXBvwKEuHmMJgmx6m': 5,
#    '3ED40EjXiD4plW6UMteKGx': 3,
#    '3tQ5uFbQpw76o2hKA9WKgW': 7,
#    '4rnriM1hFyeRrdRQSZd9uA': 5,
#    '64LVs2eF1vIj4vPSsZ5RZw': 5,
#    '3sw7cuNo0uCfTPgUYzEmAz': 5,
#    '0k4JSIG2PfVxVCiV7SDCJh': 3,
#    '2Nh2cMryoXl7BrZoIeN2Pr': 5,
#    '39iGFT4wktukoJD5XoQty4': 7,
#    '2y55JzTDe2kFDChkBZUOUS': 1,
#    '7ikBXLjiqBOW0Uapur3Uyi': 0,
#    '4rdGXL4EVj78JytSGbhaHs': 0,
#    '4OqQ2lMJ83UXdX2GR9czRr': 4,
#    '2Y93NLRKB6v8fNHdHikZui': 5,
#    '7IU3RdrHZVXUZpiuiimNfJ': 2,
#    '3UVeBezkhWj5BN4RRLJmgp': 0,
#    '1JVmbc8FR7jPS5l2u0ZC7H': 5,
#    '264udbZoXKcUv6tBmQCecP': 5,
#    '0LmD6LnXYecaaMZKG8bW12': 4,
#    '3lWA08dIua1aQKxASkQM6i': 2,
#    '2XUxq1VOiB3KXIDCULji8A': 6,
#    '1cEhrSF6EylAEqdhUGuNpX': 3,
#    '3NWrHCwvyII4fTx05PN3IO': 5,
#    '1LlwjIuSPHNk61m7X9L4DP': 2,
#    '6QutayBrziruy3GoPMqBBq': 7,
#    '3CtfBYewF9YoIj4tN1Xuh6': 1,
#    '6RpunyUP44SDweJPDScLSF': 2,
#    '6vkczNPCftHsMJpjYYiXDp': 2,
#    '7wvSEumOfmlFbiw1ssdEsn': 7,
#    '4WHTPYuYq06nlX6jLRAFuD': 5,
#    '5iMRhOHzze2CujxHiJ6cRL': 7,
#    '6motja4C4U6oCgtojBTyCI': 2,
#    '7lPYfKnWRykCKTFngnkLxU': 5,
#    '31UK3mm2N86FOhBz6FEhp6': 3,
#    '3Mns4Bp3YcGlXGTuGmd0Qd': 1,
#    '1b5A8e1EaHBtcKLeThpujG': 4,
#    '6S5dMjMifQYmyTu1mX4f8P': 7,
#    '4ELmykSaWrdjQS5iADqHxS': 1,
#    '49B8GFGaFTXkX62qXni4Px': 3,
#    '5Qyoymb64zCGxIMCdPZb4F': 1,
#    '1udwFobQ1JoOdWPQrp2b6u': 5,
#    '4rhr8LgQoPtWkQaXVPSNOO': 6,
#    '2LYs1AmKxCwLHzLv6QxeE4': 7}}}

# %%
model_predicted_labels["MLP"].keys()
intEmotionDict = {0:'sad',1:'angry',2:'energetic',3:'excited',4:'happy',5:'content',6:'calm',7:'depressed'}
playlist_ready = {}
for mood in model_predicted_labels["MLP"].keys():
    for id in model_predicted_labels["MLP"][mood].keys():
        prediction = model_predicted_labels["MLP"][mood][id]
        if intEmotionDict[prediction]==mood:
            if mood not in playlist_ready.keys():
                playlist_ready[mood] = []
            playlist_ready[mood].append(id)

for key in playlist_ready.keys():
    print(key, len(playlist_ready[key]))
# Out:
# sad 50
# angry 50
# energetic 50
# excited 50
# happy 50
# content 50
# calm 50
# depressed 50

# %%
#save playlist_ready to a pkl file
chdir('C:/Users/mlar5/OneDrive/Desktop/Code Folder/Python Projects/IRL projects/Aspire - Affective Computing Project/Playlists Data/Audio Features/Personal Track Testing/joint data')
with open('playlist_ready.pkl', 'wb') as f:
    pickle.dump(playlist_ready, f)

# %%
chdir('C:/Users/mlar5/OneDrive/Desktop/Code Folder/Python Projects/IRL projects/Aspire - Affective Computing Project/Playlists Data/Audio Features/Personal Track Testing/joint data')
#load playlist_ready from a pkl file
with open('playlist_ready.pkl', 'rb') as f:
    playlist_ready = pickle.load(f)
playlist_ready.keys()
# Out:
# dict_keys(['sad', 'angry', 'energetic', 'excited', 'happy', 'content', 'calm', 'depressed'])

# %%
sp = spotipy.Spotify(auth_manager=SpotifyOAuth('86677c795a49463d9281fac012a87155','fe6f941da771447c920e02bbb2a82859', redirect_uri='http://localhost:5000', scope='playlist-modify-public,playlist-modify-private') )

# %%
sp.current_user()['id']
# Out:
# 'nobodyknowsmynam'

# %%
#make a new playlist for the current user
user_id = sp.current_user()['id']
playlist_name = 'MLP Test SAD Playlist'
playlist_description = 'This is rlly happening lol'
playlist_id = sp.user_playlist_create(user_id, playlist_name, public=True, collaborative=False, description=playlist_description)['id']

# %%
# add the tracks from the playlist_ready['sad'] to the new playlist
results = sp.user_playlist_add_tracks(user_id, playlist_id, playlist_ready['sad'])

# %%
for key in playlist_ready.keys():
    if key != 'sad':
        #make a new playlist for the current user
        user_id = sp.current_user()['id']
        playlist_name = f'MLP Test {key} Playlist'
        playlist_description = f'{key} playlist'
        playlist_id = sp.user_playlist_create(user_id, playlist_name, public=True, collaborative=False, description=playlist_description)['id']
        sp.user_playlist_add_tracks(user_id, playlist_id, playlist_ready[key])

# %%
results
# Out:
# {'snapshot_id': 'MyxjZjQyZjA2ZTM3MjQxMzJmNDhiN2Y4NzUxMjVhMDEyNWE0NTk4ZTQy'}

# %% [markdown]
# # Data Analysis

# %%
#Analyze total songs model was able to classify selected mood / 200
target_count_moods = {}
for name in names:
    target_count_moods[name] = {}
    for mood in moods:
        target_count_moods[name][mood] = model_stats[name][mood]['count_mood_index']

# Create a 2D array of the accuracy values
total_values = np.array([[target_count_moods[model_name][mood_name] for mood_name in moods] for model_name in target_count_moods])


# Create a heatmap using matplotlib
# Create a larger figure size
fig, ax = plt.subplots(figsize=(10, 8))
im = ax.imshow(total_values, cmap='viridis')

# Add labels to the x and y axes
ax.set_xticks(np.arange(len(moods)))
ax.set_yticks(np.arange(len(target_count_moods)))
ax.set_xticklabels(moods)
ax.set_yticklabels(target_count_moods.keys())

# Add value annotations to the heatmap
for i in range(len(target_count_moods)):
    for j in range(len(moods)):
        text = ax.text(j, i, "{:.0f}".format(total_values[i, j]), ha="center", va="center", color="w")

# Add a colorbar to the heatmap
cbar = ax.figure.colorbar(im, ax=ax)

# Set the title of the heatmap
ax.set_title("Model total number of songs classified (asked to classify 200)")

# Show the heatmap
plt.show()

# %%
#Analyze acceptance rate of recommendations without similar moods
target_label_probabilities = {}
for name in names:
    target_label_probabilities[name] = {}
    for mood in moods:
        target_label_probabilities[name][mood] = model_stats[name][mood]['label_prob'][mood]

# Create a 2D array of the accuracy values
accuracy_values = np.array([[target_label_probabilities[model_name][mood_name] for mood_name in moods] for model_name in target_label_probabilities])


# Create a heatmap using matplotlib
# Create a larger figure size
fig, ax = plt.subplots(figsize=(10, 8))
im = ax.imshow(accuracy_values, cmap='viridis')

# Add labels to the x and y axes
ax.set_xticks(np.arange(len(moods)))
ax.set_yticks(np.arange(len(target_label_probabilities)))
ax.set_xticklabels(moods)
ax.set_yticklabels(target_label_probabilities.keys())

# Add value annotations to the heatmap
for i in range(len(target_label_probabilities)):
    for j in range(len(moods)):
        text = ax.text(j, i, "{:.2f}".format(accuracy_values[i, j]), ha="center", va="center", color="w")

# Add a colorbar to the heatmap
cbar = ax.figure.colorbar(im, ax=ax)

# Set the title of the heatmap
ax.set_title("Model rate of accepting recommendation for individual moods")

# Show the heatmap
plt.show()

# %%
#Analyze acceptance rate of recommendations with similar moods
target_label_probabilities = {}
for name in names:
    target_label_probabilities[name] = {}
    for mood in moods:
        mood_index = moods.index(mood)
        mood_probs = model_stats[name][mood]['label_prob']
        target_label_probabilities[name][mood] = mood_probs[moods[mood_index]] + mood_probs[moods[mood_index - 1]] + mood_probs[moods[(mood_index + 1)%len(moods)]]

# Create a 2D array of the accuracy values
accuracy_values = np.array([[target_label_probabilities[model_name][mood_name] for mood_name in moods] for model_name in target_label_probabilities])

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(10, 8))

# Create a heatmap using matplotlib
im = ax.imshow(accuracy_values, cmap='viridis')

# Add labels to the x and y axes
ax.set_xticks(np.arange(len(moods)))
ax.set_yticks(np.arange(len(target_label_probabilities)))
ax.set_xticklabels(moods)
ax.set_yticklabels(target_label_probabilities.keys())

# Add value annotations to the heatmap
for i in range(len(target_label_probabilities)):
    for j in range(len(moods)):
        text = ax.text(j, i, "{:.2f}".format(accuracy_values[i, j]), ha="center", va="center", color="w")

# Add a colorbar to the heatmap
cbar = ax.figure.colorbar(im, ax=ax)

# Set the title of the heatmap
ax.set_title("Model rate of accepting recommendation for similar moods")

# Show the heatmap
plt.show()

# %%
#Check prediction distribution of models
count_dict = {}
for name in names:
    count_dict[name] = {}
    for target_mood in moods:
        total = 0
        for predicted_mood in moods:
            total += len([v for v in model_predicted_labels[name][predicted_mood].values() if v == moods.index(target_mood)])
        count_dict[name][target_mood] = total

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(7, 6))

# Set the bar width
bar_width = 0.15

# Set the bar positions
bar_positions = [1, 2, 3, 4, 5, 6, 7, 8]

# Loop over the models and plot the bars
for i, model in enumerate(count_dict):
    # Calculate the x positions for the bars
    offset = i * bar_width
    bar_groups = [x + offset for x in bar_positions]
    
    # Get the counts for the model
    counts = [count_dict[model][mood] for mood in moods]
    
    # Plot the bars
    ax.bar(bar_groups, counts, bar_width, label=model)

# Set the x and y labels, ticks, and legend
ax.set_xlabel('Mood')
ax.set_ylabel('Count')
ax.set_xticks([x + 2.5 * bar_width for x in bar_positions])
ax.set_xticklabels(moods)
ax.legend()
ax.set_title("Prediction Distribution for each Model")

plt.show()

# %%
#Time distributions for each model
model_time_per_mood = {}
for name in names:
    model_time_per_mood[name] = {}
    for mood in moods:
        model_time_per_mood[name][mood] = model_stats[name][mood]['elapsed_time']

# Create a list of the total time taken by all models for each mood
total_times = [sum(model_time_per_mood[model][mood] for model in names) for mood in moods]

# Create a list of the time taken by each model for each mood
model_times = [[model_time_per_mood[model][mood] for model in names] for mood in moods]

# Create a stacked bar chart
fig, ax = plt.subplots(figsize=(10, 8))

# Set the bar width
bar_width = 0.2

# Define the bar groups
bar_groups = list(model_time_per_mood[list(model_time_per_mood.keys())[0]].keys())

# Initialize the model_counts dictionary
model_counts = {model: [] for model in model_time_per_mood}

# Iterate over the models and bar groups
for model in model_time_per_mood:
    for group in bar_groups:
        # Append the time for the current model and group
        model_counts[model].append(model_time_per_mood[model][group])
    
    # Add zero-padding if necessary to make sure each model_counts[model] has the same length as bar_groups
    if len(model_counts[model]) < len(bar_groups):
        model_counts[model] += [0] * (len(bar_groups) - len(model_counts[model]))

# Set the bar positions for each model
bar_positions = []
for i, model in enumerate(model_counts):
    bar_positions += [idx + (i * bar_width) for idx in range(len(bar_groups))]

# Plot the bars
for i, model in enumerate(model_counts):
    ax.bar(bar_positions[i*len(bar_groups):(i+1)*len(bar_groups)], model_counts[model], bar_width, label=model)

# Set the x and y labels, ticks, and legend
ax.set_xlabel('Mood')
ax.set_ylabel('Time (s)')
ax.set_xticks([x + bar_width for x in range(len(bar_groups))])
ax.set_xticklabels(moods)
ax.legend()
ax.set_title('Time it takes each model to generate a playlist for a specified mood')

# Show the plot
plt.show()
